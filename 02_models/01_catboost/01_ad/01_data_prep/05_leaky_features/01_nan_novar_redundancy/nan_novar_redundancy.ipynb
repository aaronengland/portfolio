# %%
import os
import pandas as pd
import functions as func
import numpy as np
from tqdm import tqdm
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# ### Constants

# %%
str_project = os.getcwd().split('/')[4].replace('_','-')
print(f'Project: {str_project}')
str_dirname_output = './output'
# Out:
# Project: 20231010-gen-xii

# %% [markdown]
# ### Output

# %%
try:
    os.mkdir(str_dirname_output)
except:
    pass

# %% [markdown]
# ### Empty list

# %%
# %%time

list_cols_all = []
for str_df in tqdm (['train','valid','test']):
    # print
    print(f'Data set: {str_df}')
    print('')
    
    # import
    str_filename = f'df_{str_df}_raw.gzip'
    str_uri = f's3://{str_project}/01_ad/01_data_prep/03_train_valid_test_split/{str_filename}'
    # read from s3
    df = pd.read_parquet(str_uri)
    # replace
    df.replace(['NaN','nan'], np.nan, inplace=True)
    
    # check all nan
    list_cols = func.find_all_nan_columns(
        df=df,
    )
    list_cols_all.extend(list_cols)
    print(f'There are {len(list_cols)} features in the {str_df} df that are 100% NaN')
    for a, col in enumerate(list_cols):
        print(f'{a+1} - {col}')
    print('')
    
    # check no var
    list_cols = func.find_no_variance_columns(
        df=df,
    )
    list_cols_all.extend(list_cols)
    print(f'There are {len(list_cols)} features in the {str_df} df that have no variance')
    for a, col in enumerate(list_cols):
        print(f'{a+1} - {col}')
    print('')
    
    # check redundancy
    list_cols = func.find_redundant_columns(
        df=df,
    )
    list_cols_all.extend(list_cols)
    print(f'There are {len(list_cols)} features in the {str_df} df that are redundant')
    for a, col in enumerate(list_cols):
        print(f'{a+1} - {col}')
    print('')
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Data set: train
#
# There are 87 features in the train df that are 100% NaN
# 1 - bitdebtor__base
# 2 - dtmstampcreation__base
# 3 - dtmapproved__base
# 4 - dtmdeclined__base
# 5 - dtmfunded__base
# 6 - observationdate__base
# 7 - analyticsmatchkey__base
# 8 - decision_dte__base
# 9 - booked__base
# 10 - acct_typ_cde__base
# 11 - open_dte__base
# 12 - curr_bal_amt__base
# 13 - terms_freq_cde__base
# 14 - affil_rem_cde__base
# 15 - cmplnc_rem_cde__base
# 16 - gnrc_rem_cde__base
# 17 - rte_rem_cde__base
# 18 - acct_rte_prfl_cde__base
# 19 - payt_pttrn_txt__base
# 20 - gnrcrem_frsrpt_dte__base
# 21 - obs_arch__base
# 22 - vtg4__base
# 23 - performance__base
# 24 - creditasofdate__tu
# 25 - firstname__tu
# 26 - middlename__tu
# 27 - lastname__tu
# 28 - address1__tu
# 29 - strname__tu
# 30 - state__tu
# 31 - zip5__tu
# 32 - zip4__tu
# 33 - ssn__tu
# 34 - dateofbirth__tu
# 35 - dtmstampcreation__tu
# 36 - observationdate__tu
# 37 - analyticsmatchkey__tu
# 38 - segment__tu
# 39 - indflag__tu
# 40 - iscrhit__tu
# 41 - bctrd__tu
# 42 - insttrd__tu
# 43 - nomttrd__tu
# 44 - revtrd__tu
# 45 - rtltrd__tu
# 46 - bkc231__tu
# 47 - bkc232__tu
# 48 - bkc233__tu
# 49 - bkc234__tu
# 50 - bkc235__tu
# 51 - bkc252__tu
# 52 - bkc253__tu
# 53 - bkc254__tu
# 54 - bkc255__tu
# 55 - bkc201__tu
# 56 - bkc202__tu
# 57 - bkc203__tu
# 58 - bkc204__tu
# 59 - bkc205__tu
# 60 - bkc222__tu
# 61 - bkc223__tu
# 62 - bkc224__tu
# 63 - bkc225__tu
# 64 - bigaccountid
# 65 - bigdebtorid
# 66 - fltadvance__app
# 67 - pti__app
# 68 - bigmileage_odometer__app
# 69 - vehiclemake__app
# 70 - vehiclemodel__app
# 71 - bitnew__app
# 72 - fltpriceselling__app
# 73 - vehiclepricewholesale__app
# 74 - fltstatesalestax__app
# 75 - vehicleyear__app
# 76 - permid__tu
# 77 - partyid__tu
# 78 - acctid__tu
# 79 - tuseqeuncenumber__tu
# 80 - bankcard_reason5__ln
# 81 - alert4__ln
# 82 - alert5__ln
# 83 - alert6__ln
# 84 - alert7__ln
# 85 - alert8__ln
# 86 - alert9__ln
# 87 - alert10__ln
#
# There are 15 features in the train df that have no variance
# 1 - fltaddfee__app
# 2 - fltinsureddisabilitypremium__app
# 3 - fltinsuredlifepremium__app
# 4 - fltinsuredunemploymentamount__app
# 5 - fltinsuredunemploymentpremium__app
# 6 - inputprovidedfirstname__ln
# 7 - inputprovidedlastname__ln
# 8 - inputprovidedlexid__ln
# 9 - auto_reason5__ln
# 10 - short_term_lending_reason5__ln
# 11 - telecommunications_reason5__ln
# 12 - crossindustry_index__ln
# 13 - crossindustry_score_name__ln
# 14 - crossindustry_reason5__ln
# 15 - alert3__ln
#  33%|███▎      | 1/3 [01:17<02:34, 77.08s/it]
# There are 253 features in the train df that are redundant
# 1 - dtmapproved__base
# 2 - dtmdeclined__base
# 3 - dtmfunded__base
# 4 - observationdate__base
# 5 - analyticsmatchkey__base
# 6 - booked__base
# 7 - curr_bal_amt__base
# 8 - vtg4__base
# 9 - firstname__tu
# 10 - middlename__tu
# 11 - lastname__tu
# 12 - address1__tu
# 13 - zip5__tu
# 14 - zip4__tu
# 15 - ssn__tu
# 16 - dateofbirth__tu
# 17 - dtmstampcreation__tu
# 18 - observationdate__tu
# 19 - analyticsmatchkey__tu
# 20 - segment__tu
# 21 - indflag__tu
# 22 - iscrhit__tu
# 23 - bctrd__tu
# 24 - insttrd__tu
# 25 - nomttrd__tu
# 26 - revtrd__tu
# 27 - rtltrd__tu
# 28 - bkc231__tu
# 29 - bkc232__tu
# 30 - bkc233__tu
# 31 - bkc234__tu
# 32 - bkc235__tu
# 33 - bkc252__tu
# 34 - bkc253__tu
# 35 - bkc254__tu
# 36 - bkc255__tu
# 37 - bkc201__tu
# 38 - bkc202__tu
# 39 - bkc203__tu
# 40 - bkc204__tu
# 41 - bkc205__tu
# 42 - bkc222__tu
# 43 - bkc223__tu
# 44 - bkc224__tu
# 45 - bkc225__tu
# 46 - bigaccountid
# 47 - bigdebtorid
# 48 - fltadvance__app
# 49 - pti__app
# 50 - bigmileage_odometer__app
# 51 - bitnew__app
# 52 - fltpriceselling__app
# 53 - vehiclepricewholesale__app
# 54 - fltstatesalestax__app
# 55 - vehicleyear__app
# 56 - partyid__tu
# 57 - acctid__tu
# 58 - tuseqeuncenumber__tu
# 59 - bankcard_reason5__ln
# 60 - alert4__ln
# 61 - alert5__ln
# 62 - alert6__ln
# 63 - alert7__ln
# 64 - alert8__ln
# 65 - alert9__ln
# 66 - alert10__ln
# 67 - acct_typ_cde__base
# 68 - open_dte__base
# 69 - terms_freq_cde__base
# 70 - affil_rem_cde__base
# 71 - cmplnc_rem_cde__base
# 72 - gnrc_rem_cde__base
# 73 - rte_rem_cde__base
# 74 - acct_rte_prfl_cde__base
# 75 - payt_pttrn_txt__base
# 76 - gnrcrem_frsrpt_dte__base
# 77 - obs_arch__base
# 78 - performance__base
# 79 - creditasofdate__tu
# 80 - strname__tu
# 81 - state__tu
# 82 - vehiclemake__app
# 83 - vehiclemodel__app
# 84 - permid__tu
# 85 - fltinsuredlifepremium__app
# 86 - fltinsuredunemploymentamount__app
# 87 - fltinsuredunemploymentpremium__app
# 88 - at900c__tu
# 89 - at999s__tu
# 90 - at999b__tu
# 91 - at920b__tu
# 92 - at920d__tu
# 93 - at920e__tu
# 94 - at920s__tu
# 95 - at934b__tu
# 96 - at934d__tu
# 97 - at934e__tu
# 98 - at934s__tu
# 99 - at935b__tu
# 100 - at935d__tu
# 101 - at935e__tu
# 102 - at935s__tu
# 103 - cc102s__tu
# 104 - cc103s__tu
# 105 - cc104s__tu
# 106 - cc105s__tu
# 107 - au900c__tu
# 108 - au999s__tu
# 109 - au999b__tu
# 110 - au920b__tu
# 111 - au920c__tu
# 112 - au920d__tu
# 113 - au920s__tu
# 114 - au934b__tu
# 115 - au934c__tu
# 116 - au934d__tu
# 117 - au934s__tu
# 118 - au935b__tu
# 119 - au935c__tu
# 120 - au935d__tu
# 121 - au935s__tu
# 122 - bc900c__tu
# 123 - bc999s__tu
# 124 - bc999b__tu
# 125 - bc920b__tu
# 126 - bc920c__tu
# 127 - bc920d__tu
# 128 - bc920s__tu
# 129 - bc934b__tu
# 130 - bc934c__tu
# 131 - bc934d__tu
# 132 - bc934s__tu
# 133 - bc935b__tu
# 134 - bc935c__tu
# 135 - bc935d__tu
# 136 - bc935s__tu
# 137 - rl900c__tu
# 138 - rl999s__tu
# 139 - rl999b__tu
# 140 - rl920b__tu
# 141 - rl920c__tu
# 142 - rl920d__tu
# 143 - rl920s__tu
# 144 - rl934b__tu
# 145 - rl934c__tu
# 146 - rl934d__tu
# 147 - rl934s__tu
# 148 - rl935b__tu
# 149 - rl935c__tu
# 150 - rl935d__tu
# 151 - rl935s__tu
# 152 - rl921c__tu
# 153 - us900c__tu
# 154 - us999s__tu
# 155 - us999b__tu
# 156 - us920b__tu
# 157 - us920c__tu
# 158 - us920d__tu
# 159 - us920s__tu
# 160 - us934b__tu
# 161 - us934c__tu
# 162 - us934d__tu
# 163 - us934s__tu
# 164 - us935b__tu
# 165 - us935c__tu
# 166 - us935d__tu
# 167 - us935s__tu
# 168 - au933b__tu
# 169 - au933c__tu
# 170 - bc933c__tu
# 171 - he900c__tu
# 172 - he999s__tu
# 173 - he999b__tu
# 174 - he920b__tu
# 175 - he920c__tu
# 176 - he920d__tu
# 177 - he920s__tu
# 178 - he934b__tu
# 179 - he934c__tu
# 180 - he934d__tu
# 181 - he934s__tu
# 182 - he935b__tu
# 183 - he935c__tu
# 184 - he935d__tu
# 185 - he935s__tu
# 186 - he933b__tu
# 187 - he933c__tu
# 188 - mt900c__tu
# 189 - mt999s__tu
# 190 - mt999b__tu
# 191 - mt920b__tu
# 192 - mt920c__tu
# 193 - mt920d__tu
# 194 - mt920s__tu
# 195 - mt934b__tu
# 196 - mt934c__tu
# 197 - mt934d__tu
# 198 - mt934s__tu
# 199 - mt935b__tu
# 200 - mt935c__tu
# 201 - mt935d__tu
# 202 - mt935s__tu
# 203 - mt933c__tu
# 204 - rt900c__tu
# 205 - rt999s__tu
# 206 - rt999b__tu
# 207 - rt920b__tu
# 208 - rt920c__tu
# 209 - rt920d__tu
# 210 - rt920s__tu
# 211 - rt934b__tu
# 212 - rt934c__tu
# 213 - rt934d__tu
# 214 - rt934s__tu
# 215 - rt935b__tu
# 216 - rt935c__tu
# 217 - rt935d__tu
# 218 - rt935s__tu
# 219 - rt933b__tu
# 220 - rt933c__tu
# 221 - us933b__tu
# 222 - us933c__tu
# 223 - at934c__tu
# 224 - at934f__tu
# 225 - at935c__tu
# 226 - at935f__tu
# 227 - at999c__tu
# 228 - at922d__tu
# 229 - at922e__tu
# 230 - at922s__tu
# 231 - at922f__tu
# 232 - au922c__tu
# 233 - au922d__tu
# 234 - au922s__tu
# 235 - bc922c__tu
# 236 - bc922d__tu
# 237 - bc922s__tu
# 238 - cc101s__tu
# 239 - he922c__tu
# 240 - he922d__tu
# 241 - he922s__tu
# 242 - mt922c__tu
# 243 - mt922d__tu
# 244 - mt922s__tu
# 245 - rl922c__tu
# 246 - rl922d__tu
# 247 - rl922s__tu
# 248 - rt922c__tu
# 249 - rt922d__tu
# 250 - rt922s__tu
# 251 - us922c__tu
# 252 - us922d__tu
# 253 - us922s__tu
#
# Data set: valid
#
# There are 91 features in the valid df that are 100% NaN
# 1 - firstname__tu
# 2 - middlename__tu
# 3 - lastname__tu
# 4 - address1__tu
# 5 - city__tu
# 6 - zip4__tu
# 7 - ssn__tu
# 8 - dateofbirth__tu
# 9 - bkc231__tu
# 10 - bkc232__tu
# 11 - bkc233__tu
# 12 - bkc234__tu
# 13 - bkc235__tu
# 14 - bkc252__tu
# 15 - bkc253__tu
# 16 - bkc254__tu
# 17 - bkc255__tu
# 18 - bkc201__tu
# 19 - bkc202__tu
# 20 - bkc203__tu
# 21 - bkc204__tu
# 22 - bkc205__tu
# 23 - bkc222__tu
# 24 - bkc223__tu
# 25 - bkc224__tu
# 26 - bkc225__tu
# 27 - partyid__tu
# 28 - acctid__tu
# 29 - analyticsmatchkey__ln
# 30 - auto_score__ln
# 31 - auto_reason1__ln
# 32 - auto_reason2__ln
# 33 - auto_reason3__ln
# 34 - auto_reason4__ln
# 35 - auto_reason5__ln
# 36 - bankcard_score__ln
# 37 - bankcard_reason1__ln
# 38 - bankcard_reason2__ln
# 39 - bankcard_reason3__ln
# 40 - bankcard_reason4__ln
# 41 - bankcard_reason5__ln
# 42 - short_term_lending_score__ln
# 43 - short_term_lending_reason1__ln
# 44 - short_term_lending_reason2__ln
# 45 - short_term_lending_reason3__ln
# 46 - short_term_lending_reason4__ln
# 47 - short_term_lending_reason5__ln
# 48 - telecommunications_score__ln
# 49 - telecommunications_reason1__ln
# 50 - telecommunications_reason2__ln
# 51 - telecommunications_reason3__ln
# 52 - telecommunications_reason4__ln
# 53 - telecommunications_reason5__ln
# 54 - crossindustry_index__ln
# 55 - crossindustry_score_name__ln
# 56 - crossindustry_score__ln
# 57 - crossindustry_reason1__ln
# 58 - crossindustry_reason2__ln
# 59 - crossindustry_reason3__ln
# 60 - crossindustry_reason4__ln
# 61 - crossindustry_reason5__ln
# 62 - alert1__ln
# 63 - alert2__ln
# 64 - alert3__ln
# 65 - alert4__ln
# 66 - alert5__ln
# 67 - alert6__ln
# 68 - alert7__ln
# 69 - alert8__ln
# 70 - alert9__ln
# 71 - alert10__ln
# 72 - scr_linka2__tu
# 73 - scr_alta2__tu
# 74 - scr_linkb2__tu
# 75 - scr_altb2__tu
# 76 - DPD60PLUS__tucvlink
# 77 - zip_code__tu
# 78 - cvau__tu
# 79 - cvam__tu
# 80 - cvbk__tu
# 81 - cvna__tu
# 82 - cvpl__tu
# 83 - cv_bc_prop__tu
# 84 - cv_cons_prop__tu
# 85 - cv_persloan_prop__tu
# 86 - syntheticfraud_score__tu
# 87 - vantagescore3__tu
# 88 - vantagescore4__tu
# 89 - cv_bc_behav_seg__tu
# 90 - archive__tu
# 91 - tu_creditbureaudate__tu
#
# There are 17 features in the valid df that have no variance
# 1 - acct_typ_cde__base
# 2 - bitsystemdecline__app
# 3 - fltaddfee__app
# 4 - fltinsureddisabilitypremium__app
# 5 - fltinsuredlifepremium__app
# 6 - fltinsuredunemploymentamount__app
# 7 - fltinsuredunemploymentpremium__app
# 8 - fltpriceselling__app
# 9 - fltstatesalestax__app
# 10 - inputprovidedfirstname__ln
# 11 - inputprovidedlastname__ln
# 12 - inputprovidedssn__ln
# 13 - inputprovideddateofbirth__ln
# 14 - inputprovidedlexid__ln
# 15 - purchaseactivitycount__ln
# 16 - purchaseactivitydollartotal__ln
# 17 - linkc010__tu
#  67%|██████▋   | 2/3 [01:58<00:56, 56.37s/it]
# There are 257 features in the valid df that are redundant
# 1 - lastname__tu
# 2 - address1__tu
# 3 - zip4__tu
# 4 - ssn__tu
# 5 - dateofbirth__tu
# 6 - bkc231__tu
# 7 - bkc232__tu
# 8 - bkc233__tu
# 9 - bkc234__tu
# 10 - bkc235__tu
# 11 - bkc252__tu
# 12 - bkc253__tu
# 13 - bkc254__tu
# 14 - bkc255__tu
# 15 - bkc201__tu
# 16 - bkc202__tu
# 17 - bkc203__tu
# 18 - bkc204__tu
# 19 - bkc205__tu
# 20 - bkc222__tu
# 21 - bkc223__tu
# 22 - bkc224__tu
# 23 - bkc225__tu
# 24 - partyid__tu
# 25 - acctid__tu
# 26 - analyticsmatchkey__ln
# 27 - auto_score__ln
# 28 - bankcard_score__ln
# 29 - bankcard_reason5__ln
# 30 - short_term_lending_score__ln
# 31 - telecommunications_score__ln
# 32 - crossindustry_index__ln
# 33 - crossindustry_score__ln
# 34 - alert4__ln
# 35 - alert5__ln
# 36 - alert6__ln
# 37 - alert7__ln
# 38 - alert8__ln
# 39 - alert9__ln
# 40 - alert10__ln
# 41 - scr_linka2__tu
# 42 - scr_alta2__tu
# 43 - scr_linkb2__tu
# 44 - scr_altb2__tu
# 45 - DPD60PLUS__tucvlink
# 46 - zip_code__tu
# 47 - cvau__tu
# 48 - cvam__tu
# 49 - cvbk__tu
# 50 - cvna__tu
# 51 - cvpl__tu
# 52 - cv_bc_prop__tu
# 53 - cv_cons_prop__tu
# 54 - cv_persloan_prop__tu
# 55 - syntheticfraud_score__tu
# 56 - vantagescore3__tu
# 57 - vantagescore4__tu
# 58 - cv_bc_behav_seg__tu
# 59 - archive__tu
# 60 - auto_reason1__ln
# 61 - auto_reason2__ln
# 62 - auto_reason3__ln
# 63 - auto_reason4__ln
# 64 - auto_reason5__ln
# 65 - bankcard_reason1__ln
# 66 - bankcard_reason2__ln
# 67 - bankcard_reason3__ln
# 68 - bankcard_reason4__ln
# 69 - short_term_lending_reason1__ln
# 70 - short_term_lending_reason2__ln
# 71 - short_term_lending_reason3__ln
# 72 - short_term_lending_reason4__ln
# 73 - short_term_lending_reason5__ln
# 74 - telecommunications_reason1__ln
# 75 - telecommunications_reason2__ln
# 76 - telecommunications_reason3__ln
# 77 - telecommunications_reason4__ln
# 78 - telecommunications_reason5__ln
# 79 - crossindustry_score_name__ln
# 80 - crossindustry_reason1__ln
# 81 - crossindustry_reason2__ln
# 82 - crossindustry_reason3__ln
# 83 - crossindustry_reason4__ln
# 84 - crossindustry_reason5__ln
# 85 - alert1__ln
# 86 - alert2__ln
# 87 - alert3__ln
# 88 - tu_creditbureaudate__tu
# 89 - fltinsuredlifepremium__app
# 90 - fltinsuredunemploymentamount__app
# 91 - fltinsuredunemploymentpremium__app
# 92 - inputprovidedstate__ln
# 93 - inputprovidedzipcode__ln
# 94 - at900c__tu
# 95 - at999s__tu
# 96 - at999b__tu
# 97 - at920b__tu
# 98 - at920d__tu
# 99 - at920e__tu
# 100 - at920s__tu
# 101 - at934b__tu
# 102 - at934d__tu
# 103 - at934e__tu
# 104 - at934s__tu
# 105 - at935b__tu
# 106 - at935d__tu
# 107 - at935e__tu
# 108 - at935s__tu
# 109 - cc102s__tu
# 110 - cc103s__tu
# 111 - cc104s__tu
# 112 - cc105s__tu
# 113 - au900c__tu
# 114 - au999s__tu
# 115 - au999b__tu
# 116 - au920b__tu
# 117 - au920c__tu
# 118 - au920d__tu
# 119 - au920s__tu
# 120 - au934b__tu
# 121 - au934c__tu
# 122 - au934d__tu
# 123 - au934s__tu
# 124 - au935b__tu
# 125 - au935c__tu
# 126 - au935d__tu
# 127 - au935s__tu
# 128 - bc900c__tu
# 129 - bc999s__tu
# 130 - bc999b__tu
# 131 - bc920b__tu
# 132 - bc920c__tu
# 133 - bc920d__tu
# 134 - bc920s__tu
# 135 - bc934b__tu
# 136 - bc934c__tu
# 137 - bc934d__tu
# 138 - bc934s__tu
# 139 - bc935b__tu
# 140 - bc935c__tu
# 141 - bc935d__tu
# 142 - bc935s__tu
# 143 - rl900c__tu
# 144 - rl999s__tu
# 145 - rl999b__tu
# 146 - rl920b__tu
# 147 - rl920c__tu
# 148 - rl920d__tu
# 16 - bkc254__tu
# 17 - bkc255__tu
# 18 - bkc201__tu
# 19 - bkc202__tu
# 20 - bkc203__tu
# 21 - bkc204__tu
# 22 - bkc205__tu
# 23 - bkc222__tu
# 24 - bkc223__tu
# 25 - bkc224__tu
# 26 - bkc225__tu
# 27 - partyid__tu
# 28 - acctid__tu
# 29 - bigaccountid__app
# 30 - bigdebtorid__app
# 31 - fltgrossmonthly__income_min
# 32 - fltgrossmonthly__income_max
# 33 - fltgrossmonthly__income_median
# 34 - fltgrossmonthly__income_mean
# 35 - fltgrossmonthly__income_std
# 36 - bigaccountid__ln
# 37 - bigdebtorid__ln
# 38 - analyticsmatchkey__ln
# 39 - auto_score__ln
# 40 - auto_reason1__ln
# 41 - auto_reason2__ln
# 42 - auto_reason3__ln
# 43 - auto_reason4__ln
# 44 - auto_reason5__ln
# 45 - bankcard_score__ln
# 46 - bankcard_reason1__ln
# 47 - bankcard_reason2__ln
# 48 - bankcard_reason3__ln
# 49 - bankcard_reason4__ln
# 50 - bankcard_reason5__ln
# 51 - short_term_lending_score__ln
# 52 - short_term_lending_reason1__ln
# 53 - short_term_lending_reason2__ln
# 54 - short_term_lending_reason3__ln
# 55 - short_term_lending_reason4__ln
# 56 - short_term_lending_reason5__ln
# 57 - telecommunications_score__ln
# 58 - telecommunications_reason1__ln
# 59 - telecommunications_reason2__ln
# 60 - telecommunications_reason3__ln
# 61 - telecommunications_reason4__ln
# 62 - telecommunications_reason5__ln
# 63 - crossindustry_index__ln
# 64 - crossindustry_score_name__ln
# 65 - crossindustry_score__ln
# 66 - crossindustry_reason1__ln
# 67 - crossindustry_reason2__ln
# 68 - crossindustry_reason3__ln
# 69 - crossindustry_reason4__ln
# 70 - crossindustry_reason5__ln
# 71 - alert1__ln
# 72 - alert2__ln
# 73 - alert3__ln
# 74 - alert4__ln
# 75 - alert5__ln
# 76 - alert6__ln
# 77 - alert7__ln
# 78 - alert8__ln
# 79 - alert9__ln
# 80 - alert10__ln
# 81 - linkc006__tu
# 82 - linkc020__tu
# 83 - linkc007__tu
# 84 - linkc048__tu
# 85 - linkc025__tu
# 86 - linkc026__tu
# 87 - linkc027__tu
# 88 - linkc028__tu
# 89 - linkc029__tu
# 90 - linkc024__tu
# 91 - linkc031__tu
# 92 - linkc032__tu
# 93 - linkc033__tu
# 94 - linkc034__tu
# 95 - linkc035__tu
# 96 - linkc030__tu
# 97 - linkc038__tu
# 98 - linkc039__tu
# 99 - linkc040__tu
# 100 - linkc041__tu
# 101 - linkc042__tu
# 102 - linkc037__tu
# 103 - linkc036__tu
# 104 - linkc008__tu
# 105 - linkc009__tu
# 106 - linkc050__tu
# 107 - linkc012__tu
# 108 - linkc011__tu
# 109 - linkc010__tu
# 110 - linkc043__tu
# 111 - linkc044__tu
# 112 - linkc045__tu
# 113 - linkc046__tu
# 114 - linkc047__tu
# 115 - linkc049__tu
# 116 - linkc005__tu
# 117 - linkc004__tu
# 118 - linkc051__tu
# 119 - scr_linka2__tu
# 120 - scr_alta2__tu
# 121 - scr_linkb2__tu
# 122 - scr_altb2__tu
# 123 - cvlst_s1__tu
# 368 - rt934s__tu
# 369 - rt935b__tu
# 370 - rt935c__tu
# 371 - rt935d__tu
# 372 - rt935s__tu
# 373 - us920b__tu
# 374 - us920c__tu
# 375 - us920d__tu
# 376 - us920s__tu
# 377 - us922b__tu
# 378 - us922c__tu
# 379 - us922d__tu
# 380 - us922s__tu
# 381 - us934b__tu
# 382 - us934c__tu
# 383 - us934d__tu
# 384 - us934s__tu
# 385 - us935b__tu
# 386 - us935c__tu
# 387 - us935d__tu
# 388 - us935s__tu
# 389 - score_bankcard__tu
# 390 - score_cvpropensity__tu
# 391 - finscore__tu
# 392 - intscore__ln
# There are 15 features in the test df that have no variance
# 1 - acct_typ_cde__base
# 2 - bitsystemdecline__app
# 3 - fltaddfee__app
# 4 - fltinsureddisabilitypremium__app
# 5 - fltinsuredlifepremium__app
# 6 - fltinsuredunemploymentamount__app
# 7 - fltinsuredunemploymentpremium__app
# 8 - fltpriceselling__app
# 9 - fltstatesalestax__app
# 10 - inputprovidedfirstname__ln
# 11 - inputprovidedlastname__ln
# 12 - inputprovideddateofbirth__ln
# 13 - inputprovidedlexid__ln
# 14 - purchaseactivitycount__ln
# 15 - purchaseactivitydollartotal__ln
# 100%|██████████| 3/3 [02:38<00:00, 52.81s/it]
# There are 394 features in the test df that are redundant
# 1 - lastname__tu
# 2 - address1__tu
# 3 - zip4__tu
# 4 - ssn__tu
# 5 - dateofbirth__tu
# 6 - bkc231__tu
# 7 - bkc232__tu
# 8 - bkc233__tu
# 9 - bkc234__tu
# 10 - bkc235__tu
# 11 - bkc252__tu
# 12 - bkc253__tu
# 13 - bkc254__tu
# 14 - bkc255__tu
# 15 - bkc201__tu
# 16 - bkc202__tu
# 17 - bkc203__tu
# 18 - bkc204__tu
# 19 - bkc205__tu
# 20 - bkc222__tu
# 21 - bkc223__tu
# 22 - bkc224__tu
# 23 - bkc225__tu
# 24 - partyid__tu
# 25 - acctid__tu
# 26 - bigaccountid__app
# 27 - bigdebtorid__app
# 28 - fltgrossmonthly__income_min
# 29 - fltgrossmonthly__income_max
# 30 - fltgrossmonthly__income_median
# 31 - fltgrossmonthly__income_mean
# 32 - fltgrossmonthly__income_std
# 33 - bigaccountid__ln
# 34 - bigdebtorid__ln
# 35 - analyticsmatchkey__ln
# 36 - auto_score__ln
# 37 - bankcard_score__ln
# 38 - bankcard_reason5__ln
# 39 - short_term_lending_score__ln
# 40 - telecommunications_score__ln
# 41 - crossindustry_index__ln
# 42 - crossindustry_score__ln
# 43 - alert4__ln
# 44 - alert5__ln
# 45 - alert6__ln
# 46 - alert7__ln
# 47 - alert8__ln
# 48 - alert9__ln
# 49 - alert10__ln
# 50 - linkc006__tu
# 51 - linkc020__tu
# 52 - linkc007__tu
# 53 - linkc048__tu
# 54 - linkc025__tu
# 55 - linkc026__tu
# 56 - linkc027__tu
# 57 - linkc028__tu
# 58 - linkc029__tu
# 59 - linkc024__tu
# 60 - linkc031__tu
# 61 - linkc032__tu
# 62 - linkc033__tu
# 63 - linkc034__tu
# 64 - linkc035__tu
# 65 - linkc030__tu
# 66 - linkc038__tu
# 67 - linkc039__tu
# 68 - linkc040__tu
# 69 - linkc041__tu
# 70 - linkc042__tu
# 71 - linkc037__tu
# 72 - linkc036__tu
# 73 - linkc008__tu
# 74 - linkc009__tu
# 75 - linkc050__tu
# 76 - linkc012__tu
# 77 - linkc011__tu
# 78 - linkc010__tu
# 79 - linkc043__tu
# 80 - linkc044__tu
# 81 - linkc045__tu
# 82 - linkc046__tu
# 83 - linkc047__tu
# 84 - linkc049__tu
# 85 - linkc005__tu
# 86 - linkc004__tu
# 87 - linkc051__tu
# 88 - scr_linka2__tu
# 89 - scr_alta2__tu
# 90 - scr_linkb2__tu
# 91 - scr_altb2__tu
# 92 - cvlst_s1__tu
# 93 - cvlst_i1__tu
# 94 - eadms1__tu
# 95 - DPD60PLUS__tucvlink
# 96 - zip_code__tu
# 97 - cvau__tu
# 98 - cvam__tu
# 99 - cvbk__tu
# 100 - cvna__tu
# 101 - cvpl__tu
# 102 - cv_bc_prop__tu
# 103 - cv_cons_prop__tu
# 104 - cv_persloan_prop__tu
# 105 - syntheticfraud_score__tu
# 106 - vantagescore3__tu
# 107 - vantagescore4__tu
# 108 - bc_trd__tu
# 109 - inst_trd__tu
# 110 - nomt_trd__tu
# 111 - rev_trd__tu
# 112 - rtl_trd__tu
# 113 - cv_bc_behav_seg__tu
# 114 - archive__tu
# 115 - linkchit__tu
# 116 - scr_alt_a_2__tu
# 117 - scr_link_a_2__tu
# 118 - scr_alt_b_2__tu
# 119 - scr_link_b_2__tu
# 120 - score_cvauto__tu
# 121 - score_newaccount__tu
# 122 - score_epd__tu
# 123 - at900s__tu
# 124 - at900b__tu
# 125 - at900c__tu
# 126 - at921s__tu
# 127 - at921b__tu
# 128 - at921c__tu
# 129 - at933s__tu
# 130 - at933b__tu
# 131 - at933c__tu
# 132 - au900s__tu
# 133 - au900b__tu
# 134 - au900c__tu
# 135 - bc900s__tu
# 136 - bc900b__tu
# 137 - bc900c__tu
# 138 - bc999s__tu
# 139 - rl900s__tu
# 140 - rl900b__tu
# 141 - rl900c__tu
# 142 - rl933s__tu
# 143 - rl933b__tu
# 144 - rl933c__tu
# 145 - us900s__tu
# 146 - us900b__tu
# 147 - us900c__tu
# 148 - at999s__tu
# 149 - at999b__tu
# 150 - au921s__tu
# 151 - au921b__tu
# 152 - au921c__tu
# 153 - au933s__tu
# 154 - au933b__tu
# 155 - au933c__tu
# 156 - au999s__tu
# 157 - au999b__tu
# 158 - bc921s__tu
# 159 - bc921b__tu
# 160 - bc921c__tu
# 161 - bc933s__tu
# 162 - bc933b__tu
# 163 - bc933c__tu
# 164 - bc999b__tu
# 165 - he900s__tu
# 166 - he900b__tu
# 167 - he900c__tu
# 168 - he921s__tu
# 169 - he921b__tu
# 170 - he921c__tu
# 171 - he933s__tu
# 172 - he933b__tu
# 173 - he933c__tu
# 174 - he999s__tu
# 175 - he999b__tu
# 176 - mt900s__tu
# 177 - mt900b__tu
# 178 - mt900c__tu
# 179 - mt921s__tu
# 180 - mt921b__tu
# 181 - mt921c__tu
# 182 - mt933s__tu
# 183 - mt933b__tu
# 184 - mt933c__tu
# 185 - mt999s__tu
# 312 - rl922c__tu
# 313 - rl922d__tu
# 314 - rl922s__tu
# 315 - rl934b__tu
# 316 - rl934c__tu
# 317 - rl934d__tu
# 318 - rl934s__tu
# 319 - rl935b__tu
# 320 - rl935c__tu
# 321 - rl935d__tu
# 322 - rl935s__tu
# 323 - rt920b__tu
# 324 - rt920c__tu
# 325 - rt920d__tu
# 326 - rt920s__tu
# 327 - rt922b__tu
# 328 - rt922c__tu
# 329 - rt922d__tu
# 330 - rt922s__tu
# 331 - rt934b__tu
# 332 - rt934c__tu
# 333 - rt934d__tu
# 334 - rt934s__tu
# 335 - rt935b__tu
# 336 - rt935c__tu
# 337 - rt935d__tu
# 338 - rt935s__tu
# 339 - us920b__tu
# 340 - us920c__tu
# 341 - us920d__tu
# 342 - us920s__tu
# 343 - us922b__tu
# 344 - us922c__tu
# 345 - us922d__tu
# 346 - us922s__tu
# 347 - us934b__tu
# 348 - us934c__tu
# 349 - us934d__tu
# 350 - us934s__tu
# 351 - us935b__tu
# 352 - us935c__tu
# 353 - us935d__tu
# 354 - us935s__tu
# 355 - score_bankcard__tu
# 356 - score_cvpropensity__tu
# 357 - finscore__tu
# 358 - intscore__ln
# 359 - auto_reason1__ln
# 360 - auto_reason2__ln
# 361 - auto_reason3__ln
# 362 - auto_reason4__ln
# 363 - auto_reason5__ln
# 364 - bankcard_reason1__ln
# 365 - bankcard_reason2__ln
# 366 - bankcard_reason3__ln
# 367 - bankcard_reason4__ln
# 368 - short_term_lending_reason1__ln
# 369 - short_term_lending_reason2__ln
# 370 - short_term_lending_reason3__ln
# 371 - short_term_lending_reason4__ln
# 372 - short_term_lending_reason5__ln
# 373 - telecommunications_reason1__ln
# 374 - telecommunications_reason2__ln
# 375 - telecommunications_reason3__ln
# 376 - telecommunications_reason4__ln
# 377 - telecommunications_reason5__ln
# 378 - crossindustry_score_name__ln
# 379 - crossindustry_reason1__ln
# 380 - crossindustry_reason2__ln
# 381 - crossindustry_reason3__ln
# 382 - crossindustry_reason4__ln
# 383 - crossindustry_reason5__ln
# 384 - alert1__ln
# 385 - alert2__ln
# 386 - alert3__ln
# 387 - credit_as_of_date__tu
# 388 - tu_creditbureaudate__tu
# 389 - zipcodefiller__tu
# 390 - fltinsuredlifepremium__app
# 391 - fltinsuredunemploymentamount__app
# 392 - fltinsuredunemploymentpremium__app
# 393 - inputprovidedstate__ln
# 394 - inputprovidedzipcode__ln
#
# CPU times: user 4min 38s, sys: 5min 2s, total: 9min 40s
# Wall time: 2min 38s

# %% [markdown]
# ### Remove duplicates

# %%
print(f'Before removing duplicates, there were {len(list_cols_all)} features to remove')
print('')

# rm dups
list_cols_all = list(dict.fromkeys(list_cols_all))
print(f'After removing duplicates, there are {len(list_cols_all)} features to remove')
for a, col in enumerate(list_cols_all):
    print(f'{a+1} - {col}')
# Out:
# Before removing duplicates, there were 1521 features to remove
#
# After removing duplicates, there are 459 features to remove
# 1 - bitdebtor__base
# 2 - dtmstampcreation__base
# 3 - dtmapproved__base
# 4 - dtmdeclined__base
# 5 - dtmfunded__base
# 6 - observationdate__base
# 7 - analyticsmatchkey__base
# 8 - decision_dte__base
# 9 - booked__base
# 10 - acct_typ_cde__base
# 11 - open_dte__base
# 12 - curr_bal_amt__base
# 13 - terms_freq_cde__base
# 14 - affil_rem_cde__base
# 15 - cmplnc_rem_cde__base
# 16 - gnrc_rem_cde__base
# 17 - rte_rem_cde__base
# 18 - acct_rte_prfl_cde__base
# 19 - payt_pttrn_txt__base
# 20 - gnrcrem_frsrpt_dte__base
# 21 - obs_arch__base
# 22 - vtg4__base
# 23 - performance__base
# 24 - creditasofdate__tu
# 25 - firstname__tu
# 26 - middlename__tu
# 27 - lastname__tu
# 28 - address1__tu
# 29 - strname__tu
# 30 - state__tu
# 31 - zip5__tu
# 32 - zip4__tu
# 33 - ssn__tu
# 34 - dateofbirth__tu
# 35 - dtmstampcreation__tu
# 36 - observationdate__tu
# 37 - analyticsmatchkey__tu
# 38 - segment__tu
# 39 - indflag__tu
# 40 - iscrhit__tu
# 41 - bctrd__tu
# 42 - insttrd__tu
# 43 - nomttrd__tu
# 44 - revtrd__tu
# 45 - rtltrd__tu
# 46 - bkc231__tu
# 47 - bkc232__tu
# 48 - bkc233__tu
# 49 - bkc234__tu
# 50 - bkc235__tu
# 51 - bkc252__tu
# 52 - bkc253__tu
# 53 - bkc254__tu
# 54 - bkc255__tu
# 55 - bkc201__tu
# 56 - bkc202__tu
# 57 - bkc203__tu
# 58 - bkc204__tu
# 59 - bkc205__tu
# 60 - bkc222__tu
# 61 - bkc223__tu
# 62 - bkc224__tu
# 63 - bkc225__tu
# 64 - bigaccountid
# 65 - bigdebtorid
# 66 - fltadvance__app
# 67 - pti__app
# 68 - bigmileage_odometer__app
# 69 - vehiclemake__app
# 70 - vehiclemodel__app
# 71 - bitnew__app
# 72 - fltpriceselling__app
# 73 - vehiclepricewholesale__app
# 74 - fltstatesalestax__app
# 75 - vehicleyear__app
# 76 - permid__tu
# 77 - partyid__tu
# 78 - acctid__tu
# 79 - tuseqeuncenumber__tu
# 80 - bankcard_reason5__ln
# 81 - alert4__ln
# 82 - alert5__ln
# 83 - alert6__ln
# 84 - alert7__ln
# 85 - alert8__ln
# 86 - alert9__ln
# 87 - alert10__ln
# 88 - fltaddfee__app
# 89 - fltinsureddisabilitypremium__app
# 90 - fltinsuredlifepremium__app
# 91 - fltinsuredunemploymentamount__app
# 92 - fltinsuredunemploymentpremium__app
# 93 - inputprovidedfirstname__ln
# 94 - inputprovidedlastname__ln
# 95 - inputprovidedlexid__ln
# 96 - auto_reason5__ln
# 97 - short_term_lending_reason5__ln
# 98 - telecommunications_reason5__ln
# 99 - crossindustry_index__ln
# 100 - crossindustry_score_name__ln
# 101 - crossindustry_reason5__ln
# 102 - alert3__ln
# 103 - at900c__tu
# 104 - at999s__tu
# 105 - at999b__tu
# 106 - at920b__tu
# 107 - at920d__tu
# 108 - at920e__tu
# 109 - at920s__tu
# 110 - at934b__tu
# 111 - at934d__tu
# 112 - at934e__tu
# 113 - at934s__tu
# 114 - at935b__tu
# 115 - at935d__tu
# 116 - at935e__tu
# 117 - at935s__tu
# 118 - cc102s__tu
# 119 - cc103s__tu
# 120 - cc104s__tu
# 247 - au922c__tu
# 248 - au922d__tu
# 249 - au922s__tu
# 250 - bc922c__tu
# 251 - bc922d__tu
# 252 - bc922s__tu
# 253 - cc101s__tu
# 254 - he922c__tu
# 255 - he922d__tu
# 256 - he922s__tu
# 257 - mt922c__tu
# 258 - mt922d__tu
# 259 - mt922s__tu
# 260 - rl922c__tu
# 261 - rl922d__tu
# 262 - rl922s__tu
# 263 - rt922c__tu
# 264 - rt922d__tu
# 265 - rt922s__tu
# 266 - us922c__tu
# 267 - us922d__tu
# 268 - us922s__tu
# 269 - city__tu
# 270 - analyticsmatchkey__ln
# 271 - auto_score__ln
# 272 - auto_reason1__ln
# 273 - auto_reason2__ln
# 274 - auto_reason3__ln
# 275 - auto_reason4__ln
# 276 - bankcard_score__ln
# 277 - bankcard_reason1__ln
# 278 - bankcard_reason2__ln
# 279 - bankcard_reason3__ln
# 280 - bankcard_reason4__ln
# 281 - short_term_lending_score__ln
# 282 - short_term_lending_reason1__ln
# 283 - short_term_lending_reason2__ln
# 284 - short_term_lending_reason3__ln
# 285 - short_term_lending_reason4__ln
# 286 - telecommunications_score__ln
# 287 - telecommunications_reason1__ln
# 288 - telecommunications_reason2__ln
# 289 - telecommunications_reason3__ln
# 290 - telecommunications_reason4__ln
# 291 - crossindustry_score__ln
# 292 - crossindustry_reason1__ln
# 293 - crossindustry_reason2__ln
# 294 - crossindustry_reason3__ln
# 295 - crossindustry_reason4__ln
# 296 - alert1__ln
# 297 - alert2__ln
# 298 - scr_linka2__tu
# 299 - scr_alta2__tu
# 300 - scr_linkb2__tu
# 301 - scr_altb2__tu
# 302 - DPD60PLUS__tucvlink
# 303 - zip_code__tu
# 304 - cvau__tu
# 305 - cvam__tu
# 306 - cvbk__tu
# 307 - cvna__tu
# 308 - cvpl__tu
# 309 - cv_bc_prop__tu
# 310 - cv_cons_prop__tu
# 311 - cv_persloan_prop__tu
# 312 - syntheticfraud_score__tu
# 313 - vantagescore3__tu
# 314 - vantagescore4__tu
# 315 - cv_bc_behav_seg__tu
# 316 - archive__tu
# 317 - tu_creditbureaudate__tu
# 318 - bitsystemdecline__app
# 319 - inputprovidedssn__ln
# 320 - inputprovideddateofbirth__ln
# 321 - purchaseactivitycount__ln
# 322 - purchaseactivitydollartotal__ln
# 323 - linkc010__tu
# 324 - inputprovidedstate__ln
# 325 - inputprovidedzipcode__ln
# 326 - bc933b__tu
# 327 - bigaccountid__app
# 328 - bigdebtorid__app
# 329 - fltgrossmonthly__income_min
# 330 - fltgrossmonthly__income_max
# 331 - fltgrossmonthly__income_median
# 332 - fltgrossmonthly__income_mean
# 333 - fltgrossmonthly__income_std
# 334 - bigaccountid__ln
# 335 - bigdebtorid__ln
# 336 - linkc006__tu
# 337 - linkc020__tu
# 338 - linkc007__tu
# 339 - linkc048__tu
# 340 - linkc025__tu
# 341 - linkc026__tu
# 342 - linkc027__tu
# 343 - linkc028__tu
# 344 - linkc029__tu
# 345 - linkc024__tu
# 346 - linkc031__tu
# 347 - linkc032__tu
# 348 - linkc033__tu
# 349 - linkc034__tu
# 350 - linkc035__tu
# 351 - linkc030__tu
# 352 - linkc038__tu
# 353 - linkc039__tu
# 354 - linkc040__tu
# 355 - linkc041__tu
# 356 - linkc042__tu
# 357 - linkc037__tu
# 358 - linkc036__tu
# 359 - linkc008__tu
# 360 - linkc009__tu
# 361 - linkc050__tu
# 362 - linkc012__tu
# 363 - linkc011__tu
# 364 - linkc043__tu
# 365 - linkc044__tu
# 366 - linkc045__tu
# 367 - linkc046__tu
# 368 - linkc047__tu
# 369 - linkc049__tu
# 370 - linkc005__tu
# 371 - linkc004__tu
# 372 - linkc051__tu
# 373 - cvlst_s1__tu
# 374 - cvlst_i1__tu
# 375 - eadms1__tu
# 376 - credit_as_of_date__tu
# 377 - bc_trd__tu
# 378 - inst_trd__tu
# 379 - nomt_trd__tu
# 380 - rev_trd__tu
# 381 - rtl_trd__tu
# 382 - linkchit__tu
# 383 - scr_alt_a_2__tu
# 384 - scr_link_a_2__tu
# 385 - scr_alt_b_2__tu
# 386 - scr_link_b_2__tu
# 387 - zipcodefiller__tu
# 388 - score_cvauto__tu
# 389 - score_newaccount__tu
# 390 - score_epd__tu
# 391 - at900s__tu
# 392 - at900b__tu
# 393 - at921s__tu
# 394 - at921b__tu
# 395 - at921c__tu
# 396 - at933s__tu
# 397 - at933b__tu
# 398 - at933c__tu
# 399 - au900s__tu
# 400 - au900b__tu
# 401 - bc900s__tu
# 402 - bc900b__tu
# 403 - rl900s__tu
# 404 - rl900b__tu
# 405 - rl933s__tu
# 406 - rl933b__tu
# 407 - rl933c__tu
# 408 - us900s__tu
# 409 - us900b__tu
# 410 - au921s__tu
# 411 - au921b__tu
# 412 - au921c__tu
# 413 - au933s__tu
# 414 - bc921s__tu
# 415 - bc921b__tu
# 416 - bc921c__tu
# 417 - bc933s__tu
# 418 - he900s__tu
# 419 - he900b__tu
# 420 - he921s__tu
# 421 - he921b__tu
# 422 - he921c__tu
# 423 - he933s__tu
# 424 - mt900s__tu
# 425 - mt900b__tu
# 426 - mt921s__tu
# 427 - mt921b__tu
# 428 - mt921c__tu
# 429 - mt933s__tu
# 430 - mt933b__tu
# 431 - rl921s__tu
# 432 - rl921b__tu
# 433 - rt900s__tu
# 434 - rt900b__tu
# 435 - rt921s__tu
# 436 - rt921b__tu
# 437 - rt921c__tu
# 438 - rt933s__tu
# 439 - us921s__tu
# 440 - us921b__tu
# 441 - us921c__tu
# 442 - us933s__tu
# 443 - at920c__tu
# 444 - at920f__tu
# 445 - at922b__tu
# 446 - at922c__tu
# 447 - au922b__tu
# 448 - bc922b__tu
# 449 - cc100s__tu
# 450 - cc101b__tu
# 451 - he922b__tu
# 452 - mt922b__tu
# 453 - rl922b__tu
# 454 - rt922b__tu
# 455 - us922b__tu
# 456 - score_bankcard__tu
# 457 - score_cvpropensity__tu
# 458 - finscore__tu
# 459 - intscore__ln

# %% [markdown]
# ### Save

# %%
# %%time

df = pd.DataFrame({'feature': list_cols_all})
str_filename = 'df_cols_drop.csv'
str_local_path = f'{str_dirname_output}/{str_filename}'
df.to_csv(str_local_path, index=False)
# Out:
# CPU times: user 109 ms, sys: 0 ns, total: 109 ms
# Wall time: 109 ms
