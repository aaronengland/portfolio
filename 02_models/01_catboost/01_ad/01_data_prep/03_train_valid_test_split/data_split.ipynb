# %% [markdown]
# # Train, Valid, Test Split (ml.m5.12xlarge)

# %%
import os
import pandas as pd
import numpy as np
from tqdm import tqdm
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# ### Functions

# %%
# denote df
def mark_df(flt_prop_row):
    if flt_prop_row <= 0.6:
        return 'train'
    elif flt_prop_row <= 0.8:
        return 'valid'
    else:
        return 'test'

# %% [markdown]
# ### Constants

# %%
str_project = os.getcwd().split('/')[4].replace('_','-')
print(f'Project: {str_project}')
str_step = os.getcwd().split('/')[-1]
print(f'Step: {str_step}')
str_dirname_output = './output'

str_id = 'uniqueid'
str_datecol = 'applicationdate__app'
str_target = 'target'

list_cols_id = [
    str_id,
    str_datecol,
    str_target,
]
# Out:
# Project: 20231010-gen-xii
# Step: 03_train_valid_test_split

# %% [markdown]
# ### Output

# %%
try:
    os.mkdir(str_dirname_output)
except:
    pass

# %% [markdown]
# ### Import data

# %%
# %%time

# import
str_filename = 'df_raw.gzip'
str_uri = f's3://{str_project}/01_ad/01_data_prep/01_data_collection/output/{str_filename}'
# read from s3
df = pd.read_parquet(str_uri)
# replace
df.replace(['NaN','nan'], np.nan, inplace=True)

# show
df
# Out:
# CPU times: user 2min 48s, sys: 4min 57s, total: 7min 46s
# Wall time: 51.2 s
#          bitdebtor__base  dtmstampcreation__base  dtmapproved__base  \
# 0                    0.0              20181103.0         20181103.0
# 1                    0.0              20181103.0                NaN
# 2                    0.0              20181103.0                NaN
# 3                    0.0              20181030.0                NaN
# 4                    0.0              20181031.0         20181031.0
# ...                  ...                     ...                ...
# 2100693              NaN                     NaN                NaN
# 2100694              NaN                     NaN                NaN
# 2100695              NaN                     NaN                NaN
# 2100696              NaN                     NaN                NaN
# 2100697              NaN                     NaN                NaN
#
#          dtmdeclined__base  dtmfunded__base  observationdate__base  \
# 0                      NaN              NaN               201810.0
# 1               20181103.0              NaN               201810.0
# 2               20181103.0              NaN               201810.0
# 3               20181030.0              NaN               201810.0
# 4                      NaN              NaN               201810.0
# ...                    ...              ...                    ...
# 2100693                NaN              NaN                    NaN
# 2100694                NaN              NaN                    NaN
# 2100695                NaN              NaN                    NaN
# 2100696                NaN              NaN                    NaN
# 2100697                NaN              NaN                    NaN
#
#          analyticsmatchkey__base decision_dte__base  booked__base  \
# 0                        73140.0         2018-11-03           0.0
# 1                        72817.0         2018-11-03           0.0
# 2                        74494.0         2018-11-03           0.0
# 3                        61357.0         2018-10-30           0.0
# 4                        61417.0         2018-10-31           0.0
# ...                          ...                ...           ...
# 2100693                      NaN                NaN           NaN
# 2100694                      NaN                NaN           NaN
# 2100695                      NaN                NaN           NaN
# 2100696                      NaN                NaN           NaN
# 2100697                      NaN                NaN           NaN
#
#         acct_typ_cde__base  ... us934d__tu  us934s__tu us935b__tu us935c__tu  \
# 0                       AU  ...        NaN         NaN        NaN        NaN
# 1                       AU  ...        NaN         NaN        NaN        NaN
# 2                       AU  ...        NaN         NaN        NaN        NaN
# 3                       AU  ...        NaN         NaN        NaN        NaN
# 4                       AU  ...        NaN         NaN        NaN        NaN
# ...                    ...  ...        ...         ...        ...        ...
# 2100693                NaN  ...       -1.0        -1.0       -1.0       -1.0
# 2100694                NaN  ...       -1.0        -1.0       -1.0       -1.0
# 2100695                NaN  ...       -1.0        -1.0       -1.0       -1.0
# 2100696                NaN  ...       -1.0        -1.0       -1.0       -1.0
# 2100697                NaN  ...       -1.0        -1.0       -1.0       -1.0
#
#         us935d__tu us935s__tu score_bankcard__tu score_cvpropensity__tu  \
# 0              NaN        NaN                NaN                    NaN
# 1              NaN        NaN                NaN                    NaN
# 2              NaN        NaN                NaN                    NaN
# 3              NaN        NaN                NaN                    NaN
# 4              NaN        NaN                NaN                    NaN
# ...            ...        ...                ...                    ...
# 2100693       -1.0       -1.0                0.0                    NaN
# 2100694       -1.0       -1.0                0.0                  451.0
# 2100695       -1.0       -1.0                0.0                  447.0
# 2100696       -1.0       -1.0                0.0                  501.0
# 2100697       -1.0       -1.0                0.0                    NaN
#
#         finscore__tu intscore__ln
# 0                NaN          NaN
# 1                NaN          NaN
# 2                NaN          NaN
# 3                NaN          NaN
# 4                NaN          NaN
# ...              ...          ...
# 2100693        555.0        588.0
# 2100694        571.0        574.0
# 2100695        616.0        568.0
# 2100696        648.0        595.0
# 2100697        534.0        597.0
#
# [2100698 rows x 2488 columns]

# %% [markdown]
# ### Mark each row as train, valid, or test

# %%
# %%time

# sort
df.sort_values(by=str_datecol, ascending=True, inplace=True)

# create column
int_nrows = df.shape[0]
df['int_row'] = [i for i in range(1, int_nrows + 1)]
# divide by n rows
df['flt_prop_row'] = df['int_row'] / int_nrows

# drop
df.drop('int_row', axis=1, inplace=True)

# mark the df
df['data_set'] = df['flt_prop_row'].apply(mark_df)

# show
df
# Out:
# CPU times: user 28.6 s, sys: 17.9 s, total: 46.5 s
# Wall time: 43.5 s
#         bitdebtor__base  dtmstampcreation__base  dtmapproved__base  \
# 578033              NaN                     NaN                NaN
# 578463              NaN                     NaN                NaN
# 578464              NaN                     NaN                NaN
# 578465              NaN                     NaN                NaN
# 578466              NaN                     NaN                NaN
# ...                 ...                     ...                ...
# 61490               1.0              20191231.0                NaN
# 98385               1.0              20191231.0                NaN
# 98384               1.0              20191231.0                NaN
# 413531              1.0              20191231.0                NaN
# 560787              NaN                     NaN                NaN
#
#         dtmdeclined__base  dtmfunded__base  observationdate__base  \
# 578033                NaN              NaN                    NaN
# 578463                NaN              NaN                    NaN
# 578464                NaN              NaN                    NaN
# 578465                NaN              NaN                    NaN
# 578466                NaN              NaN                    NaN
# ...                   ...              ...                    ...
# 61490          20191231.0              NaN               201910.0
# 98385          20191231.0              NaN               201910.0
# 98384          20191231.0              NaN               201910.0
# 413531         20191231.0              NaN               201910.0
# 560787                NaN              NaN                    NaN
#
#         analyticsmatchkey__base decision_dte__base  booked__base  \
# 578033                      NaN                NaN           NaN
# 578463                      NaN                NaN           NaN
# 578464                      NaN                NaN           NaN
# 578465                      NaN                NaN           NaN
# 578466                      NaN                NaN           NaN
# ...                         ...                ...           ...
# 61490                  866585.0         2019-12-31           0.0
# 98385                  862293.0         2019-12-31           0.0
# 98384                  937386.0         2019-12-31           0.0
# 413531                 865161.0         2019-12-31           0.0
# 560787                      NaN                NaN           NaN
#
#        acct_typ_cde__base  ... us935b__tu  us935c__tu us935d__tu us935s__tu  \
# 578033                NaN  ...        NaN         NaN        NaN        NaN
# 578463                NaN  ...        NaN         NaN        NaN        NaN
# 578464                NaN  ...        NaN         NaN        NaN        NaN
# 578465                NaN  ...        NaN         NaN        NaN        NaN
# 578466                NaN  ...        NaN         NaN        NaN        NaN
# ...                   ...  ...        ...         ...        ...        ...
# 61490                  AU  ...        NaN         NaN        NaN        NaN
# 98385                  AU  ...        NaN         NaN        NaN        NaN
# 98384                  AU  ...        NaN         NaN        NaN        NaN
# 413531                 AU  ...        NaN         NaN        NaN        NaN
# 560787                 AU  ...        NaN         NaN        NaN        NaN
#
#        score_bankcard__tu score_cvpropensity__tu finscore__tu intscore__ln  \
# 578033                NaN                    NaN          NaN          NaN
# 578463                NaN                    NaN          NaN          NaN
# 578464                NaN                    NaN          NaN          NaN
# 578465                NaN                    NaN          NaN          NaN
# 578466                NaN                    NaN          NaN          NaN
# ...                   ...                    ...          ...          ...
# 61490                 NaN                    NaN          NaN          NaN
# 98385                 NaN                    NaN          NaN          NaN
# 98384                 NaN                    NaN          NaN          NaN
# 413531                NaN                    NaN          NaN          NaN
# 560787                NaN                    NaN          NaN          NaN
#
#         flt_prop_row data_set
# 578033  4.760323e-07    train
# 578463  9.520645e-07    train
# 578464  1.428097e-06    train
# 578465  1.904129e-06    train
# 578466  2.380161e-06    train
# ...              ...      ...
# 61490   9.999981e-01     test
# 98385   9.999986e-01     test
# 98384   9.999990e-01     test
# 413531  9.999995e-01     test
# 560787  1.000000e+00     test
#
# [2100698 rows x 2490 columns]

# %% [markdown]
# ### Show value counts

# %%
ser_prop = pd.value_counts(df['data_set'], normalize=True)
print(ser_prop)
# Out:
# data_set
# train    0.6
# valid    0.2
# test     0.2
# Name: proportion, dtype: float64
# /tmp/ipykernel_37772/1628931787.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   ser_prop = pd.value_counts(df['data_set'], normalize=True)

# %%
ser_freq = pd.value_counts(df['data_set'], normalize=False)
print(ser_freq)
# Out:
# data_set
# train    1260418
# valid     420140
# test      420140
# Name: count, dtype: int64
# /tmp/ipykernel_37772/3389291447.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   ser_freq = pd.value_counts(df['data_set'], normalize=False)

# %% [markdown]
# ### Write data frames

# %%
list_df = [
    'train',
    'valid',
    'test',
]
for str_df in tqdm (list_df):
    # subset
    df_tmp = df[df['data_set']==str_df].copy()
    
    # drop
    list_cols = [
        'flt_prop_row',
        'data_set',
    ]
    df_tmp.drop(list_cols, axis=1, inplace=True)
    
    # write to s3
    str_filename = f'df_{str_df}_raw.gzip'
    str_uri = f's3://{str_project}/01_ad/01_data_prep/{str_step}/{str_filename}'
    df_tmp.to_parquet(str_uri, compression='gzip')
# Out:
# 100%|██████████| 3/3 [14:06<00:00, 282.11s/it]
