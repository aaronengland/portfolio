# %%
import os
import boto3
from sagemaker import get_execution_role
from pprint import pprint
import json
import time
import datetime as dt
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %%
print(f'Latest run date: {dt.datetime.today()}')
# Out:
# Latest run date: 2024-03-19 17:52:24.414430

# %% [markdown]
# ### Constants

# %%
# name of step function
str_name = 'genxii-payload-parsing'
# project
str_project = os.getcwd().split('/')[4].replace('_','-')
print(f'Project: {str_project}')
# Out:
# Project: 20231010-gen-xii

# %% [markdown]
# ### Write ```definition.json```

# %%
# %%writefile definition.json
#
# {
#   "Comment": "A description of my state machine",
#   "StartAt": "PullRequests",
#   "States": {
#     "PullRequests": {
#       "Type": "Task",
#       "Resource": "arn:aws:states:::batch:submitJob.sync",
#       "Parameters": {
#         "JobName": "job-def-genxii-pull-payloads-1",
#         "JobDefinition": "arn:aws:batch:us-west-2:836690756591:job-definition/job-def-genxii-pull-payloads-1:2",
#         "JobQueue": "arn:aws:batch:us-west-2:836690756591:job-queue/queue-genxii-pull-payloads-1"
#       },
#       "Next": "SplitRequests"
#     },
#     "SplitRequests": {
#       "Type": "Task",
#       "Resource": "arn:aws:states:::batch:submitJob.sync",
#       "Parameters": {
#         "JobName": "job-def-genxii-split-payloads-1",
#         "JobDefinition": "arn:aws:batch:us-west-2:836690756591:job-definition/job-def-genxii-split-payloads-1:4",
#         "JobQueue": "arn:aws:batch:us-west-2:836690756591:job-queue/queue-genxii-split-payloads-1"
#       },
#       "Next": "ParsePayloadsMap"
#     },
#     "ParsePayloadsMap": {
#       "Type": "Map",
#       "ItemProcessor": {
#         "ProcessorConfig": {
#           "Mode": "DISTRIBUTED",
#           "ExecutionType": "STANDARD"
#         },
#         "StartAt": "ParsePayloads",
#         "States": {
#           "ParsePayloads": {
#             "Type": "Task",
#             "Resource": "arn:aws:states:::lambda:invoke",
#             "OutputPath": "$.Payload",
#             "Parameters": {
#               "Payload.$": "$",
#               "FunctionName": "arn:aws:lambda:us-west-2:836690756591:function:genxii-parse-payloads:$LATEST"
#             },
#             "Retry": [
#               {
#                 "ErrorEquals": [
#                   "Lambda.ServiceException",
#                   "Lambda.AWSLambdaException",
#                   "Lambda.SdkClientException",
#                   "Lambda.TooManyRequestsException"
#                 ],
#                 "IntervalSeconds": 1,
#                 "MaxAttempts": 3,
#                 "BackoffRate": 2
#               }
#             ],
#             "End": true
#           }
#         }
#       },
#       "ItemReader": {
#         "Resource": "arn:aws:states:::s3:getObject",
#         "ReaderConfig": {
#           "InputType": "CSV",
#           "CSVHeaderLocation": "FIRST_ROW"
#         },
#         "Parameters": {
#           "Bucket": "20231010-gen-xii",
#           "Key": "13_payload_parsing/df_idx.csv"
#         }
#       },
#       "MaxConcurrency": 1000,
#       "Label": "ParsePayloadsMap",
#       "Next": "ConcatResults"
#     },
#     "ConcatResults": {
#       "Type": "Task",
#       "Resource": "arn:aws:states:::batch:submitJob.sync",
#       "Parameters": {
#         "JobName": "job-name-genxii-concat-parsed-payloads-1",
#         "JobDefinition": "arn:aws:batch:us-west-2:836690756591:job-definition/job-def-genxii-concat-parsed-payloads-1:1",
#         "JobQueue": "arn:aws:batch:us-west-2:836690756591:job-queue/queue-genxii-concat-parsed-payloads-1"
#       },
#       "End": true
#     }
#   }
# }
# Out:
# Writing definition.json

# %% [markdown]
# ### Make string definition

# %%
# load it
dict_definition = json.load(open('./definition.json'))
# make into string
str_definition = json.dumps(dict_definition)

# %% [markdown]
# ### Create state machine

# %%
cls_client_sfn = boto3.client('stepfunctions')

# %%
# get role
str_role = get_execution_role()
print(f'Role: {str_role}')
# Out:
# Role: arn:aws:iam::836690756591:role/risk-ops-role

# %%
# list state machines
dict_response = cls_client_sfn.list_state_machines(
)
list_dict_state_machines = dict_response['stateMachines']
list_dict_state_names = [{dict_state_machine['name']: dict_state_machine['stateMachineArn']} for dict_state_machine in list_dict_state_machines]
dict_state_names = {key: val for dict_name in list_dict_state_names for key, val in dict_name.items()}
pprint(dict_state_names)
# Out:
# {'MyStateMachine-fldl4s6of': 'arn:aws:states:us-west-2:836690756591:stateMachine:MyStateMachine-fldl4s6of',
#  'gen-xi-retro-scoring': 'arn:aws:states:us-west-2:836690756591:stateMachine:gen-xi-retro-scoring',
#  'gen-xii-retro-scoring': 'arn:aws:states:us-west-2:836690756591:stateMachine:gen-xii-retro-scoring',
#  'genxii-payload-parsing': 'arn:aws:states:us-west-2:836690756591:stateMachine:genxii-payload-parsing',
#  'poc-step-genxii-lgd-lambda-boto3': 'arn:aws:states:us-west-2:836690756591:stateMachine:poc-step-genxii-lgd-lambda-boto3',
#  'poc-step-genxii-pd-lambda-boto3': 'arn:aws:states:us-west-2:836690756591:stateMachine:poc-step-genxii-pd-lambda-boto3',
#  'step-genxii-ad-feat-select-boto3': 'arn:aws:states:us-west-2:836690756591:stateMachine:step-genxii-ad-feat-select-boto3',
#  'step-genxii-ad-model-boto3': 'arn:aws:states:us-west-2:836690756591:stateMachine:step-genxii-ad-model-boto3',
#  'step-genxii-ad-pre-boto3': 'arn:aws:states:us-west-2:836690756591:stateMachine:step-genxii-ad-pre-boto3',
#  'step-genxii-lgd-feat-select-boto3': 'arn:aws:states:us-west-2:836690756591:stateMachine:step-genxii-lgd-feat-select-boto3',
#  'step-genxii-lgd-model-boto3': 'arn:aws:states:us-west-2:836690756591:stateMachine:step-genxii-lgd-model-boto3',
#  'step-genxii-lgd-pre-boto3': 'arn:aws:states:us-west-2:836690756591:stateMachine:step-genxii-lgd-pre-boto3',
#  'step-genxii-pd-feat-select-boto3': 'arn:aws:states:us-west-2:836690756591:stateMachine:step-genxii-pd-feat-select-boto3',
#  'step-genxii-pd-model-boto3': 'arn:aws:states:us-west-2:836690756591:stateMachine:step-genxii-pd-model-boto3',
#  'step-genxii-pd-pre-boto3': 'arn:aws:states:us-west-2:836690756591:stateMachine:step-genxii-pd-pre-boto3',
#  'step-model-monitoring-boto3': 'arn:aws:states:us-west-2:836690756591:stateMachine:step-model-monitoring-boto3',
#  'step-retention-combined-predictions-boto3': 'arn:aws:states:us-west-2:836690756591:stateMachine:step-retention-combined-predictions-boto3'}

# %%
# get list of just names
list_str_names = [list(dict_state_names.keys())[0] for dict_state_names in list_dict_state_names]
# if our name is in there
if str_name in list_str_names:
    print(f'State machine {str_name} exists, it will be deleted')
    str_arn = dict_state_names[str_name]
    print(f'Deleting {str_arn}')
    print('')
    dict_response = cls_client_sfn.delete_state_machine(
        stateMachineArn=str_arn,
    )
    pprint(dict_response)
else:
    print(f'State machine {str_name} does not exist, so it will not be deleted')
# Out:
# State machine genxii-payload-parsing exists, it will be deleted
# Deleting arn:aws:states:us-west-2:836690756591:stateMachine:genxii-payload-parsing
#
# {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                       'content-length': '2',
#                                       'content-type': 'application/x-amz-json-1.0',
#                                       'date': 'Tue, 19 Mar 2024 17:52:24 GMT',
#                                       'x-amzn-requestid': 'a9ff9e6d-0b9e-4e0d-8957-56c39e449c98'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'a9ff9e6d-0b9e-4e0d-8957-56c39e449c98',
#                       'RetryAttempts': 0}}

# %%
# make a state machine
while True:
    try:
        dict_response = cls_client_sfn.create_state_machine(
            name=str_name,
            definition=str_definition,
            roleArn=str_role,
            type='STANDARD',
        )
        pprint(dict_response)
        break
    except:
        pass
# Out:
# {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                       'content-length': '127',
#                                       'content-type': 'application/x-amz-json-1.0',
#                                       'date': 'Tue, 19 Mar 2024 17:53:37 GMT',
#                                       'x-amzn-requestid': '64a135b6-7032-4221-9a92-bf3a90f4afb9'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '64a135b6-7032-4221-9a92-bf3a90f4afb9',
#                       'RetryAttempts': 2},
#  'creationDate': datetime.datetime(2024, 3, 19, 17, 53, 37, 21000, tzinfo=tzlocal()),
#  'stateMachineArn': 'arn:aws:states:us-west-2:836690756591:stateMachine:genxii-payload-parsing'}

# %% [markdown]
# ### Describe state machine

# %%
str_state_machine_arn = dict_response['stateMachineArn']
print(f'State Machine ARN: {str_state_machine_arn}')
dict_response = cls_client_sfn.describe_state_machine(
    stateMachineArn=str_state_machine_arn,
)
pprint(dict_response)
# Out:
# State Machine ARN: arn:aws:states:us-west-2:836690756591:stateMachine:genxii-payload-parsing
# {'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                       'content-length': '2838',
#                                       'content-type': 'application/x-amz-json-1.0',
#                                       'date': 'Tue, 19 Mar 2024 17:53:37 GMT',
#                                       'x-amzn-requestid': 'd9297899-cb2c-47b4-97a8-2609a851daa0'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'd9297899-cb2c-47b4-97a8-2609a851daa0',
#                       'RetryAttempts': 0},
#  'creationDate': datetime.datetime(2024, 3, 19, 17, 53, 37, 21000, tzinfo=tzlocal()),
#  'definition': '{"Comment": "A description of my state machine", "StartAt": '
#                '"PullRequests", "States": {"PullRequests": {"Type": "Task", '
#                '"Resource": "arn:aws:states:::batch:submitJob.sync", '
#                '"Parameters": {"JobName": "job-def-genxii-pull-payloads-1", '
#                '"JobDefinition": '
#                '"arn:aws:batch:us-west-2:836690756591:job-definition/job-def-genxii-pull-payloads-1:2", '
#                '"JobQueue": '
#                '"arn:aws:batch:us-west-2:836690756591:job-queue/queue-genxii-pull-payloads-1"}, '
#                '"Next": "SplitRequests"}, "SplitRequests": {"Type": "Task", '
#                '"Resource": "arn:aws:states:::batch:submitJob.sync", '
#                '"Parameters": {"JobName": "job-def-genxii-split-payloads-1", '
#                '"JobDefinition": '
#                '"arn:aws:batch:us-west-2:836690756591:job-definition/job-def-genxii-split-payloads-1:4", '
#                '"JobQueue": '
#                '"arn:aws:batch:us-west-2:836690756591:job-queue/queue-genxii-split-payloads-1"}, '
#                '"Next": "ParsePayloadsMap"}, "ParsePayloadsMap": {"Type": '
#                '"Map", "ItemProcessor": {"ProcessorConfig": {"Mode": '
#                '"DISTRIBUTED", "ExecutionType": "STANDARD"}, "StartAt": '
#                '"ParsePayloads", "States": {"ParsePayloads": {"Type": "Task", '
#                '"Resource": "arn:aws:states:::lambda:invoke", "OutputPath": '
#                '"$.Payload", "Parameters": {"Payload.$": "$", "FunctionName": '
#                '"arn:aws:lambda:us-west-2:836690756591:function:genxii-parse-payloads:$LATEST"}, '
#                '"Retry": [{"ErrorEquals": ["Lambda.ServiceException", '
#                '"Lambda.AWSLambdaException", "Lambda.SdkClientException", '
#                '"Lambda.TooManyRequestsException"], "IntervalSeconds": 1, '
#                '"MaxAttempts": 3, "BackoffRate": 2}], "End": true}}}, '
#                '"ItemReader": {"Resource": "arn:aws:states:::s3:getObject", '
#                '"ReaderConfig": {"InputType": "CSV", "CSVHeaderLocation": '
#                '"FIRST_ROW"}, "Parameters": {"Bucket": "20231010-gen-xii", '
#                '"Key": "13_payload_parsing/df_idx.csv"}}, "MaxConcurrency": '
#                '1000, "Label": "ParsePayloadsMap", "Next": "ConcatResults"}, '
#                '"ConcatResults": {"Type": "Task", "Resource": '
#                '"arn:aws:states:::batch:submitJob.sync", "Parameters": '
#                '{"JobName": "job-name-genxii-concat-parsed-payloads-1", '
#                '"JobDefinition": '
#                '"arn:aws:batch:us-west-2:836690756591:job-definition/job-def-genxii-concat-parsed-payloads-1:1", '
#                '"JobQueue": '
#                '"arn:aws:batch:us-west-2:836690756591:job-queue/queue-genxii-concat-parsed-payloads-1"}, '
#                '"End": true}}}',
#  'loggingConfiguration': {'includeExecutionData': False, 'level': 'OFF'},
#  'name': 'genxii-payload-parsing',
#  'roleArn': 'arn:aws:iam::836690756591:role/risk-ops-role',
#  'stateMachineArn': 'arn:aws:states:us-west-2:836690756591:stateMachine:genxii-payload-parsing',
#  'status': 'ACTIVE',
#  'tracingConfiguration': {'enabled': False},
#  'type': 'STANDARD'}

# %% [markdown]
# ### Execute step function workflow

# %%
# # start execution
# dict_response = cls_client_sfn.start_execution(
#     stateMachineArn=str_state_machine_arn,
# )

# %% [markdown]
# ### Clean-up

# %%
os.remove('./definition.json')
