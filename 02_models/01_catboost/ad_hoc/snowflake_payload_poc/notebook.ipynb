# %%
import os
import pandas as pd
import numpy as np
from passwords import *
try:
    import snowflake.connector
except ModuleNotFoundError:
    ! pip install pandas snowflake-connector-python
    import snowflake.connector

# %% [markdown]
# ### Connection

# %%
# Connect to Snowflake
conn = snowflake.connector.connect(
    user=USERNAME,
    password=PASSWORD,
    account=ACCOUNT,
    warehouse=WAREHOUSE,
    database=DATABASE,
    schema=SCHEMA,
)

# %% [markdown]
# ### Query

# %%
str_query = """
select * from 
raw.source_s3_scorehistory.PAYLOADS_PARSED_YESTERDAY
"""

# %% [markdown]
# ### Pull data

# %%
df = pd.read_sql(
    sql=str_query,
    con=conn,
)
df
# Out:
# /tmp/ipykernel_22751/4274107538.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(
#                              FILE_NAME ACCOUNTID     REQUEST_DATETIME  \
# 0     7567091/Ew00-2024-03-04-15:46:12   7567091  2024-03-04 15:46:12
# 1     7629821/Ay9H-2024-03-04-16:01:20   7629821  2024-03-04 16:01:20
# 2     7625038/aI8u-2024-03-04-16:28:46   7625038  2024-03-04 16:28:46
# 3     7629203/3D5V-2024-03-04-14:45:01   7629203  2024-03-04 14:45:01
# 4     7629551/j5f4-2024-03-04-01:53:49   7629551  2024-03-04 01:53:49
# ...                                ...       ...                  ...
# 1357  7603998/A7i7-2024-03-04-14:28:55   7603998  2024-03-04 14:28:55
# 1358  7622345/2Fkr-2024-03-04-16:07:30   7622345  2024-03-04 16:07:30
# 1359  7627831/Vj2K-2024-03-04-15:54:08   7627831  2024-03-04 15:54:08
# 1360  7629512/77oN-2024-03-04-01:04:01   7629512  2024-03-04 01:04:01
# 1361  7629760/yc1t-2024-03-04-15:44:03   7629760  2024-03-04 15:44:03
#
#                                              FILE_VALUE  \
# 0     {\n  "request": {\n    "request_id": "75670911...
# 1     {\n  "request": {\n    "request_id": "76298218...
# 2     {\n  "request": {\n    "request_id": "76250381...
# 3     {\n  "request": {\n    "request_id": "76292031...
# 4     {\n  "request": {\n    "request_id": "76295511...
# ...                                                 ...
# 1357  {\n  "request": {\n    "request_id": "76039987...
# 1358  {\n  "request": {\n    "request_id": "76223459...
# 1359  {\n  "request": {\n    "request_id": "76278315...
# 1360  {\n  "request": {\n    "request_id": "76295128...
# 1361  {\n  "request": {\n    "request_id": "76297607...
#
#                                            REQUEST_JSON  \
# 0     {\n  "request_id": "7567091131377",\n  "rows":...
# 1     {\n  "request_id": "7629821841898",\n  "rows":...
# 2     {\n  "request_id": "7625038100602",\n  "rows":...
# 3     {\n  "request_id": "7629203149649",\n  "rows":...
# 4     {\n  "request_id": "762955118432",\n  "rows": ...
# ...                                                 ...
# 1357  {\n  "request_id": "760399871466",\n  "rows": ...
# 1358  {\n  "request_id": "7622345919453",\n  "rows":...
# 1359  {\n  "request_id": "7627831527998",\n  "rows":...
# 1360  {\n  "request_id": "7629512820779",\n  "rows":...
# 1361  {\n  "request_id": "7629760737044",\n  "rows":...
#
#                                           RESPONSE_JSON     REQUEST_ID  \
# 0     {\n  "Response": [\n    {\n      "Model_name":...  7567091131377
# 1     {\n  "Response": [\n    {\n      "Model_name":...  7629821841898
# 2     {\n  "Response": [\n    {\n      "Model_name":...  7625038100602
# 3     {\n  "Response": [\n    {\n      "Model_name":...  7629203149649
# 4     {\n  "Response": [\n    {\n      "Model_name":...   762955118432
# ...                                                 ...            ...
# 1357  {\n  "Response": [\n    {\n      "Model_name":...   760399871466
# 1358  {\n  "Response": [\n    {\n      "Model_name":...  7622345919453
# 1359  {\n  "Response": [\n    {\n      "Model_name":...  7627831527998
# 1360  {\n  "Response": [\n    {\n      "Model_name":...  7629512820779
# 1361  {\n  "Response": [\n    {\n      "Model_name":...  7629760737044
#
#      RESPONSE_MODEL_NAME RESPONSE_MODEL_VERSION
# 0         PRESTIGE-GENXI                     V2
# 1       PRESTIGE-GEN-XII                     V1
# 2       PRESTIGE-GEN-XII                     V1
# 3       PRESTIGE-GEN-XII                     V1
# 4       PRESTIGE-GEN-XII                     V1
# ...                  ...                    ...
# 1357      PRESTIGE-GENXI                     V2
# 1358      PRESTIGE-GENXI                     V2
# 1359      PRESTIGE-GENXI                     V2
# 1360      PRESTIGE-GENXI                     V2
# 1361    PRESTIGE-GEN-XII                     V1
#
# [1362 rows x 9 columns]
