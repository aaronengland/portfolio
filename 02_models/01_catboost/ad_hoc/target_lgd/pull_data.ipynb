# %% [markdown]
# # Pull data

# %%
from passwords import *
from pprint import pprint
import pandas as pd
import pyodbc
import os
import boto3

# %% [markdown]
# ## Functions

# %%
# upload to s3
def upload_to_s3(aws_access_key_id, aws_secret_access_key, str_local_path, str_bucket_key, str_bucket_name='dustin-payment-analysis'):
    # init client
    cls_client = boto3.client(
        's3',
        aws_access_key_id=aws_access_key_id,
        aws_secret_access_key=aws_secret_access_key,
        aws_session_token=None,
    )
    # upload
    cls_client.upload_file(
        str_local_path, 
        str_bucket_name, 
        str_bucket_key,
    )

# %% [markdown]
# ## Constants

# %%
# project
str_project = os.getcwd().split('\\')[4].replace('_','-')
print(f'Project: {str_project}')
# output
str_dirname_output = './output'
# Out:
# Project: 20231010-gen-xii

# %% [markdown]
# ## Output directory

# %%
try:
    os.mkdir(str_dirname_output)
except FileExistsError:
    pass

# %% [markdown]
# ## Read query

# %%
str_filepath = './sql/query.sql'
str_query = open(str_filepath, 'r').read()
pprint(str_query)
# Out:
# ('with tblMax as\n'
#  '(\n'
#  'select\n'
#  '\tbigAccountId,\n'
#  '\tmax(concat(MonthOnBooks, bigAccountid, bigRunDateKeyId)) as MaxUnique\n'
#  'from riskdb.dbo.tblReportCOStaticPools_StaticPool\n'
#  'where MonthOnBooks<=72\n'
#  'group by bigAccountId\n'
#  '),\n'
#  '\n'
#  '\n'
#  '\n'
#  'tblReportCOStaticPools_StaticPoolNew as\n'
#  '(\n'
#  'select\n'
#  '\tconcat(MonthOnBooks, bigAccountid, bigRunDateKeyId) as uniqueC,\n'
#  '\t*\n'
#  'from riskdb.dbo.tblReportCOStaticPools_StaticPool\n'
#  'where MonthOnBooks<=72\n'
#  ')\n'
#  '\n'
#  '\n'
#  'select \n'
#  '\tCONCAT(tblAccount.bigAccountId, tblAccount.bigDebtorId, 1) as UniqueID,\n'
#  '\ttbltempstaticpool.bigAccountId,\n'
#  '\ttblAccount.bigDebtorId,\n'
#  '\t1 as bitDebtor,\n'
#  '\ttblAccount.dtmStampCreation,\n'
#  '\ttbltempstaticpool.dtmFunded,\n'
#  "\tcase when tbltempstaticpool.LoanStatusCNCombined='Default' then 1 else 0 "
#  'end as bitDefault,\n'
#  '\ttblReportCOStaticPools_StaticPoolNew.MonthOnBooks,\n'
#  '\ttblReportCOStaticPools_StaticPoolNew.RunningNetLoss,\n'
#  '\ttbltempstaticpool.AmtFinanced,\n'
#  '\ttbltempstaticpool.intOpenBKType,\n'
#  '\ttbltempstaticpool.intTerm,\n'
#  '\ttbltempstaticpool.VehicleYear,\n'
#  '\ttbltempstaticpool.bitNew,\n'
#  '\ttbltempstaticpool.VehicleMake,\n'
#  '\ttbltempstaticpool.Miles_Odometer,\n'
#  '\ttbltempstaticpool.BookValue,\n'
#  '\ttbltempstaticpool.fltDownCash,\n'
#  '\ttblAccount.fltApprovedDownTotal,\n'
#  '\ttbltempstaticpool.fltPaymentOriginal as Payment,\n'
#  '\ttbltempstaticpool.DTI,\n'
#  '\ttbltempstaticpool.PTI,\n'
#  '\ttbltempstaticpool.bitServiceContract,\n'
#  '\ttbltempstaticpool.fltAdvance,\n'
#  '\ttbltempstaticpool.strVehicleType,\n'
#  '\ttbltempstaticpool.bitGap,\n'
#  '\ttblDealer.dtmStampCreation as DealerStampCreation\n'
#  'from riskdb.analytics.tbltempstaticpool\n'
#  'left outer join tblMax on '
#  'tblMax.bigAccountid=tbltempstaticpool.bigAccountId\n'
#  'left outer join tblReportCOStaticPools_StaticPoolNew on '
#  'tblReportCOStaticPools_StaticPoolNew.uniqueC=tblMax.MaxUnique\n'
#  'left outer join tblAccount on '
#  'tblAccount.bigAccountId=tbltempstaticpool.bigAccountId\n'
#  'left outer join tblDealer on '
#  'tblDealer.bigDealerId=tbltempstaticpool.bigDealerId\n'
#  "where tblAccount.dtmStampCreation>='10/01/2013'\n"
#  "and tblAccount.dtmStampCreation<'01/01/2020'\n"
#  '\n'
#  'union\n'
#  '\n'
#  'select \n'
#  '\tCONCAT(tblAccount.bigAccountId, tblAccount.bigDebtorId, 1) as UniqueID,\n'
#  '\ttbltempstaticpool.bigAccountId,\n'
#  '\ttblCosigner.bigDebtorId_cosigner as bigDebtorId,\n'
#  '\t0 as bitDebtor,\n'
#  '\ttblAccount.dtmStampCreation,\n'
#  '\ttbltempstaticpool.dtmFunded,\n'
#  "\tcase when tbltempstaticpool.LoanStatusCNCombined='Default' then 1 else 0 "
#  'end as bitDefault,\n'
#  '\ttblReportCOStaticPools_StaticPoolNew.MonthOnBooks,\n'
#  '\ttblReportCOStaticPools_StaticPoolNew.RunningNetLoss,\n'
#  '\ttbltempstaticpool.AmtFinanced,\n'
#  '\ttbltempstaticpool.intOpenBKType,\n'
#  '\ttbltempstaticpool.intTerm,\n'
#  '\ttbltempstaticpool.VehicleYear,\n'
#  '\ttbltempstaticpool.bitNew,\n'
#  '\ttbltempstaticpool.VehicleMake,\n'
#  '\ttbltempstaticpool.Miles_Odometer,\n'
#  '\ttbltempstaticpool.BookValue,\n'
#  '\ttbltempstaticpool.fltDownCash,\n'
#  '\ttblAccount.fltApprovedDownTotal,\n'
#  '\ttbltempstaticpool.fltPaymentOriginal as Payment,\n'
#  '\ttbltempstaticpool.DTI,\n'
#  '\ttbltempstaticpool.PTI,\n'
#  '\ttbltempstaticpool.bitServiceContract,\n'
#  '\ttbltempstaticpool.fltAdvance,\n'
#  '\ttbltempstaticpool.strVehicleType,\n'
#  '\ttbltempstaticpool.bitGap,\n'
#  '\ttblDealer.dtmStampCreation as DealerStampCreation\n'
#  'from riskdb.analytics.tbltempstaticpool\n'
#  'left outer join tblMax on '
#  'tblMax.bigAccountid=tbltempstaticpool.bigAccountId\n'
#  'left outer join tblReportCOStaticPools_StaticPoolNew on '
#  'tblReportCOStaticPools_StaticPoolNew.uniqueC=tblMax.MaxUnique\n'
#  'left outer join tblAccount on '
#  'tblAccount.bigAccountId=tbltempstaticpool.bigAccountId\n'
#  'left outer join tblDealer on '
#  'tblDealer.bigDealerId=tbltempstaticpool.bigDealerId\n'
#  'left outer join tblCosigner on '
#  'tblCosigner.bigAccountId=tbltempstaticpool.bigAccountId\n'
#  "where tblAccount.dtmStampCreation>='10/01/2013'\n"
#  "and tblAccount.dtmStampCreation<'01/01/2020'\n"
#  'and tblCosigner.bigDebtorId_cosigner is not null\n'
#  '\n')

# %% [markdown]
# ## Write into df

# %%
# %%time

# create connection
conn = pyodbc.connect(
    'Driver={SQL Server};'
    'Server=electra;'
    'Database=pfsdb;'
    'Trusted_Connection=yes;'
)
df = pd.read_sql_query(
    str_query, 
    con=conn,
)
# close
conn.close()
# info
print(f'Data contains {df.shape[0]} rows and {df.shape[1]} columns')
# Out:
# Data contains 196839 rows and 27 columns
# Wall time: 44.3 s

# %%
# preview
df.head()
# Out:
#           UniqueID  bigAccountId  bigDebtorId  bitDebtor  \
# 0  133751117564401       1337511      1756440          1
# 1  133756117565081       1337561      1756508          1
# 2  133770217566931       1337702      1756693          1
# 3  133788617569361       1337886      1756936          1
# 4  133789717569521       1337897      1756952          1
#
#          dtmStampCreation  dtmFunded  bitDefault MonthOnBooks  RunningNetLoss  \
# 0 2013-10-01 07:28:54.833 2013-10-30           1           72        -1423.19
# 1 2013-10-01 09:00:08.383 2013-10-22           0           72            0.00
# 2 2013-10-01 10:35:41.517 2013-10-14           0           72            0.00
# 3 2013-10-01 12:21:07.203 2013-10-09           0           72            0.00
# 4 2013-10-01 12:29:28.650 2013-10-16           0           72            0.00
#
#    AmtFinanced  ...  fltDownCash  fltApprovedDownTotal  Payment       DTI  \
# 0     14532.90  ...       2000.0                2000.0   398.83  0.229354
# 1     16095.80  ...       2281.0                 500.0   349.06  0.467034
# 2     20568.71  ...          0.0                   0.0   448.99  0.425978
# 3     18307.12  ...          0.0                 800.0   410.00  0.361873
# 4     23968.40  ...          0.0                   0.0   493.76  0.498550
#
#         PTI  bitServiceContract  fltAdvance  strVehicleType  bitGap  \
# 0  0.052130                   1    1.106635            auto       0
# 1  0.109700                   1    1.050962            auto       1
# 2  0.102261                   0    1.151824             suv       0
# 3  0.057743                   0    1.198959             suv       0
# 4  0.137717                   0    1.175853             suv       0
#
#       DealerStampCreation
# 0 2012-06-18 09:31:54.393
# 1 2012-09-05 09:13:41.740
# 2 2012-02-10 13:48:47.720
# 3 2012-11-30 14:09:02.010
# 4 2012-09-05 09:13:41.740
#
# [5 rows x 27 columns]

# %%
for col in df.columns:
    print(col)
# Out:
# UniqueID
# bigAccountId
# bigDebtorId
# bitDebtor
# dtmStampCreation
# dtmFunded
# bitDefault
# MonthOnBooks
# RunningNetLoss
# AmtFinanced
# intOpenBKType
# intTerm
# VehicleYear
# bitNew
# VehicleMake
# Miles_Odometer
# BookValue
# fltDownCash
# fltApprovedDownTotal
# Payment
# DTI
# PTI
# bitServiceContract
# fltAdvance
# strVehicleType
# bitGap
# DealerStampCreation

# %%
# get prop nan
df.isnull().mean()
# Out:
# UniqueID                0.000000
# bigAccountId            0.000000
# bigDebtorId             0.000000
# bitDebtor               0.000000
# dtmStampCreation        0.000000
# dtmFunded               0.000000
# bitDefault              0.000000
# MonthOnBooks            0.000000
# RunningNetLoss          0.000000
# AmtFinanced             0.000000
# intOpenBKType           0.580322
# intTerm                 0.000000
# VehicleYear             0.000000
# bitNew                  0.000798
# VehicleMake             0.000000
# Miles_Odometer          0.000010
# BookValue               0.000000
# fltDownCash             0.000000
# fltApprovedDownTotal    0.013412
# Payment                 0.000000
# DTI                     0.000122
# PTI                     0.000000
# bitServiceContract      0.000000
# fltAdvance              0.000000
# strVehicleType          0.000041
# bitGap                  0.000000
# DealerStampCreation     0.000000
# dtype: float64

# %% [markdown]
# ### Lower column names and add suffix

# %%
# %%time

# list_cols = [
# ]

# # subset
# df = df[list_cols]

# lower columns
df.columns = [f'{col.lower()}__app' for col in df.columns]

# show
df
# Out:
# Wall time: 1 ms
#           uniqueid__app  bigaccountid__app  bigdebtorid__app  bitdebtor__app  \
# 0       133751117564401            1337511           1756440               1
# 1       133756117565081            1337561           1756508               1
# 2       133770217566931            1337702           1756693               1
# 3       133788617569361            1337886           1756936               1
# 4       133789717569521            1337897           1756952               1
# ...                 ...                ...               ...             ...
# 196834  481138661285821            4811386           6128583               0
# 196835  481150161287221            4811501           6128723               0
# 196836  481157161288091            4811571           6128810               0
# 196837  481178461290801            4811784           6129081               0
# 196838  481249861299931            4812498           6129994               0
#
#          dtmstampcreation__app dtmfunded__app  bitdefault__app  \
# 0      2013-10-01 07:28:54.833     2013-10-30                1
# 1      2013-10-01 09:00:08.383     2013-10-22                0
# 2      2013-10-01 10:35:41.517     2013-10-14                0
# 3      2013-10-01 12:21:07.203     2013-10-09                0
# 4      2013-10-01 12:29:28.650     2013-10-16                0
# ...                        ...            ...              ...
# 196834 2019-12-31 07:56:11.937     2020-02-18                0
# 196835 2019-12-31 09:10:49.117     2020-01-08                0
# 196836 2019-12-31 09:43:20.773     2020-01-31                0
# 196837 2019-12-31 11:14:46.693     2020-01-09                0
# 196838 2019-12-31 16:09:44.410     2020-01-13                0
#
#        monthonbooks__app  runningnetloss__app  amtfinanced__app  ...  \
# 0                     72             -1423.19          14532.90  ...
# 1                     72                 0.00          16095.80  ...
# 2                     72                 0.00          20568.71  ...
# 3                     72                 0.00          18307.12  ...
# 4                     72                 0.00          23968.40  ...
# ...                  ...                  ...               ...  ...
# 196834                44                 0.00          22631.56  ...
# 196835                45                 0.00          20024.75  ...
# 196836                45                 0.00          15796.96  ...
# 196837                45                 0.00          21666.29  ...
# 196838                45                 0.00          21007.00  ...
#
#         fltdowncash__app  fltapproveddowntotal__app  payment__app  dti__app  \
# 0                 2000.0                     2000.0        398.83  0.229354
# 1                 2281.0                      500.0        349.06  0.467034
# 2                    0.0                        0.0        448.99  0.425978
# 3                    0.0                      800.0        410.00  0.361873
# 4                    0.0                        0.0        493.76  0.498550
# ...                  ...                        ...           ...       ...
# 196834            1000.0                     1000.0        527.34  0.371485
# 196835             500.0                      500.0        454.07  0.300602
# 196836               0.0                        0.0        344.86  0.280712
# 196837            1000.0                     1000.0        443.03  0.271795
# 196838               0.0                        0.0        509.16  0.255062
#
#         pti__app  bitservicecontract__app  fltadvance__app  \
# 0       0.052130                        1         1.106635
# 1       0.109700                        1         1.050962
# 2       0.102261                        0         1.151824
# 3       0.057743                        0         1.198959
# 4       0.137717                        0         1.175853
# ...          ...                      ...              ...
# 196834  0.053058                        0         1.058707
# 196835  0.063171                        1         1.234773
# 196836  0.100332                        1         1.221195
# 196837  0.068680                        0         1.106953
# 196838  0.068108                        1         1.210836
#
#         strvehicletype__app  bitgap__app  dealerstampcreation__app
# 0                      auto            0   2012-06-18 09:31:54.393
# 1                      auto            1   2012-09-05 09:13:41.740
# 2                       suv            0   2012-02-10 13:48:47.720
# 3                       suv            0   2012-11-30 14:09:02.010
# 4                       suv            0   2012-09-05 09:13:41.740
# ...                     ...          ...                       ...
# 196834                  suv            0   2018-11-21 11:01:46.307
# 196835                  suv            0   2009-06-11 17:08:59.937
# 196836                 auto            1   2019-08-09 13:53:46.860
# 196837                 auto            1   2015-01-21 14:44:01.150
# 196838                 auto            1   2009-12-28 16:59:42.413
#
# [196839 rows x 27 columns]

# %% [markdown]
# ### Save

# %%
# %%time

# save
str_filename = 'df_target_lgd.csv'
str_local_path = f'{str_dirname_output}/{str_filename}'
df.to_csv(str_local_path, index=False)
# Out:
# Wall time: 8.16 s

# %% [markdown]
# ## Upload to s3

# %%
# upload
upload_to_s3(
    aws_access_key_id=AWS_ACCESS_KEY_ID, 
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY, 
    str_local_path=str_local_path, 
    str_bucket_key=f'ad_hoc/target_lgd/{str_filename}', 
    str_bucket_name=str_project,
)

# %% [markdown]
# ## Clean-up

# %%
os.remove(str_local_path)
