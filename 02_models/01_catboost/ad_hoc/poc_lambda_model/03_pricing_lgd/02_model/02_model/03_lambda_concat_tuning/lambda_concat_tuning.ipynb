# %%
import os
import boto3
from sagemaker import get_execution_role
import shutil
from pprint import pprint
import time
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %% [markdown]
# ### Constants

# %%
# function name
str_function_name = 'genxii-lgd-concat-tuning-2'

# %% [markdown]
# ### 1. Create container

# %% [markdown]
# ### Create ```Dockerfile```

# %%
# %%writefile Dockerfile
#
# FROM public.ecr.aws/lambda/python:3.8
#
# # update pip
# RUN pip install --upgrade pip
#
# # install dependencies from project folder
# COPY requirements.txt  .
# RUN  pip3 install -r requirements.txt --target "${LAMBDA_TASK_ROOT}"
#
# # copy function code
# COPY lambda_function.py ${LAMBDA_TASK_ROOT}
#
# # Set the CMD to your handler (could also be done as a parameter override outside of the Dockerfile)
# CMD ["lambda_function.lambda_handler"]
# Out:
# Writing Dockerfile

# %% [markdown]
# ### Write ```requirements.txt```

# %%
# %%writefile requirements.txt
#
# pyarrow==9.0.0
# fsspec==2022.10.0
# s3fs==2022.10.0
# pandas==1.2.4
# boto3==1.24.59
# Out:
# Writing requirements.txt

# %% [markdown]
# ### Write ```lambda_function.py```

# %%
# %%writefile lambda_function.py

import pandas as pd
import boto3

# lambda handler
def lambda_handler(event, context):
    # constants
    str_project = '20231010-gen-xii'
    str_prefix = '03_pricing_lgd/02_model/02_model/02_batch_tuning/models'
    
    # get df_hyperparameters
    str_filename = 'df_hyperparameters.csv'
    str_uri = f's3://{str_project}/03_pricing_lgd/02_model/02_model/12_step_function/{str_filename}'
    df = pd.read_csv(str_uri)
    # convert to dict
    dict_hyperparameters = dict(zip(df['keys'], df['values']))
    
    # get eval metric
    str_eval_metric = dict_hyperparameters['STR_EVAL_METRIC']
    print(f'Eval metric: {str_eval_metric}')
            
    # get index files in s3
    print('Getting files in s3...')
    cls_client = boto3.resource('s3')
    cls_bucket = cls_client.Bucket(str_project)
    list_str_filenames = []
    for file in cls_bucket.objects.filter(Prefix=str_prefix):
        # get key
        str_key = file.key
        # make sure it is a .csv
        if '.csv' in str_key:
            # get filename
            str_filename = str_key.split('/')[-1]
            list_str_filenames.append(str_filename)
    print(f'There are {len(list_str_filenames)} files to import')
    
    # iterate and import
    print('Importing files...')
    list_df = []
    for str_filename in list_str_filenames:
        str_uri = f's3://{str_project}/{str_prefix}/{str_filename}'
        df = pd.read_csv(str_uri)
        list_df.append(df)
    
    # create df
    print('Creating data frame...')
    df = pd.concat(list_df)
    del list_df
    
    # logic for sorting
    print('Sorting...')
    if str_eval_metric in ['AUC', 'PRAUC', 'F1']:
        bool_ascending = False
    else:
        bool_ascending = True # works for RMSE
    df.sort_values(by='flt_eval_metric_valid', ascending=bool_ascending, inplace=True)
    
    # write to s3
    print('Writing to s3...')
    str_filename = 'df_tuning.csv'
    str_uri = f's3://{str_project}/03_pricing_lgd/02_model/02_model/03_lambda_concat_tuning/{str_filename}'
    df.to_csv(str_uri, index=False)
# Out:
# Writing lambda_function.py

# %% [markdown]
# ### Build image and push to ECR

# %%
# %%sh
#
# # name the image
# image=genxii-lgd-concat-tuning-2
#
# # build image
# docker build -t ${image} .
#
# # get region
# region=$(aws configure get region)
# region=${region:-us-west-2}
#
# # get account
# account=$(aws sts get-caller-identity --query Account --output text)
#
# # get full name
# fullname="${account}.dkr.ecr.${region}.amazonaws.com/${image}:latest"
#
# # get login command and execute it
# aws ecr get-login-password --region "${region}" | docker login --username AWS --password-stdin "${account}".dkr.ecr."${region}".amazonaws.com
#
# # create repository in ECR
# aws ecr create-repository --repository-name "${image}" --image-scanning-configuration scanOnPush=true --image-tag-mutability MUTABLE
#
# # tag image
# docker tag  ${image} ${fullname}
#
# # push image to ECR
# docker push ${fullname}
# Out:
# Sending build context to Docker daemon  16.38kB
# Step 1/6 : FROM public.ecr.aws/lambda/python:3.8
#  ---> 54a294f880ad
# Step 2/6 : RUN pip install --upgrade pip
#  ---> Using cache
#  ---> 96a84c45543c
# Step 3/6 : COPY requirements.txt  .
#  ---> Using cache
#  ---> 7e3a3bbc4bf2
# Step 4/6 : RUN  pip3 install -r requirements.txt --target "${LAMBDA_TASK_ROOT}"
#  ---> Using cache
#  ---> 7e9d691f00f7
# Step 5/6 : COPY lambda_function.py ${LAMBDA_TASK_ROOT}
#  ---> 05d40adcf978
# Step 6/6 : CMD ["lambda_function.lambda_handler"]
#  ---> Running in 7085414396b6
# Removing intermediate container 7085414396b6
#  ---> 9242884011d5
# Successfully built 9242884011d5
# Successfully tagged genxii-lgd-concat-tuning-2:latest
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
# Login Succeeded
# {
#     "repository": {
#         "repositoryArn": "arn:aws:ecr:us-west-2:836690756591:repository/genxii-lgd-concat-tuning-2",
#         "registryId": "836690756591",
#         "repositoryName": "genxii-lgd-concat-tuning-2",
#         "repositoryUri": "836690756591.dkr.ecr.us-west-2.amazonaws.com/genxii-lgd-concat-tuning-2",
#         "createdAt": 1697728308.0,
#         "imageTagMutability": "MUTABLE",
#         "imageScanningConfiguration": {
#             "scanOnPush": true
#         },
#         "encryptionConfiguration": {
#             "encryptionType": "AES256"
#         }
#     }
# }
# The push refers to repository [836690756591.dkr.ecr.us-west-2.amazonaws.com/genxii-lgd-concat-tuning-2]
# 89d97a9800ac: Preparing
# b2808624fb74: Preparing
# 50c77eb61941: Preparing
# 895fcc9c35e0: Preparing
# 2ae7c19e0b5c: Preparing
# 9e6784b558c3: Preparing
# 89d97a9800ac: Waiting
# 15dd6c63f3a2: Preparing
# 8819b61d0672: Preparing
# 30349c0bf45d: Preparing
# 50c77eb61941: Waiting
# 9e6784b558c3: Waiting
# 91232f425615: Preparing
# 895fcc9c35e0: Waiting
# b2808624fb74: Waiting
# 30349c0bf45d: Waiting
# 2ae7c19e0b5c: Waiting
# 15dd6c63f3a2: Waiting
# 91232f425615: Waiting
# 89d97a9800ac: Pushed
# 50c77eb61941: Pushed
# 895fcc9c35e0: Pushed
# 2ae7c19e0b5c: Pushed
# 15dd6c63f3a2: Pushed
# 8819b61d0672: Pushed
# 30349c0bf45d: Pushed
# b2808624fb74: Pushed
# 9e6784b558c3: Pushed
# 91232f425615: Pushed
# latest: digest: sha256:32356f78c643418fb4adeaf5ec1c5a3adb6a16b04cce4f4b4c1a4dd23706e7df size: 2419

# %% [markdown]
# ### 2. Create lambda function from image

# %%
# initialize class
cls_client_lambda = boto3.client('lambda')

# %%
# get role
str_role = get_execution_role()
print(f'Role: {str_role}')
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# Role: arn:aws:iam::836690756591:role/risk-ops-role

# %%
# delete it if it exists
try:
    dict_response = cls_client_lambda.delete_function(
        FunctionName=str_function_name,
    )
    pprint(dict_response)
except:
    pass

# %%
# create function
str_image_uri = '836690756591.dkr.ecr.us-west-2.amazonaws.com/genxii-lgd-concat-tuning-2:latest' # this must match what we name the image above
dict_response = cls_client_lambda.create_function(
    FunctionName=str_function_name,
    Role=str_role,
    Code={
        'ImageUri': str_image_uri,
    },
    Timeout=60,
    MemorySize=512,
    Publish=True,
    PackageType='Image',
    Architectures=[
        'x86_64',
    ],
    EphemeralStorage={
        'Size': 512,
    },
)
pprint(dict_response)
time.sleep(40)
# Out:
# {'Architectures': ['x86_64'],
#  'CodeSha256': '32356f78c643418fb4adeaf5ec1c5a3adb6a16b04cce4f4b4c1a4dd23706e7df',
#  'CodeSize': 0,
#  'Description': '',
#  'EphemeralStorage': {'Size': 512},
#  'FunctionArn': 'arn:aws:lambda:us-west-2:836690756591:function:genxii-lgd-concat-tuning-2',
#  'FunctionName': 'genxii-lgd-concat-tuning-2',
#  'LastModified': '2023-10-19T15:12:26.790+0000',
#  'MemorySize': 512,
#  'PackageType': 'Image',
#  'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                       'content-length': '1072',
#                                       'content-type': 'application/json',
#                                       'date': 'Thu, 19 Oct 2023 15:12:27 GMT',
#                                       'x-amzn-requestid': '81b7ccac-c017-46bd-a6e3-480b04742676'},
#                       'HTTPStatusCode': 201,
#                       'RequestId': '81b7ccac-c017-46bd-a6e3-480b04742676',
#                       'RetryAttempts': 0},
#  'RevisionId': 'a9ca563d-6dbc-48f8-b6bc-bed2cb778792',
#  'Role': 'arn:aws:iam::836690756591:role/risk-ops-role',
#  'SnapStart': {'ApplyOn': 'None', 'OptimizationStatus': 'Off'},
#  'State': 'Pending',
#  'StateReason': 'The function is being created.',
#  'StateReasonCode': 'Creating',
#  'Timeout': 60,
#  'TracingConfig': {'Mode': 'PassThrough'},
#  'Version': '1'}

# %% [markdown]
# ### Clean-up

# %%
for str_file in ['Dockerfile', 'lambda_function.py', 'requirements.txt']:
    os.remove(str_file)
