# %%
import os
import boto3
from sagemaker import get_execution_role
import time
from pprint import pprint
import shutil
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %% [markdown]
# ### Constants

# %%
# name
str_function_name = 'genxii-pd-update-feats'

# %% [markdown]
# ### 1. Create container

# %% [markdown]
# ### Create ```Dockerfile```

# %%
# %%writefile Dockerfile
#
# FROM public.ecr.aws/lambda/python:3.8
#
# # update pip
# RUN pip install --upgrade pip
#
# # install dependencies from project folder
# COPY requirements.txt  .
# RUN  pip3 install -r requirements.txt --target "${LAMBDA_TASK_ROOT}"
#
# # copy function code
# COPY lambda_function.py ${LAMBDA_TASK_ROOT}
#
# # Set the CMD to your handler (could also be done as a parameter override outside of the Dockerfile)
# CMD ["lambda_function.lambda_handler"]
# Out:
# Writing Dockerfile

# %% [markdown]
# ### Write ```requirements.txt```

# %%
# %%writefile requirements.txt
#
# pyarrow==9.0.0
# fsspec==2022.10.0
# s3fs==2022.10.0
#
# pandas==1.2.4
# Out:
# Writing requirements.txt

# %% [markdown]
# ### Write ```lambda_function.py```

# %%
# %%writefile lambda_function.py

import pandas as pd

# lambda handler
def lambda_handler(event, context):
    # constants
    str_project = '20231010-gen-xii'
    
    # load output from concat sensitivity
    print('Loading output from sensitivity analysis concatenation...')
    str_filename = 'df_sensitivity.csv'
    str_uri = f's3://{str_project}/02_pricing_pd/02_model/02_model/05_lambda_concat_sensitivity/{str_filename}'
    df = pd.read_csv(str_uri)
    
    # get the top feature
    print('Getting feature that helps the model most once removed...')
    str_col = df['feature'].iloc[0]
    
    # import the features to drop
    print('Importing features to drop...')
    str_filename = 'df_feats_to_drop.csv'
    str_uri = f's3://{str_project}/02_pricing_pd/02_model/02_model/01_lambda_get_starting_feats/{str_filename}'
    list_cols_drop = list(pd.read_csv(str_uri)['feature'])
    
    # append
    print(f'Appending {str_col} to {str_uri}...')
    list_cols_drop.append(str_col)
    
    # create df and upload to s3
    print(f'Creating data frame and uploading to {str_uri}...')
    df = pd.DataFrame({'feature': list_cols_drop})
    df.to_csv(str_uri, index=False)
# Out:
# Writing lambda_function.py

# %% [markdown]
# ### Build image and push to ECR

# %%
# %%sh
#
# # name the image
# image=genxii-pd-update-feats
#
# # build image
# docker build -t ${image} .
#
# # get region
# region=$(aws configure get region)
# region=${region:-us-west-2}
#
# # get account
# account=$(aws sts get-caller-identity --query Account --output text)
#
# # get full name
# fullname="${account}.dkr.ecr.${region}.amazonaws.com/${image}:latest"
#
# # get login command and execute it
# aws ecr get-login-password --region "${region}" | docker login --username AWS --password-stdin "${account}".dkr.ecr."${region}".amazonaws.com
#
# # create repository in ECR
# aws ecr create-repository --repository-name "${image}" --image-scanning-configuration scanOnPush=true --image-tag-mutability MUTABLE
#
# # tag image
# docker tag  ${image} ${fullname}
#
# # push image to ECR
# docker push ${fullname}
# Out:
# Sending build context to Docker daemon  23.04kB
# Step 1/6 : FROM public.ecr.aws/lambda/python:3.8
#  ---> 54a294f880ad
# Step 2/6 : RUN pip install --upgrade pip
#  ---> Using cache
#  ---> bccff1672d23
# Step 3/6 : COPY requirements.txt  .
#  ---> Using cache
#  ---> b77ffae33534
# Step 4/6 : RUN  pip3 install -r requirements.txt --target "${LAMBDA_TASK_ROOT}"
#  ---> Using cache
#  ---> 3c857bab572f
# Step 5/6 : COPY lambda_function.py ${LAMBDA_TASK_ROOT}
#  ---> 526ba874f2ad
# Step 6/6 : CMD ["lambda_function.lambda_handler"]
#  ---> Running in ba47b85affdf
# Removing intermediate container ba47b85affdf
#  ---> 7637a2bf41d6
# Successfully built 7637a2bf41d6
# Successfully tagged genxii-pd-update-feats:latest
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
# Login Succeeded
# {
#     "repository": {
#         "repositoryArn": "arn:aws:ecr:us-west-2:836690756591:repository/genxii-pd-update-feats",
#         "registryId": "836690756591",
#         "repositoryName": "genxii-pd-update-feats",
#         "repositoryUri": "836690756591.dkr.ecr.us-west-2.amazonaws.com/genxii-pd-update-feats",
#         "createdAt": 1697670727.0,
#         "imageTagMutability": "MUTABLE",
#         "imageScanningConfiguration": {
#             "scanOnPush": true
#         },
#         "encryptionConfiguration": {
#             "encryptionType": "AES256"
#         }
#     }
# }
# The push refers to repository [836690756591.dkr.ecr.us-west-2.amazonaws.com/genxii-pd-update-feats]
# 5d61e2a7d6fb: Preparing
# b8c8ad51044b: Preparing
# e0db9f1fa528: Preparing
# 00e37b3ec5b7: Preparing
# 2ae7c19e0b5c: Preparing
# 9e6784b558c3: Preparing
# 15dd6c63f3a2: Preparing
# 8819b61d0672: Preparing
# 30349c0bf45d: Preparing
# 91232f425615: Preparing
# 9e6784b558c3: Waiting
# 30349c0bf45d: Waiting
# 91232f425615: Waiting
# 15dd6c63f3a2: Waiting
# 8819b61d0672: Waiting
# 5d61e2a7d6fb: Pushed
# e0db9f1fa528: Pushed
# 00e37b3ec5b7: Pushed
# 15dd6c63f3a2: Pushed
# 8819b61d0672: Pushed
# 30349c0bf45d: Pushed
# 2ae7c19e0b5c: Pushed
# 9e6784b558c3: Pushed
# b8c8ad51044b: Pushed
# 91232f425615: Pushed
# latest: digest: sha256:7bf3c37a88242c6cd5b69cbd7949c7acf02a3296dcc792764c0e49b8cf99d9e7 size: 2419

# %% [markdown]
# ### 2. Create lambda function from image

# %%
# initialize class
cls_client_lambda = boto3.client('lambda')

# %%
# get role
str_role = get_execution_role()
print(f'Role: {str_role}')
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# Role: arn:aws:iam::836690756591:role/risk-ops-role

# %%
# delete it if it exists
try:
    dict_response = cls_client_lambda.delete_function(
        FunctionName=str_function_name,
    )
    pprint(dict_response)
except:
    pass

# %%
# create function
str_image_uri = '836690756591.dkr.ecr.us-west-2.amazonaws.com/genxii-pd-update-feats:latest' # this must match what we name the image above
dict_response = cls_client_lambda.create_function(
    FunctionName=str_function_name,
    Role=str_role,
    Code={
        'ImageUri': str_image_uri,
    },
    Timeout=60,
    MemorySize=512,
    Publish=True,
    PackageType='Image',
    Architectures=[
        'x86_64',
    ],
    EphemeralStorage={
        'Size': 512,
    },
)
pprint(dict_response)
time.sleep(40)
# Out:
# {'Architectures': ['x86_64'],
#  'CodeSha256': '7bf3c37a88242c6cd5b69cbd7949c7acf02a3296dcc792764c0e49b8cf99d9e7',
#  'CodeSize': 0,
#  'Description': '',
#  'EphemeralStorage': {'Size': 512},
#  'FunctionArn': 'arn:aws:lambda:us-west-2:836690756591:function:genxii-pd-update-feats',
#  'FunctionName': 'genxii-pd-update-feats',
#  'LastModified': '2023-10-18T23:12:48.127+0000',
#  'MemorySize': 512,
#  'PackageType': 'Image',
#  'ResponseMetadata': {'HTTPHeaders': {'connection': 'keep-alive',
#                                       'content-length': '1064',
#                                       'content-type': 'application/json',
#                                       'date': 'Wed, 18 Oct 2023 23:12:49 GMT',
#                                       'x-amzn-requestid': 'c87f3869-0a0d-4708-ad40-395a43ea8876'},
#                       'HTTPStatusCode': 201,
#                       'RequestId': 'c87f3869-0a0d-4708-ad40-395a43ea8876',
#                       'RetryAttempts': 0},
#  'RevisionId': '3fc60fbb-d673-4e12-9e9c-0c77a6ba5c9c',
#  'Role': 'arn:aws:iam::836690756591:role/risk-ops-role',
#  'SnapStart': {'ApplyOn': 'None', 'OptimizationStatus': 'Off'},
#  'State': 'Pending',
#  'StateReason': 'The function is being created.',
#  'StateReasonCode': 'Creating',
#  'Timeout': 60,
#  'TracingConfig': {'Mode': 'PassThrough'},
#  'Version': '1'}

# %% [markdown]
# ### Clean-up

# %%
for str_file in ['Dockerfile', 'lambda_function.py', 'requirements.txt']:
    os.remove(str_file)
