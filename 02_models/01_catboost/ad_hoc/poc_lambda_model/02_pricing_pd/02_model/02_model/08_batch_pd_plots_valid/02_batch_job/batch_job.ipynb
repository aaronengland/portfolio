# %%
import boto3
import math
from sagemaker import get_execution_role
from pprint import pprint
import time
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %% [markdown]
# ### Functions

# %%
def get_specs(str_instance):
    if str_instance == 'm5.large':
        int_vcpu = 2
        int_memory_gb = 8
    elif str_instance == 'm5.xlarge':
        int_vcpu = 4
        int_memory_gb = 16
    elif str_instance == 'm5.2xlarge':
        int_vcpu = 8
        int_memory_gb = 32
    elif str_instance == 'm5.4xlarge':
        int_vcpu = 16
        int_memory_gb = 64
    elif str_instance == 'm5.8xlarge':
        int_vcpu = 32
        int_memory_gb = 128
    elif str_instance == 'm5.12xlarge':
        int_vcpu = 48
        int_memory_gb = 192
    int_memory_mebibytes = math.ceil(int_memory_gb * 953.674)
    dict_output = {
        'int_vcpu': int_vcpu,
        'int_memory_gb': int_memory_gb,
        'int_memory_mebibytes': int_memory_mebibytes,
    }
    return dict_output

# %% [markdown]
# ### Constants

# %%
str_image_name = 'genxii-pd-plots-valid'
int_iteration = 1
str_instance = 'm5.large'
dict_specs = get_specs(str_instance=str_instance)
int_vcpu = dict_specs['int_vcpu']
int_memory_gb = dict_specs['int_memory_gb']
int_memory_mebibytes = dict_specs['int_memory_mebibytes']
for key, val in dict_specs.items():
    print(f'{key}: {val}')
# Out:
# int_vcpu: 2
# int_memory_gb: 8
# int_memory_mebibytes: 7630

# %% [markdown]
# ### Create compute environment

# %%
# initialize class
cls_client = boto3.client('batch')

# %%
# get role
str_role = get_execution_role()
print(f'Role: {str_role}')
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# Role: arn:aws:iam::836690756591:role/risk-ops-role

# %%
# create compute environment
while True:
    try:
        str_compute_env_name = f'env-{str_image_name}-{int_iteration}'
        dict_response = cls_client.create_compute_environment(
            computeEnvironmentName=str_compute_env_name,
            type= 'Managed', 
            state= 'ENABLED',
            serviceRole = str_role,
            computeResources={
                #'type': 'SPOT',
                'type': 'EC2',
                'minvCpus': 0,
                'maxvCpus': 256, 
                'desiredvCpus': int_vcpu,
                'instanceTypes': [
                    str_instance,
                ], 
                'subnets': ['subnet-044e573651bb251a7'], 
                'securityGroupIds': ['sg-03904237048cdc335'], 
                'instanceRole': 'ecsInstanceRole',
                #'spotIamFleetRole': 'AmazonEC2SpotFleetTaggingRole',
            },
        )
        pprint(dict_response)
        break
    except:
        int_iteration += 1
# Out:
# {'ResponseMetadata': {'HTTPHeaders': {'access-control-allow-origin': '*',
#                                       'access-control-expose-headers': 'X-amzn-errortype,X-amzn-requestid,X-amzn-errormessage,X-amzn-trace-id,X-amz-apigw-id,date',
#                                       'connection': 'keep-alive',
#                                       'content-length': '167',
#                                       'content-type': 'application/json',
#                                       'date': 'Thu, 26 Oct 2023 18:32:49 GMT',
#                                       'x-amz-apigw-id': 'NbCQyEe1vHcEaxQ=',
#                                       'x-amzn-requestid': '048a1f44-b62a-4b95-937d-4747d82634ec',
#                                       'x-amzn-trace-id': 'Root=1-653ab0d1-2e93bb1a40c073e0289dd721'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '048a1f44-b62a-4b95-937d-4747d82634ec',
#                       'RetryAttempts': 0},
#  'computeEnvironmentArn': 'arn:aws:batch:us-west-2:836690756591:compute-environment/env-genxii-pd-plots-valid-1',
#  'computeEnvironmentName': 'env-genxii-pd-plots-valid-1'}

# %% [markdown]
# ### Create Job Queue

# %%
# create job queue (this is where AWS will store your jobs until an EC2 Instance is available to run them)
while True:
    try:
        str_job_queue_name = f'queue-{str_image_name}-{int_iteration}'
        dict_response = cls_client.create_job_queue(
            jobQueueName=str_job_queue_name,
            state='ENABLED',
            priority=1,
            computeEnvironmentOrder=[
                {
                    'order': 1,
                    'computeEnvironment': str_compute_env_name,
                },
            ]
        )
        # get arn
        str_job_queue_arn = dict_response['jobQueueArn']
        pprint(dict_response)
        break
    except:
        time.sleep(1)
# Out:
# {'ResponseMetadata': {'HTTPHeaders': {'access-control-allow-origin': '*',
#                                       'access-control-expose-headers': 'X-amzn-errortype,X-amzn-requestid,X-amzn-errormessage,X-amzn-trace-id,X-amz-apigw-id,date',
#                                       'connection': 'keep-alive',
#                                       'content-length': '141',
#                                       'content-type': 'application/json',
#                                       'date': 'Thu, 26 Oct 2023 18:32:55 GMT',
#                                       'x-amz-apigw-id': 'NbCRpHxCvHcEgZg=',
#                                       'x-amzn-requestid': '0b866b77-6772-41b1-a2ad-e71ceaca6f4a',
#                                       'x-amzn-trace-id': 'Root=1-653ab0d7-30f8c2f11b772ddf658656ef'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '0b866b77-6772-41b1-a2ad-e71ceaca6f4a',
#                       'RetryAttempts': 0},
#  'jobQueueArn': 'arn:aws:batch:us-west-2:836690756591:job-queue/queue-genxii-pd-plots-valid-1',
#  'jobQueueName': 'queue-genxii-pd-plots-valid-1'}

# %% [markdown]
# ### Register job definition

# %%
# job definition
while True:
    try:
        str_job_definition = f'job-def-{str_image_name}-{int_iteration}'
        dict_response = cls_client.register_job_definition(
            type='container',
            containerProperties={
                'image': f'836690756591.dkr.ecr.us-west-2.amazonaws.com/{str_image_name}:latest',
                'memory': int_memory_mebibytes,
                'vcpus': int_vcpu,
            },
            jobDefinitionName=str_job_definition,
        )
        # get arn
        str_job_def_arn = dict_response['jobDefinitionArn']
        pprint(dict_response)
        break
    except:
        time.sleep(1)
# Out:
# {'ResponseMetadata': {'HTTPHeaders': {'access-control-allow-origin': '*',
#                                       'access-control-expose-headers': 'X-amzn-errortype,X-amzn-requestid,X-amzn-errormessage,X-amzn-trace-id,X-amz-apigw-id,date',
#                                       'connection': 'keep-alive',
#                                       'content-length': '175',
#                                       'content-type': 'application/json',
#                                       'date': 'Thu, 26 Oct 2023 18:32:55 GMT',
#                                       'x-amz-apigw-id': 'NbCRqE91vHcEuvg=',
#                                       'x-amzn-requestid': 'f38ca4ad-ad2d-41b0-9b62-d667d38b56d7',
#                                       'x-amzn-trace-id': 'Root=1-653ab0d7-44eed84d001fe51f713c92c6'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'f38ca4ad-ad2d-41b0-9b62-d667d38b56d7',
#                       'RetryAttempts': 0},
#  'jobDefinitionArn': 'arn:aws:batch:us-west-2:836690756591:job-definition/job-def-genxii-pd-plots-valid-1:3',
#  'jobDefinitionName': 'job-def-genxii-pd-plots-valid-1',
#  'revision': 3}

# %% [markdown]
# ### Submit job

# %%
# # submit a job (only for testing)
# while True:
#     try:
#         str_job_name = f'job-name-{str_image_name}-{int_iteration}'
#         response = cls_client.submit_job(
#             jobDefinition=str_job_definition,
#             jobQueue=str_job_queue_name,
#             jobName=str_job_name,
#         )
#         pprint(response)
#         break
#     except:
#         time.sleep(1)

# %% [markdown]
# ### Show arns

# %%
print(f'Job Queue ARN: {str_job_queue_arn}')
print(f'Job Definition ARN: {str_job_def_arn}')
# Out:
# Job Queue ARN: arn:aws:batch:us-west-2:836690756591:job-queue/queue-genxii-pd-plots-valid-1
# Job Definition ARN: arn:aws:batch:us-west-2:836690756591:job-definition/job-def-genxii-pd-plots-valid-1:3
