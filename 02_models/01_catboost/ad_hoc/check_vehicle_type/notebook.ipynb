# %%
import pandas as pd

# %%
str_uri = 's3://20231010-gen-xii/02_pricing_pd/01_data_prep/05_leaky_features/04_write_dfs/df_train_noleaks.gzip'
list_cols = [
    'strvehicletype__app',
    'miles_odometer__app',
]
df = pd.read_parquet(str_uri, columns=list_cols)
df
# Out:
#       strvehicletype__app  miles_odometer__app
# 0                    auto              46429.0
# 1                    auto              46429.0
# 2                    auto              58628.0
# 3                    auto              58628.0
# 4                    auto              29855.0
# ...                   ...                  ...
# 74584                 suv              38155.0
# 74585                auto              29703.0
# 74586                auto              29703.0
# 74587                auto              47377.0
# 74588                auto              46294.0
#
# [74589 rows x 2 columns]

# %%
df['strvehicletype__app'].value_counts()
# Out:
# strvehicletype__app
# auto     56680
# suv      13563
# van       2258
# truck     2082
# Name: count, dtype: int64

# %%
df['miles_odometer__app'].value_counts()
# Out:
# miles_odometer__app
# 10.0       360
# 5.0        318
# 12.0       235
# 15.0       228
# 11.0       201
#           ...
# 53493.0      1
# 29434.0      1
# 65828.0      1
# 36868.0      1
# 46294.0      1
# Name: count, Length: 38453, dtype: int64
