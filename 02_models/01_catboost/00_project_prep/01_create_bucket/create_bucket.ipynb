# %% [markdown]
# # Create Bucket

# %%
import os
import boto3

# %% [markdown]
# ## Constants

# %%
str_project = os.getcwd().split('/')[-3].replace('_','-')
print(f'Project: {str_project}')
# Out:
# Project: 20231010-gen-xii

# %% [markdown]
# ## Get region

# %%
# region
str_region = boto3.client('s3').meta.region_name
print(f'Region: {str_region}')
# Out:
# Region: us-west-2

# %% [markdown]
# ## Create bucket

# %%
# initialize class
cls_client = boto3.client('s3')

# config dictionary
dict_config = {
    'LocationConstraint': str_region,
}

# create bucket
cls_client.create_bucket(
    ACL='private',
    Bucket=str_project,
    CreateBucketConfiguration=dict_config,
)
# Out:
# {'ResponseMetadata': {'RequestId': 'BYS0Z3R24TCMA45M',
#   'HostId': 'CqHuYA0uH20y0WonFUb1yeDb3GDAaEH2by7x4Z+Loqm6LAFWhnN7E3d6N0FXFl6yAnh4lJo//9CumUh50Czpsg==',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'CqHuYA0uH20y0WonFUb1yeDb3GDAaEH2by7x4Z+Loqm6LAFWhnN7E3d6N0FXFl6yAnh4lJo//9CumUh50Czpsg==',
#    'x-amz-request-id': 'BYS0Z3R24TCMA45M',
#    'date': 'Tue, 10 Oct 2023 17:19:05 GMT',
#    'location': 'http://20231010-gen-xii.s3.amazonaws.com/',
#    'server': 'AmazonS3',
#    'content-length': '0'},
#   'RetryAttempts': 0},
#  'Location': 'http://20231010-gen-xii.s3.amazonaws.com/'}
