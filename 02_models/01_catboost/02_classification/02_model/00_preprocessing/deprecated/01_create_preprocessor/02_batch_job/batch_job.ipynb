# %%
import boto3
import math
from sagemaker import get_execution_role
from pprint import pprint
import time

# %% [markdown]
# ### Functions

# %%
def get_specs(str_instance):
    if str_instance == 'm5.large':
        int_vcpu = 2
        int_memory_gb = 8
    elif str_instance == 'm5.xlarge':
        int_vcpu = 4
        int_memory_gb = 16
    elif str_instance == 'm5.2xlarge':
        int_vcpu = 8
        int_memory_gb = 32
    elif str_instance == 'm5.4xlarge':
        int_vcpu = 16
        int_memory_gb = 64
    elif str_instance == 'm5.8xlarge':
        int_vcpu = 32
        int_memory_gb = 128
    elif str_instance == 'm5.12xlarge':
        int_vcpu = 48
        int_memory_gb = 192
    int_memory_mebibytes = math.ceil(int_memory_gb * 953.674)
    dict_output = {
        'int_vcpu': int_vcpu,
        'int_memory_gb': int_memory_gb,
        'int_memory_mebibytes': int_memory_mebibytes,
    }
    return dict_output

# %% [markdown]
# ### Constants

# %%
str_image_name = 'genxii-ad-preprocessing'
int_iteration = 1
str_instance = 'm5.12xlarge'
dict_specs = get_specs(str_instance=str_instance)
int_vcpu = dict_specs['int_vcpu']
int_memory_gb = dict_specs['int_memory_gb']
int_memory_mebibytes = dict_specs['int_memory_mebibytes']
for key, val in dict_specs.items():
    print(f'{key}: {val}')
# Out:
# int_vcpu: 48
# int_memory_gb: 192
# int_memory_mebibytes: 183106

# %% [markdown]
# ### Create compute environment

# %%
# initialize class
cls_client = boto3.client('batch')

# %%
# get role
str_role = get_execution_role()
print(f'Role: {str_role}')
# Out:
# Role: arn:aws:iam::836690756591:role/risk-ops-role

# %%
# create compute environment
while True:
    try:
        str_compute_env_name = f'env-{str_image_name}-{int_iteration}'
        dict_response = cls_client.create_compute_environment(
            computeEnvironmentName=str_compute_env_name,
            type= 'Managed', 
            state= 'ENABLED',
            serviceRole = str_role,
            computeResources={
                #'type': 'SPOT',
                'type': 'EC2',
                'minvCpus': 0,
                'maxvCpus': 256, 
                'desiredvCpus': int_vcpu,
                'instanceTypes': [
                    str_instance,
                ], 
                'subnets': ['subnet-044e573651bb251a7'], 
                'securityGroupIds': ['sg-03904237048cdc335'], 
                'instanceRole': 'ecsInstanceRole',
                #'spotIamFleetRole': 'AmazonEC2SpotFleetTaggingRole',
            },
        )
        pprint(dict_response)
        break
    except:
        int_iteration += 1
# Out:
# {'ResponseMetadata': {'HTTPHeaders': {'access-control-allow-origin': '*',
#                                       'access-control-expose-headers': 'X-amzn-errortype,X-amzn-requestid,X-amzn-errormessage,X-amzn-trace-id,X-amz-apigw-id,date',
#                                       'connection': 'keep-alive',
#                                       'content-length': '171',
#                                       'content-type': 'application/json',
#                                       'date': 'Wed, 11 Oct 2023 19:50:05 GMT',
#                                       'x-amz-apigw-id': 'MpxhFEwwvHcEWIg=',
#                                       'x-amzn-requestid': 'ddb17bea-74c0-4d1c-8d1d-f9e35fc78785',
#                                       'x-amzn-trace-id': 'Root=1-6526fc6d-690e712246b386106da1d79a'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'ddb17bea-74c0-4d1c-8d1d-f9e35fc78785',
#                       'RetryAttempts': 0},
#  'computeEnvironmentArn': 'arn:aws:batch:us-west-2:836690756591:compute-environment/env-genxii-ad-preprocessing-1',
#  'computeEnvironmentName': 'env-genxii-ad-preprocessing-1'}

# %% [markdown]
# ### Create Job Queue

# %%
# create job queue (this is where AWS will store your jobs until an EC2 Instance is available to run them)
while True:
    try:
        str_job_queue_name = f'queue-{str_image_name}-{int_iteration}'
        dict_response = cls_client.create_job_queue(
            jobQueueName=str_job_queue_name,
            state='ENABLED',
            priority=1,
            computeEnvironmentOrder=[
                {
                    'order': 1,
                    'computeEnvironment': str_compute_env_name,
                },
            ]
        )
        # get arn
        str_job_queue_arn = dict_response['jobQueueArn']
        pprint(dict_response)
        break
    except:
        time.sleep(1)
# Out:
# {'ResponseMetadata': {'HTTPHeaders': {'access-control-allow-origin': '*',
#                                       'access-control-expose-headers': 'X-amzn-errortype,X-amzn-requestid,X-amzn-errormessage,X-amzn-trace-id,X-amz-apigw-id,date',
#                                       'connection': 'keep-alive',
#                                       'content-length': '145',
#                                       'content-type': 'application/json',
#                                       'date': 'Wed, 11 Oct 2023 19:50:11 GMT',
#                                       'x-amz-apigw-id': 'MpxiGHkwvHcEp2A=',
#                                       'x-amzn-requestid': 'cadbcd6e-be8b-4fa7-823c-6de174a0e4fb',
#                                       'x-amzn-trace-id': 'Root=1-6526fc73-48376b5c103688235010bf62'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'cadbcd6e-be8b-4fa7-823c-6de174a0e4fb',
#                       'RetryAttempts': 0},
#  'jobQueueArn': 'arn:aws:batch:us-west-2:836690756591:job-queue/queue-genxii-ad-preprocessing-1',
#  'jobQueueName': 'queue-genxii-ad-preprocessing-1'}

# %% [markdown]
# ### Register job definition

# %%
# job definition
while True:
    try:
        str_job_definition = f'job-def-{str_image_name}-{int_iteration}'
        dict_response = cls_client.register_job_definition(
            type='container',
            containerProperties={
                'image': f'836690756591.dkr.ecr.us-west-2.amazonaws.com/{str_image_name}:latest',
                'memory': int_memory_mebibytes,
                'vcpus': int_vcpu,
            },
            jobDefinitionName=str_job_definition,
        )
        # get arn
        str_job_def_arn = dict_response['jobDefinitionArn']
        pprint(dict_response)
        break
    except:
        time.sleep(1)
# Out:
# {'ResponseMetadata': {'HTTPHeaders': {'access-control-allow-origin': '*',
#                                       'access-control-expose-headers': 'X-amzn-errortype,X-amzn-requestid,X-amzn-errormessage,X-amzn-trace-id,X-amz-apigw-id,date',
#                                       'connection': 'keep-alive',
#                                       'content-length': '179',
#                                       'content-type': 'application/json',
#                                       'date': 'Wed, 11 Oct 2023 19:50:11 GMT',
#                                       'x-amz-apigw-id': 'MpxiHEscvHcEJMQ=',
#                                       'x-amzn-requestid': 'c18df4a1-9748-4978-b09a-093b2bbab9e4',
#                                       'x-amzn-trace-id': 'Root=1-6526fc73-205fc87561295a1542f6d5b0'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'c18df4a1-9748-4978-b09a-093b2bbab9e4',
#                       'RetryAttempts': 0},
#  'jobDefinitionArn': 'arn:aws:batch:us-west-2:836690756591:job-definition/job-def-genxii-ad-preprocessing-1:2',
#  'jobDefinitionName': 'job-def-genxii-ad-preprocessing-1',
#  'revision': 2}

# %% [markdown]
# ### Submit job

# %%
# # submit a job
# while True:
#     try:
#         str_job_name = f'job-name-{str_image_name}-{int_iteration}'
#         response = cls_client.submit_job(
#             jobDefinition=str_job_definition,
#             jobQueue=str_job_queue_name,
#             jobName=str_job_name,
#         )
#         pprint(response)
#         break
#     except:
#         time.sleep(1)

# %% [markdown]
# ### Show arns

# %%
print(f'Job Queue ARN: {str_job_queue_arn}')
print(f'Job Definition ARN: {str_job_def_arn}')
# Out:
# Job Queue ARN: arn:aws:batch:us-west-2:836690756591:job-queue/queue-genxii-ad-preprocessing-1
# Job Definition ARN: arn:aws:batch:us-west-2:836690756591:job-definition/job-def-genxii-ad-preprocessing-1:2
