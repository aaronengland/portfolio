# %%
import boto3
import math
from sagemaker import get_execution_role
from pprint import pprint
import time
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %% [markdown]
# ### Functions

# %%
def get_specs(str_instance):
    if str_instance == 'm5.large':
        int_vcpu = 2
        int_memory_gb = 8
    elif str_instance == 'm5.xlarge':
        int_vcpu = 4
        int_memory_gb = 16
    elif str_instance == 'm5.2xlarge':
        int_vcpu = 8
        int_memory_gb = 32
    elif str_instance == 'm5.4xlarge':
        int_vcpu = 16
        int_memory_gb = 64
    elif str_instance == 'm5.8xlarge':
        int_vcpu = 32
        int_memory_gb = 128
    elif str_instance == 'm5.12xlarge':
        int_vcpu = 48
        int_memory_gb = 192
    int_memory_mebibytes = math.ceil(int_memory_gb * 953.674)
    dict_output = {
        'int_vcpu': int_vcpu,
        'int_memory_gb': int_memory_gb,
        'int_memory_mebibytes': int_memory_mebibytes,
    }
    return dict_output

# %% [markdown]
# ### Constants

# %%
str_image_name = 'genxii-pd-eda'
int_iteration = 1
str_instance = 'm5.large'
dict_specs = get_specs(str_instance=str_instance)
int_vcpu = dict_specs['int_vcpu']
int_memory_gb = dict_specs['int_memory_gb']
int_memory_mebibytes = dict_specs['int_memory_mebibytes']
for key, val in dict_specs.items():
    print(f'{key}: {val}')
# Out:
# int_vcpu: 2
# int_memory_gb: 8
# int_memory_mebibytes: 7630

# %% [markdown]
# ### Create compute environment

# %%
# initialize class
cls_client = boto3.client('batch')

# %%
# get role
str_role = get_execution_role()
print(f'Role: {str_role}')
# Out:
# Role: arn:aws:iam::836690756591:role/risk-ops-role

# %%
# create compute environment
while True:
    try:
        str_compute_env_name = f'env-{str_image_name}-{int_iteration}'
        dict_response = cls_client.create_compute_environment(
            computeEnvironmentName=str_compute_env_name,
            type= 'Managed', 
            state= 'ENABLED',
            serviceRole = str_role,
            computeResources={
                #'type': 'SPOT',
                'type': 'EC2',
                'minvCpus': 0,
                'maxvCpus': 256, 
                'desiredvCpus': int_vcpu,
                'instanceTypes': [
                    str_instance,
                ], 
                'subnets': ['subnet-044e573651bb251a7'], 
                'securityGroupIds': ['sg-03904237048cdc335'], 
                'instanceRole': 'ecsInstanceRole',
                #'spotIamFleetRole': 'AmazonEC2SpotFleetTaggingRole',
            },
        )
        pprint(dict_response)
        break
    except:
        int_iteration += 1
# Out:
# {'ResponseMetadata': {'HTTPHeaders': {'access-control-allow-origin': '*',
#                                       'access-control-expose-headers': 'X-amzn-errortype,X-amzn-requestid,X-amzn-errormessage,X-amzn-trace-id,X-amz-apigw-id,date',
#                                       'connection': 'keep-alive',
#                                       'content-length': '151',
#                                       'content-type': 'application/json',
#                                       'date': 'Mon, 22 Apr 2024 20:51:09 GMT',
#                                       'x-amz-apigw-id': 'WpUVlHQ_PHcEJJA=',
#                                       'x-amzn-requestid': 'd1b6747c-f604-4d58-869e-f9a429fbb649',
#                                       'x-amzn-trace-id': 'Root=1-6626cdbd-1c950edd57272cf418e465c8'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'd1b6747c-f604-4d58-869e-f9a429fbb649',
#                       'RetryAttempts': 0},
#  'computeEnvironmentArn': 'arn:aws:batch:us-west-2:836690756591:compute-environment/env-genxii-pd-eda-1',
#  'computeEnvironmentName': 'env-genxii-pd-eda-1'}

# %% [markdown]
# ### Create job Queue

# %%
# create job queue (this is where AWS will store your jobs until an EC2 Instance is available to run them)
while True:
    try:
        str_job_queue_name = f'queue-{str_image_name}-{int_iteration}'
        dict_response = cls_client.create_job_queue(
            jobQueueName=str_job_queue_name,
            state='ENABLED',
            priority=1,
            computeEnvironmentOrder=[
                {
                    'order': 1,
                    'computeEnvironment': str_compute_env_name,
                },
            ]
        )
        # get arn
        str_job_queue_arn = dict_response['jobQueueArn']
        pprint(dict_response)
        break
    except:
        time.sleep(1)
# Out:
# {'ResponseMetadata': {'HTTPHeaders': {'access-control-allow-origin': '*',
#                                       'access-control-expose-headers': 'X-amzn-errortype,X-amzn-requestid,X-amzn-errormessage,X-amzn-trace-id,X-amz-apigw-id,date',
#                                       'connection': 'keep-alive',
#                                       'content-length': '125',
#                                       'content-type': 'application/json',
#                                       'date': 'Mon, 22 Apr 2024 20:51:25 GMT',
#                                       'x-amz-apigw-id': 'WpUYHGk-PHcErQA=',
#                                       'x-amzn-requestid': 'cc7a2c64-7c80-4aef-b488-b7114ad2d704',
#                                       'x-amzn-trace-id': 'Root=1-6626cdcd-6d5787dd5e72d0635e8dc7b9'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'cc7a2c64-7c80-4aef-b488-b7114ad2d704',
#                       'RetryAttempts': 0},
#  'jobQueueArn': 'arn:aws:batch:us-west-2:836690756591:job-queue/queue-genxii-pd-eda-1',
#  'jobQueueName': 'queue-genxii-pd-eda-1'}

# %% [markdown]
# ### Register job definition

# %%
# job definition
while True:
    try:
        str_job_definition = f'job-def-{str_image_name}-{int_iteration}'
        dict_response = cls_client.register_job_definition(
            type='container',
            containerProperties={
                'image': f'836690756591.dkr.ecr.us-west-2.amazonaws.com/{str_image_name}:latest',
                'memory': int_memory_mebibytes,
                'vcpus': int_vcpu,
            },
            jobDefinitionName=str_job_definition,
        )
        # get arn
        str_job_def_arn = dict_response['jobDefinitionArn']
        pprint(dict_response)
        break
    except:
        time.sleep(1)
# Out:
# {'ResponseMetadata': {'HTTPHeaders': {'access-control-allow-origin': '*',
#                                       'access-control-expose-headers': 'X-amzn-errortype,X-amzn-requestid,X-amzn-errormessage,X-amzn-trace-id,X-amz-apigw-id,date',
#                                       'connection': 'keep-alive',
#                                       'content-length': '159',
#                                       'content-type': 'application/json',
#                                       'date': 'Mon, 22 Apr 2024 20:51:25 GMT',
#                                       'x-amz-apigw-id': 'WpUYHG9rPHcEkUw=',
#                                       'x-amzn-requestid': '5404e428-8ffe-41de-8d6e-752a57479743',
#                                       'x-amzn-trace-id': 'Root=1-6626cdcd-07723a411164a0c901fa6bf1'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '5404e428-8ffe-41de-8d6e-752a57479743',
#                       'RetryAttempts': 0},
#  'jobDefinitionArn': 'arn:aws:batch:us-west-2:836690756591:job-definition/job-def-genxii-pd-eda-1:6',
#  'jobDefinitionName': 'job-def-genxii-pd-eda-1',
#  'revision': 6}

# %% [markdown]
# ### Submit job

# %%
# # submit a job
# while True:
#     try:
#         str_job_name = f'job-name-{str_image_name}-{int_iteration}'
#         response = cls_client.submit_job(
#             jobDefinition=str_job_definition,
#             jobQueue=str_job_queue_name,
#             jobName=str_job_name,
#         )
#         pprint(response)
#         break
#     except:
#         time.sleep(1)

# %% [markdown]
# ### Show arns

# %%
print(f'Job Queue ARN: {str_job_queue_arn}')
print(f'Job Definition ARN: {str_job_def_arn}')
# Out:
# Job Queue ARN: arn:aws:batch:us-west-2:836690756591:job-queue/queue-genxii-pd-eda-1
# Job Definition ARN: arn:aws:batch:us-west-2:836690756591:job-definition/job-def-genxii-pd-eda-1:6
