# %%
import os
import pandas as pd
import functions as func
import numpy as np
from tqdm import tqdm

# %% [markdown]
# ### Constants

# %%
str_project = os.getcwd().split('/')[4].replace('_','-')
print(f'Project: {str_project}')
str_dirname_output = './output'
# Out:
# Project: 20231010-gen-xii

# %% [markdown]
# ### Output

# %%
try:
    os.mkdir(str_dirname_output)
except:
    pass

# %% [markdown]
# ### Empty list

# %%
# %%time

list_cols_all = []
for str_df in tqdm (['train','valid','test']):
    # print
    print(f'Data set: {str_df}')
    print('')
    
    # import
    str_filename = f'df_{str_df}_raw.gzip'
    str_uri = f's3://{str_project}/02_pricing_pd/01_data_prep/03_train_valid_test_split/{str_filename}'
    # read from s3
    df = pd.read_parquet(str_uri)
    # replace
    df.replace(['NaN','nan'], np.nan, inplace=True)
    
    # check all nan
    list_cols = func.find_all_nan_columns(
        df=df,
    )
    list_cols_all.extend(list_cols)
    print(f'There are {len(list_cols)} features in the {str_df} df that are 100% NaN')
    for a, col in enumerate(list_cols):
        print(f'{a+1} - {col}')
    print('')
    
    # check no var
    list_cols = func.find_no_variance_columns(
        df=df,
    )
    list_cols_all.extend(list_cols)
    print(f'There are {len(list_cols)} features in the {str_df} df that have no variance')
    for a, col in enumerate(list_cols):
        print(f'{a+1} - {col}')
    print('')
    
    # check redundancy
    list_cols = func.find_redundant_columns(
        df=df,
    )
    list_cols_all.extend(list_cols)
    print(f'There are {len(list_cols)} features in the {str_df} df that are redundant')
    for a, col in enumerate(list_cols):
        print(f'{a+1} - {col}')
    print('')
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Data set: train
#
# There are 79 features in the train df that are 100% NaN
# 1 - dtmstampcreation__base
# 2 - dtmapproved__base
# 3 - dtmdeclined__base
# 4 - observationdate__base
# 5 - analyticsmatchkey__base
# 6 - decision_dte__base
# 7 - booked__base
# 8 - acct_typ_cde__base
# 9 - open_dte__base
# 10 - curr_bal_amt__base
# 11 - terms_freq_cde__base
# 12 - affil_rem_cde__base
# 13 - cmplnc_rem_cde__base
# 14 - gnrc_rem_cde__base
# 15 - rte_rem_cde__base
# 16 - acct_rte_prfl_cde__base
# 17 - payt_pttrn_txt__base
# 18 - gnrcrem_frsrpt_dte__base
# 19 - obs_arch__base
# 20 - vtg4__base
# 21 - performance__base
# 22 - creditasofdate__tu
# 23 - firstname__tu
# 24 - middlename__tu
# 25 - lastname__tu
# 26 - address1__tu
# 27 - strname__tu
# 28 - state__tu
# 29 - zip5__tu
# 30 - zip4__tu
# 31 - ssn__tu
# 32 - dateofbirth__tu
# 33 - dtmstampcreation__tu
# 34 - observationdate__tu
# 35 - analyticsmatchkey__tu
# 36 - segment__tu
# 37 - indflag__tu
# 38 - iscrhit__tu
# 39 - bctrd__tu
# 40 - insttrd__tu
# 41 - nomttrd__tu
# 42 - revtrd__tu
# 43 - rtltrd__tu
# 44 - bkc231__tu
# 45 - bkc232__tu
# 46 - bkc233__tu
# 47 - bkc234__tu
# 48 - bkc235__tu
# 49 - bkc252__tu
# 50 - bkc253__tu
# 51 - bkc254__tu
# 52 - bkc255__tu
# 53 - bkc201__tu
# 54 - bkc202__tu
# 55 - bkc203__tu
# 56 - bkc204__tu
# 57 - bkc205__tu
# 58 - bkc222__tu
# 59 - bkc223__tu
# 60 - bkc224__tu
# 61 - bkc225__tu
# 62 - bigmileage_odometer__app
# 63 - vehiclemodel__app
# 64 - fltpriceselling__app
# 65 - vehiclepricewholesale__app
# 66 - fltstatesalestax__app
# 67 - permid__tu
# 68 - partyid__tu
# 69 - acctid__tu
# 70 - tuseqeuncenumber__tu
# 71 - bankcard_reason5__ln
# 72 - alert4__ln
# 73 - alert5__ln
# 74 - alert6__ln
# 75 - alert7__ln
# 76 - alert8__ln
# 77 - alert9__ln
# 78 - alert10__ln
# 79 - DPD60PLUS__tucvlink
#
# There are 18 features in the train df that have no variance
# 1 - bitfunded__app
# 2 - fltaddfee__app
# 3 - fltinsureddisabilitypremium__app
# 4 - fltinsuredlifepremium__app
# 5 - fltinsuredunemploymentamount__app
# 6 - fltinsuredunemploymentpremium__app
# 7 - inputprovidedfirstname__ln
# 8 - inputprovidedlastname__ln
# 9 - inputprovidedssn__ln
# 10 - inputprovideddateofbirth__ln
# 11 - inputprovidedlexid__ln
# 12 - short_term_lending_reason5__ln
# 13 - telecommunications_reason5__ln
# 14 - crossindustry_index__ln
# 15 - crossindustry_score_name__ln
# 16 - crossindustry_reason5__ln
# 17 - linkc010__tu
# 18 - monthonbooks__app
#  33%|███▎      | 1/3 [00:12<00:25, 12.80s/it]
# There are 274 features in the train df that are redundant
# 1 - dtmdeclined__base
# 2 - observationdate__base
# 3 - analyticsmatchkey__base
# 4 - booked__base
# 5 - curr_bal_amt__base
# 6 - vtg4__base
# 7 - firstname__tu
# 8 - middlename__tu
# 9 - lastname__tu
# 10 - address1__tu
# 11 - zip5__tu
# 12 - zip4__tu
# 13 - ssn__tu
# 14 - dateofbirth__tu
# 15 - dtmstampcreation__tu
# 16 - observationdate__tu
# 17 - analyticsmatchkey__tu
# 18 - segment__tu
# 19 - indflag__tu
# 20 - iscrhit__tu
# 21 - bctrd__tu
# 22 - insttrd__tu
# 23 - nomttrd__tu
# 24 - revtrd__tu
# 25 - rtltrd__tu
# 26 - bkc231__tu
# 27 - bkc232__tu
# 28 - bkc233__tu
# 29 - bkc234__tu
# 30 - bkc235__tu
# 31 - bkc252__tu
# 32 - bkc253__tu
# 33 - bkc254__tu
# 34 - bkc255__tu
# 35 - bkc201__tu
# 36 - bkc202__tu
# 37 - bkc203__tu
# 38 - bkc204__tu
# 39 - bkc205__tu
# 40 - bkc222__tu
# 41 - bkc223__tu
# 42 - bkc224__tu
# 43 - bkc225__tu
# 44 - bigmileage_odometer__app
# 45 - fltpriceselling__app
# 46 - vehiclepricewholesale__app
# 47 - fltstatesalestax__app
# 48 - permid__tu
# 49 - partyid__tu
# 50 - acctid__tu
# 51 - tuseqeuncenumber__tu
# 52 - bankcard_reason5__ln
# 53 - alert4__ln
# 54 - alert5__ln
# 55 - alert6__ln
# 56 - alert7__ln
# 57 - alert8__ln
# 58 - alert9__ln
# 59 - alert10__ln
# 60 - DPD60PLUS__tucvlink
# 61 - acct_typ_cde__base
# 62 - open_dte__base
# 63 - terms_freq_cde__base
# 64 - affil_rem_cde__base
# 65 - cmplnc_rem_cde__base
# 66 - gnrc_rem_cde__base
# 67 - rte_rem_cde__base
# 68 - acct_rte_prfl_cde__base
# 69 - payt_pttrn_txt__base
# 70 - gnrcrem_frsrpt_dte__base
# 71 - obs_arch__base
# 72 - performance__base
# 73 - creditasofdate__tu
# 74 - strname__tu
# 75 - state__tu
# 76 - vehiclemodel__app
# 77 - fltinsuredlifepremium__app
# 78 - fltinsuredunemploymentamount__app
# 79 - fltinsuredunemploymentpremium__app
# 80 - inputprovidedstate__ln
# 81 - addrpreviouscorrectional__ln
# 82 - at900c__tu
# 83 - at999s__tu
# 84 - at999b__tu
# 85 - at920b__tu
# 86 - at920d__tu
# 87 - at920e__tu
# 88 - at920s__tu
# 89 - at922b__tu
# 90 - at922d__tu
# 91 - at922e__tu
# 92 - at922s__tu
# 93 - at934b__tu
# 94 - at934d__tu
# 95 - at934e__tu
# 96 - at934s__tu
# 97 - at935b__tu
# 98 - at935d__tu
# 99 - at935e__tu
# 100 - at935s__tu
# 101 - cc101b__tu
# 102 - cc101s__tu
# 103 - cc102s__tu
# 104 - cc103s__tu
# 105 - cc104s__tu
# 106 - cc105s__tu
# 107 - at933c__tu
# 108 - au900c__tu
# 109 - au999s__tu
# 110 - au999b__tu
# 111 - au920b__tu
# 112 - au920c__tu
# 113 - au920d__tu
# 114 - au920s__tu
# 115 - au922b__tu
# 116 - au922c__tu
# 117 - au922d__tu
# 118 - au922s__tu
# 119 - au934b__tu
# 120 - au934c__tu
# 121 - au934d__tu
# 122 - au934s__tu
# 123 - au935b__tu
# 124 - au935c__tu
# 125 - au935d__tu
# 126 - au935s__tu
# 127 - bc900c__tu
# 128 - bc999s__tu
# 129 - bc999b__tu
# 130 - bc920b__tu
# 131 - bc920c__tu
# 132 - bc920d__tu
# 133 - bc920s__tu
# 134 - bc922b__tu
# 135 - bc922c__tu
# 136 - bc922d__tu
# 137 - bc922s__tu
# 138 - bc934b__tu
# 139 - bc934c__tu
# 140 - bc934d__tu
# 141 - bc934s__tu
# 142 - bc935b__tu
# 143 - bc935c__tu
# 144 - bc935d__tu
# 145 - bc935s__tu
# 146 - rl900c__tu
# 147 - rl999s__tu
# 148 - rl999b__tu
# 149 - rl920b__tu
# 150 - rl920c__tu
# 151 - rl920d__tu
# 152 - rl920s__tu
# 153 - rl922b__tu
# 154 - rl922c__tu
# 155 - rl922d__tu
# 156 - rl922s__tu
# 157 - rl934b__tu
# 158 - rl934c__tu
# 159 - rl934d__tu
# 160 - rl934s__tu
# 161 - rl935b__tu
# 162 - rl935c__tu
# 163 - rl935d__tu
# 164 - rl935s__tu
# 165 - rl933c__tu
# 166 - rl921b__tu
# 10 - indflag__tu
# 11 - bkc231__tu
# 12 - bkc232__tu
# 13 - bkc233__tu
# 14 - bkc234__tu
# 15 - bkc235__tu
# 16 - bkc252__tu
# 17 - bkc253__tu
# 18 - bkc254__tu
# 19 - bkc255__tu
# 20 - bkc201__tu
# 21 - bkc202__tu
# 22 - bkc203__tu
# 23 - bkc204__tu
# 24 - bkc205__tu
# 25 - bkc222__tu
# 26 - bkc223__tu
# 27 - bkc224__tu
# 28 - bkc225__tu
# 29 - permid__tu
# 30 - partyid__tu
# 31 - acctid__tu
# 32 - tuseqeuncenumber__tu
# 33 - analyticsmatchkey__ln
# 34 - auto_score__ln
# 35 - auto_reason1__ln
# 36 - auto_reason2__ln
# 37 - auto_reason3__ln
# 38 - auto_reason4__ln
# 39 - auto_reason5__ln
# 40 - bankcard_score__ln
# 41 - bankcard_reason1__ln
# 42 - bankcard_reason2__ln
# 43 - bankcard_reason3__ln
# 44 - bankcard_reason4__ln
# 45 - bankcard_reason5__ln
# 46 - short_term_lending_score__ln
# 47 - short_term_lending_reason1__ln
# 48 - short_term_lending_reason2__ln
# 49 - short_term_lending_reason3__ln
# 50 - short_term_lending_reason4__ln
# 51 - short_term_lending_reason5__ln
# 52 - telecommunications_score__ln
# 53 - telecommunications_reason1__ln
# 54 - telecommunications_reason2__ln
# 55 - telecommunications_reason3__ln
# 56 - telecommunications_reason4__ln
# 57 - telecommunications_reason5__ln
# 58 - crossindustry_index__ln
# 59 - crossindustry_score_name__ln
# 60 - crossindustry_score__ln
# 61 - crossindustry_reason1__ln
# 62 - crossindustry_reason2__ln
# 63 - crossindustry_reason3__ln
# 64 - crossindustry_reason4__ln
# 65 - crossindustry_reason5__ln
# 66 - alert1__ln
# 67 - alert2__ln
# 68 - alert3__ln
# 69 - alert4__ln
# 70 - alert5__ln
# 71 - alert6__ln
# 72 - alert7__ln
# 73 - alert8__ln
# 74 - alert9__ln
# 75 - alert10__ln
# 76 - scr_linka2__tu
# 77 - scr_alta2__tu
# 78 - scr_linkb2__tu
# 79 - scr_altb2__tu
# 80 - DPD60PLUS__tucvlink
# 81 - zip_code__tu
# 82 - cvau__tu
# 83 - cvam__tu
# 84 - cvbk__tu
# 85 - cvna__tu
# 86 - cvpl__tu
# 87 - cv_bc_prop__tu
# 88 - cv_cons_prop__tu
# 89 - cv_persloan_prop__tu
# 90 - syntheticfraud_score__tu
# 91 - vantagescore3__tu
# 92 - vantagescore4__tu
# 93 - cv_bc_behav_seg__tu
# 94 - archive__tu
# 95 - tu_creditbureaudate__tu
#
# There are 26 features in the valid df that have no variance
# 1 - observationdate__base
# 2 - booked__base
# 3 - acct_typ_cde__base
# 4 - terms_freq_cde__base
# 5 - obs_arch__base
# 6 - creditasofdate__tu
# 7 - observationdate__tu
# 8 - bitsystemdecline__app
# 9 - bitfunded__app
# 10 - fltaddfee__app
# 11 - fltinsureddisabilitypremium__app
# 12 - fltinsuredlifepremium__app
# 13 - fltinsuredunemploymentamount__app
# 14 - fltinsuredunemploymentpremium__app
# 15 - fltpriceselling__app
# 16 - fltstatesalestax__app
# 17 - inputprovidedfirstname__ln
# 18 - inputprovidedlastname__ln
# 19 - inputprovidedstreetaddress__ln
# 20 - inputprovidedcity__ln
# 21 - inputprovidedstate__ln
# 22 - inputprovidedzipcode__ln
# 23 - inputprovidedssn__ln
# 24 - inputprovideddateofbirth__ln
# 25 - inputprovidedlexid__ln
# 26 - linkc010__tu
#  67%|██████▋   | 2/3 [00:20<00:09,  9.56s/it]
# There are 278 features in the valid df that are redundant
# 1 - dtmapproved__tu
# 2 - city__tu
# 3 - auto_reason1__ln
# 4 - auto_reason2__ln
# 5 - auto_reason3__ln
# 6 - auto_reason4__ln
# 7 - auto_reason5__ln
# 8 - bankcard_reason1__ln
# 9 - bankcard_reason2__ln
# 10 - bankcard_reason3__ln
# 11 - bankcard_reason4__ln
# 12 - short_term_lending_reason1__ln
# 13 - short_term_lending_reason2__ln
# 14 - short_term_lending_reason3__ln
# 15 - short_term_lending_reason4__ln
# 16 - short_term_lending_reason5__ln
# 17 - telecommunications_reason1__ln
# 18 - telecommunications_reason2__ln
# 19 - telecommunications_reason3__ln
# 20 - telecommunications_reason4__ln
# 21 - telecommunications_reason5__ln
# 22 - crossindustry_score_name__ln
# 23 - crossindustry_reason1__ln
# 24 - crossindustry_reason2__ln
# 25 - crossindustry_reason3__ln
# 26 - crossindustry_reason4__ln
# 27 - crossindustry_reason5__ln
# 28 - alert1__ln
# 29 - alert2__ln
# 30 - alert3__ln
# 31 - tu_creditbureaudate__tu
# 32 - middlename__tu
# 33 - lastname__tu
# 34 - address1__tu
# 35 - zip4__tu
# 36 - ssn__tu
# 37 - dateofbirth__tu
# 38 - indflag__tu
# 39 - bkc231__tu
# 40 - bkc232__tu
# 41 - bkc233__tu
# 42 - bkc234__tu
# 43 - bkc235__tu
# 44 - bkc252__tu
# 45 - bkc253__tu
# 46 - bkc254__tu
# 47 - bkc255__tu
# 48 - bkc201__tu
# 49 - bkc202__tu
# 50 - bkc203__tu
# 51 - bkc204__tu
# 52 - bkc205__tu
# 53 - bkc222__tu
# 54 - bkc223__tu
# 55 - bkc224__tu
# 56 - bkc225__tu
# 57 - permid__tu
# 58 - partyid__tu
# 59 - acctid__tu
# 60 - tuseqeuncenumber__tu
# 61 - analyticsmatchkey__ln
# 62 - auto_score__ln
# 63 - bankcard_score__ln
# 64 - bankcard_reason5__ln
# 65 - short_term_lending_score__ln
# 66 - telecommunications_score__ln
# 67 - crossindustry_index__ln
# 68 - crossindustry_score__ln
# 69 - alert4__ln
# 70 - alert5__ln
# 71 - alert6__ln
# 72 - alert7__ln
# 73 - alert8__ln
# 74 - alert9__ln
# 75 - alert10__ln
# 76 - scr_linka2__tu
# 77 - scr_alta2__tu
# 78 - scr_linkb2__tu
# 79 - scr_altb2__tu
# 80 - DPD60PLUS__tucvlink
# 31 - analyticsmatchkey__ln
# 32 - auto_score__ln
# 33 - auto_reason1__ln
# 34 - auto_reason2__ln
# 35 - auto_reason3__ln
# 36 - auto_reason4__ln
# 37 - auto_reason5__ln
# 38 - bankcard_score__ln
# 39 - bankcard_reason1__ln
# 40 - bankcard_reason2__ln
# 41 - bankcard_reason3__ln
# 42 - bankcard_reason4__ln
# 43 - bankcard_reason5__ln
# 44 - short_term_lending_score__ln
# 45 - short_term_lending_reason1__ln
# 46 - short_term_lending_reason2__ln
# 47 - short_term_lending_reason3__ln
# 48 - short_term_lending_reason4__ln
# 49 - short_term_lending_reason5__ln
# 50 - telecommunications_score__ln
# 51 - telecommunications_reason1__ln
# 52 - telecommunications_reason2__ln
# 53 - telecommunications_reason3__ln
# 54 - telecommunications_reason4__ln
# 55 - telecommunications_reason5__ln
# 56 - crossindustry_index__ln
# 57 - crossindustry_score_name__ln
# 58 - crossindustry_score__ln
# 59 - crossindustry_reason1__ln
# 60 - crossindustry_reason2__ln
# 61 - crossindustry_reason3__ln
# 62 - crossindustry_reason4__ln
# 63 - crossindustry_reason5__ln
# 64 - alert1__ln
# 65 - alert2__ln
# 66 - alert3__ln
# 67 - alert4__ln
# 68 - alert5__ln
# 69 - alert6__ln
# 70 - alert7__ln
# 71 - alert8__ln
# 72 - alert9__ln
# 73 - alert10__ln
# 74 - scr_linka2__tu
# 75 - scr_alta2__tu
# 76 - scr_linkb2__tu
# 77 - scr_altb2__tu
# 78 - DPD60PLUS__tucvlink
# 79 - zip_code__tu
# 80 - cvau__tu
# 81 - cvam__tu
# 82 - cvbk__tu
# 83 - cvna__tu
# 84 - cvpl__tu
# 85 - cv_bc_prop__tu
# 86 - cv_cons_prop__tu
# 87 - cv_persloan_prop__tu
# 88 - syntheticfraud_score__tu
# 89 - vantagescore3__tu
# 90 - vantagescore4__tu
# 91 - cv_bc_behav_seg__tu
# 92 - archive__tu
# 93 - tu_creditbureaudate__tu
# 94 - zipcodefiller__tu
#
# There are 23 features in the test df that have no variance
# 1 - booked__base
# 2 - acct_typ_cde__base
# 3 - terms_freq_cde__base
# 4 - linka067__tu
# 5 - linka073__tu
# 6 - bitsystemdecline__app
# 7 - bitfunded__app
# 8 - fltaddfee__app
# 9 - fltinsureddisabilitypremium__app
# 10 - fltinsuredlifepremium__app
# 11 - fltinsuredunemploymentamount__app
# 12 - fltinsuredunemploymentpremium__app
# 13 - fltpriceselling__app
# 14 - fltstatesalestax__app
# 15 - inputprovidedfirstname__ln
# 16 - inputprovidedlastname__ln
# 17 - inputprovidedstreetaddress__ln
# 18 - inputprovidedstate__ln
# 19 - inputprovidedzipcode__ln
# 20 - inputprovideddateofbirth__ln
# 21 - inputprovidedlexid__ln
# 22 - purchaseactivitycount__ln
# 23 - purchaseactivitydollartotal__ln
# 100%|██████████| 3/3 [00:29<00:00,  9.76s/it]
# There are 342 features in the test df that are redundant
# 1 - middlename__tu
# 2 - lastname__tu
# 3 - address1__tu
# 4 - zip4__tu
# 5 - ssn__tu
# 6 - dateofbirth__tu
# 7 - bkc231__tu
# 8 - bkc232__tu
# 9 - bkc233__tu
# 10 - bkc234__tu
# 11 - bkc235__tu
# 12 - bkc252__tu
# 13 - bkc253__tu
# 14 - bkc254__tu
# 15 - bkc255__tu
# 16 - bkc201__tu
# 17 - bkc202__tu
# 18 - bkc203__tu
# 19 - bkc204__tu
# 20 - bkc205__tu
# 21 - bkc222__tu
# 22 - bkc223__tu
# 23 - bkc224__tu
# 24 - bkc225__tu
# 25 - permid__tu
# 26 - partyid__tu
# 27 - acctid__tu
# 28 - tuseqeuncenumber__tu
# 29 - analyticsmatchkey__ln
# 30 - auto_score__ln
# 31 - bankcard_score__ln
# 32 - bankcard_reason5__ln
# 33 - short_term_lending_score__ln
# 34 - telecommunications_score__ln
# 35 - crossindustry_index__ln
# 36 - crossindustry_score__ln
# 37 - alert4__ln
# 38 - alert5__ln
# 39 - alert6__ln
# 40 - alert7__ln
# 41 - alert8__ln
# 42 - alert9__ln
# 43 - alert10__ln
# 44 - scr_linka2__tu
# 45 - scr_alta2__tu
# 46 - scr_linkb2__tu
# 47 - scr_altb2__tu
# 48 - DPD60PLUS__tucvlink
# 49 - zip_code__tu
# 50 - cvau__tu
# 51 - cvam__tu
# 52 - cvbk__tu
# 53 - cvna__tu
# 54 - cvpl__tu
# 55 - cv_bc_prop__tu
# 56 - cv_cons_prop__tu
# 57 - cv_persloan_prop__tu
# 58 - syntheticfraud_score__tu
# 59 - vantagescore3__tu
# 60 - vantagescore4__tu
# 61 - cv_bc_behav_seg__tu
# 62 - archive__tu
# 63 - auto_reason1__ln
# 64 - auto_reason2__ln
# 65 - auto_reason3__ln
# 66 - auto_reason4__ln
# 67 - auto_reason5__ln
# 68 - bankcard_reason1__ln
# 69 - bankcard_reason2__ln
# 70 - bankcard_reason3__ln
# 71 - bankcard_reason4__ln
# 72 - short_term_lending_reason1__ln
# 73 - short_term_lending_reason2__ln
# 74 - short_term_lending_reason3__ln
# 75 - short_term_lending_reason4__ln
# 76 - short_term_lending_reason5__ln
# 77 - telecommunications_reason1__ln
# 78 - telecommunications_reason2__ln
# 79 - telecommunications_reason3__ln
# 80 - telecommunications_reason4__ln
# 81 - telecommunications_reason5__ln
# 82 - crossindustry_score_name__ln
# 83 - crossindustry_reason1__ln
# 84 - crossindustry_reason2__ln
# 85 - crossindustry_reason3__ln
# 86 - crossindustry_reason4__ln
# 87 - crossindustry_reason5__ln
# 88 - alert1__ln
# 89 - alert2__ln
# 90 - alert3__ln
# 91 - tu_creditbureaudate__tu
# 92 - zipcodefiller__tu
# 93 - linka073__tu
# 94 - hr35s__tu
# 95 - fltinsuredlifepremium__app
# 96 - fltinsuredunemploymentamount__app
# 97 - fltinsuredunemploymentpremium__app
# 98 - inputprovidedlastname__ln
# 99 - inputprovidedstreetaddress__ln
# 100 - inputprovidedstate__ln
# 101 - inputprovidedzipcode__ln
# 337 - at922f__tu
# 338 - at934c__tu
# 339 - at934f__tu
# 340 - at935c__tu
# 341 - at935f__tu
# 342 - at999c__tu
#
# CPU times: user 37.6 s, sys: 32.2 s, total: 1min 9s
# Wall time: 29.3 s

# %% [markdown]
# ### Remove duplicates

# %%
print(f'Before removing duplicates, there were {len(list_cols_all)} features to remove')
print('')

# rm dups
list_cols_all = list(dict.fromkeys(list_cols_all))
print(f'After removing duplicates, there are {len(list_cols_all)} features to remove')
for a, col in enumerate(list_cols_all):
    print(f'{a+1} - {col}')
# Out:
# Before removing duplicates, there were 1229 features to remove
#
# After removing duplicates, there are 402 features to remove
# 1 - dtmstampcreation__base
# 2 - dtmapproved__base
# 3 - dtmdeclined__base
# 4 - observationdate__base
# 5 - analyticsmatchkey__base
# 6 - decision_dte__base
# 7 - booked__base
# 8 - acct_typ_cde__base
# 9 - open_dte__base
# 10 - curr_bal_amt__base
# 11 - terms_freq_cde__base
# 12 - affil_rem_cde__base
# 13 - cmplnc_rem_cde__base
# 14 - gnrc_rem_cde__base
# 15 - rte_rem_cde__base
# 16 - acct_rte_prfl_cde__base
# 17 - payt_pttrn_txt__base
# 18 - gnrcrem_frsrpt_dte__base
# 19 - obs_arch__base
# 20 - vtg4__base
# 21 - performance__base
# 22 - creditasofdate__tu
# 23 - firstname__tu
# 24 - middlename__tu
# 25 - lastname__tu
# 26 - address1__tu
# 27 - strname__tu
# 28 - state__tu
# 29 - zip5__tu
# 30 - zip4__tu
# 31 - ssn__tu
# 32 - dateofbirth__tu
# 33 - dtmstampcreation__tu
# 34 - observationdate__tu
# 35 - analyticsmatchkey__tu
# 36 - segment__tu
# 37 - indflag__tu
# 38 - iscrhit__tu
# 39 - bctrd__tu
# 40 - insttrd__tu
# 41 - nomttrd__tu
# 42 - revtrd__tu
# 43 - rtltrd__tu
# 44 - bkc231__tu
# 45 - bkc232__tu
# 46 - bkc233__tu
# 47 - bkc234__tu
# 48 - bkc235__tu
# 49 - bkc252__tu
# 50 - bkc253__tu
# 51 - bkc254__tu
# 52 - bkc255__tu
# 53 - bkc201__tu
# 54 - bkc202__tu
# 55 - bkc203__tu
# 56 - bkc204__tu
# 57 - bkc205__tu
# 58 - bkc222__tu
# 59 - bkc223__tu
# 60 - bkc224__tu
# 61 - bkc225__tu
# 62 - bigmileage_odometer__app
# 63 - vehiclemodel__app
# 64 - fltpriceselling__app
# 65 - vehiclepricewholesale__app
# 66 - fltstatesalestax__app
# 67 - permid__tu
# 68 - partyid__tu
# 69 - acctid__tu
# 70 - tuseqeuncenumber__tu
# 71 - bankcard_reason5__ln
# 72 - alert4__ln
# 73 - alert5__ln
# 74 - alert6__ln
# 75 - alert7__ln
# 76 - alert8__ln
# 77 - alert9__ln
# 78 - alert10__ln
# 79 - DPD60PLUS__tucvlink
# 80 - bitfunded__app
# 81 - fltaddfee__app
# 82 - fltinsureddisabilitypremium__app
# 83 - fltinsuredlifepremium__app
# 84 - fltinsuredunemploymentamount__app
# 85 - fltinsuredunemploymentpremium__app
# 86 - inputprovidedfirstname__ln
# 87 - inputprovidedlastname__ln
# 88 - inputprovidedssn__ln
# 89 - inputprovideddateofbirth__ln
# 90 - inputprovidedlexid__ln
# 91 - short_term_lending_reason5__ln
# 92 - telecommunications_reason5__ln
# 93 - crossindustry_index__ln
# 94 - crossindustry_score_name__ln
# 95 - crossindustry_reason5__ln
# 96 - linkc010__tu
# 97 - monthonbooks__app
# 98 - inputprovidedstate__ln
# 99 - addrpreviouscorrectional__ln
# 100 - at900c__tu
# 101 - at999s__tu
# 102 - at999b__tu
# 103 - at920b__tu
# 104 - at920d__tu
# 105 - at920e__tu
# 106 - at920s__tu
# 107 - at922b__tu
# 108 - at922d__tu
# 109 - at922e__tu
# 110 - at922s__tu
# 111 - at934b__tu
# 112 - at934d__tu
# 113 - at934e__tu
# 114 - at934s__tu
# 115 - at935b__tu
# 116 - at935d__tu
# 117 - at935e__tu
# 118 - at935s__tu
# 119 - cc101b__tu
# 120 - cc101s__tu
# 121 - cc102s__tu
# 122 - cc103s__tu
# 123 - cc104s__tu
# 124 - cc105s__tu
# 125 - at933c__tu
# 126 - au900c__tu
# 127 - au999s__tu
# 128 - au999b__tu
# 129 - au920b__tu
# 130 - au920c__tu
# 131 - au920d__tu
# 132 - au920s__tu
# 133 - au922b__tu
# 134 - au922c__tu
# 135 - au922d__tu
# 136 - au922s__tu
# 137 - au934b__tu
# 138 - au934c__tu
# 139 - au934d__tu
# 140 - au934s__tu
# 141 - au935b__tu
# 142 - au935c__tu
# 143 - au935d__tu
# 144 - au935s__tu
# 145 - bc900c__tu
# 146 - bc999s__tu
# 147 - bc999b__tu
# 148 - bc920b__tu
# 149 - bc920c__tu
# 150 - bc920d__tu
# 151 - bc920s__tu
# 152 - bc922b__tu
# 153 - bc922c__tu
# 154 - bc922d__tu
# 155 - bc922s__tu
# 156 - bc934b__tu
# 157 - bc934c__tu
# 158 - bc934d__tu
# 159 - bc934s__tu
# 160 - bc935b__tu
# 161 - bc935c__tu
# 162 - bc935d__tu
# 163 - bc935s__tu
# 164 - rl900c__tu
# 165 - rl999s__tu
# 166 - rl999b__tu
# 167 - rl920b__tu
# 168 - rl920c__tu
# 169 - rl920d__tu
# 170 - rl920s__tu
# 171 - rl922b__tu
# 172 - rl922c__tu
# 173 - rl922d__tu
# 174 - rl922s__tu
# 175 - rl934b__tu
# 176 - rl934c__tu
# 177 - rl934d__tu
# 178 - rl934s__tu
# 179 - rl935b__tu
# 180 - rl935c__tu
# 181 - rl935d__tu
# 182 - rl935s__tu
# 183 - rl933c__tu
# 184 - rl921b__tu
# 185 - rl921c__tu
# 186 - us900c__tu
# 187 - us999s__tu
# 188 - us999b__tu
# 189 - us920b__tu
# 190 - us920c__tu
# 191 - us920d__tu
# 192 - us920s__tu
# 193 - us922b__tu
# 194 - us922c__tu
# 195 - us922d__tu
# 196 - us922s__tu
# 197 - us934b__tu
# 198 - us934c__tu
# 199 - us934d__tu
# 200 - us934s__tu
# 201 - us935b__tu
# 202 - us935c__tu
# 203 - us935d__tu
# 204 - us935s__tu
# 205 - au933s__tu
# 206 - au933b__tu
# 207 - au933c__tu
# 208 - bc921c__tu
# 209 - bc933s__tu
# 210 - bc933b__tu
# 211 - bc933c__tu
# 212 - he900c__tu
# 213 - he999s__tu
# 214 - he999b__tu
# 215 - he920b__tu
# 216 - he920c__tu
# 217 - he920d__tu
# 218 - he920s__tu
# 219 - he922b__tu
# 220 - he922c__tu
# 221 - he922d__tu
# 222 - he922s__tu
# 223 - he934b__tu
# 224 - he934c__tu
# 225 - he934d__tu
# 226 - he934s__tu
# 227 - he935b__tu
# 228 - he935c__tu
# 229 - he935d__tu
# 230 - he935s__tu
# 231 - he921c__tu
# 232 - he933s__tu
# 233 - he933b__tu
# 234 - he933c__tu
# 235 - mt900b__tu
# 236 - mt900c__tu
# 237 - mt999s__tu
# 238 - mt999b__tu
# 239 - mt920b__tu
# 240 - mt920c__tu
# 241 - mt920d__tu
# 242 - mt920s__tu
# 243 - mt922b__tu
# 244 - mt922c__tu
# 245 - mt922d__tu
# 246 - mt922s__tu
# 247 - mt934b__tu
# 248 - mt934c__tu
# 249 - mt934d__tu
# 250 - mt934s__tu
# 251 - mt935b__tu
# 252 - mt935c__tu
# 253 - mt935d__tu
# 254 - mt935s__tu
# 255 - mt933s__tu
# 256 - mt921c__tu
# 257 - mt933b__tu
# 258 - mt933c__tu
# 259 - rt900c__tu
# 260 - rt999s__tu
# 261 - rt999b__tu
# 262 - rt920b__tu
# 263 - rt920c__tu
# 264 - rt920d__tu
# 265 - rt920s__tu
# 266 - rt922b__tu
# 267 - rt922c__tu
# 268 - rt922d__tu
# 269 - rt922s__tu
# 270 - rt934b__tu
# 271 - rt934c__tu
# 272 - rt934d__tu
# 273 - rt934s__tu
# 274 - rt935b__tu
# 275 - rt935c__tu
# 276 - rt935d__tu
# 277 - rt935s__tu
# 278 - rt921c__tu
# 279 - rt933s__tu
# 280 - rt933b__tu
# 281 - rt933c__tu
# 282 - us921c__tu
# 283 - us933s__tu
# 284 - us933b__tu
# 285 - us933c__tu
# 286 - at922c__tu
# 287 - at922f__tu
# 288 - at934c__tu
# 289 - at934f__tu
# 290 - at935c__tu
# 291 - at935f__tu
# 292 - at999c__tu
# 293 - city__tu
# 294 - analyticsmatchkey__ln
# 295 - auto_score__ln
# 296 - auto_reason1__ln
# 297 - auto_reason2__ln
# 298 - auto_reason3__ln
# 299 - auto_reason4__ln
# 300 - auto_reason5__ln
# 301 - bankcard_score__ln
# 302 - bankcard_reason1__ln
# 303 - bankcard_reason2__ln
# 304 - bankcard_reason3__ln
# 305 - bankcard_reason4__ln
# 306 - short_term_lending_score__ln
# 307 - short_term_lending_reason1__ln
# 308 - short_term_lending_reason2__ln
# 309 - short_term_lending_reason3__ln
# 310 - short_term_lending_reason4__ln
# 311 - telecommunications_score__ln
# 312 - telecommunications_reason1__ln
# 313 - telecommunications_reason2__ln
# 314 - telecommunications_reason3__ln
# 315 - telecommunications_reason4__ln
# 316 - crossindustry_score__ln
# 317 - crossindustry_reason1__ln
# 318 - crossindustry_reason2__ln
# 319 - crossindustry_reason3__ln
# 320 - crossindustry_reason4__ln
# 321 - alert1__ln
# 322 - alert2__ln
# 323 - alert3__ln
# 324 - scr_linka2__tu
# 325 - scr_alta2__tu
# 326 - scr_linkb2__tu
# 327 - scr_altb2__tu
# 328 - zip_code__tu
# 329 - cvau__tu
# 330 - cvam__tu
# 331 - cvbk__tu
# 332 - cvna__tu
# 333 - cvpl__tu
# 334 - cv_bc_prop__tu
# 335 - cv_cons_prop__tu
# 336 - cv_persloan_prop__tu
# 337 - syntheticfraud_score__tu
# 338 - vantagescore3__tu
# 339 - vantagescore4__tu
# 340 - cv_bc_behav_seg__tu
# 341 - archive__tu
# 342 - tu_creditbureaudate__tu
# 343 - bitsystemdecline__app
# 344 - inputprovidedstreetaddress__ln
# 345 - inputprovidedcity__ln
# 346 - inputprovidedzipcode__ln
# 347 - dtmapproved__tu
# 348 - hr25s__tu
# 349 - hr33s__tu
# 350 - hr35s__tu
# 351 - zipcodefiller__tu
# 352 - linka067__tu
# 353 - linka073__tu
# 354 - purchaseactivitycount__ln
# 355 - purchaseactivitydollartotal__ln
# 356 - lienjudgmentforeclosurecount__ln
# 357 - addrcurrentcorrectional__ln
# 358 - fltgrossmonthly__income_mean
# 359 - linkc025__tu
# 360 - linkc029__tu
# 361 - linkc038__tu
# 362 - linkc039__tu
# 363 - linkc008__tu
# 364 - linkc009__tu
# 365 - linkc050__tu
# 366 - linkc012__tu
# 367 - linkc011__tu
# 368 - linkc043__tu
# 369 - linkc044__tu
# 370 - linkc045__tu
# 371 - linkc046__tu
# 372 - linkc047__tu
# 373 - linkc005__tu
# 374 - linkc004__tu
# 375 - linkc051__tu
# 376 - linkc041__tu
# 377 - at900b__tu
# 378 - at921b__tu
# 379 - at921c__tu
# 380 - at933s__tu
# 381 - at933b__tu
# 382 - au900b__tu
# 383 - bc900b__tu
# 384 - rl900b__tu
# 385 - rl933s__tu
# 386 - rl933b__tu
# 387 - he900s__tu
# 388 - he900b__tu
# 389 - he921s__tu
# 390 - he921b__tu
# 391 - mt900s__tu
# 392 - mt921s__tu
# 393 - mt921b__tu
# 394 - rl921s__tu
# 395 - us900b__tu
# 396 - au921b__tu
# 397 - au921c__tu
# 398 - bc921b__tu
# 399 - rt900b__tu
# 400 - rt921b__tu
# 401 - us921b__tu
# 402 - at920f__tu

# %% [markdown]
# ### Save

# %%
# %%time

df = pd.DataFrame({'feature': list_cols_all})
str_filename = 'df_cols_drop.csv'
str_local_path = f'{str_dirname_output}/{str_filename}'
df.to_csv(str_local_path, index=False)
# Out:
# CPU times: user 11.3 ms, sys: 3.59 ms, total: 14.9 ms
# Wall time: 14.5 ms
