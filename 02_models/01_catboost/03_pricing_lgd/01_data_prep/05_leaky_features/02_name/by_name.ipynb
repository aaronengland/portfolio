# %%
import os
import pandas as pd
import functions as func
import numpy as np
from tqdm import tqdm
from pprint import pprint

# %% [markdown]
# ### Constants

# %%
str_project = os.getcwd().split('/')[4].replace('_','-')
print(f'Project: {str_project}')
str_step = os.getcwd().split('/')[-1]
print(f'Step: {str_step}')
str_dirname_output = './output'

str_id = 'uniqueid'
str_datecol = 'applicationdate__app'
str_target = 'target'
flt_threshold = 0.80 # proportion missing in any data set

list_cols_id = [
    str_id,
    str_datecol,
    str_target,
]
# Out:
# Project: 20231010-gen-xii
# Step: 02_name

# %% [markdown]
# ### Output

# %%
try:
    os.mkdir(str_dirname_output)
except:
    pass

# %% [markdown]
# ### Import column names

# %%
# %%time

str_filename = 'df_descriptives_train.csv'
str_local_path = f'../../04_eda_pt_2/output/{str_filename}'
list_cols = list(pd.read_csv(str_local_path)['feature'])
# message
print(f'We will be reviewing {len(list_cols)} columns for leaks by name')
print('')
# Out:
# We will be reviewing 2489 columns for leaks by name
#
# CPU times: user 11.4 ms, sys: 3.54 ms, total: 14.9 ms
# Wall time: 14.1 ms

# %% [markdown]
# ### List of Leaky Features by Name

# %%
# %%time

# get id, date, score, fund columns
list_id_cols, list_date_cols, list_score_cols, list_fund_cols = func.check_columns(list_cols)

# combine lists
list_leaky_by_name = list_id_cols + list_date_cols + list_score_cols + list_fund_cols
# rm dups
list_leaky_by_name = list(dict.fromkeys(list_leaky_by_name))
# message
print('')
print(f'There are {len(list_leaky_by_name)} features with names suggesting they should be dropped')
for a, col in enumerate(list_leaky_by_name):
    print(f'{a+1} - {col}')

print('')
# Out:
# There are 22 columns containing the string "id"
# 1 - permid__tu
# 2 - partyid__tu
# 3 - acctid__tu
# 4 - middlename__tu
# 5 - educationevidence__ln
# 6 - inputprovidedfirstname__ln
# 7 - inputprovidedlastname__ln
# 8 - inputprovidedlexid__ln
# 9 - inputprovidedphone__ln
# 10 - inputprovideddateofbirth__ln
# 11 - inputprovidedssn__ln
# 12 - inputprovidedzipcode__ln
# 13 - inputprovidedstate__ln
# 14 - inputprovidedcity__ln
# 15 - inputprovidedstreetaddress__ln
# 16 - uniqueid__app
# 17 - bigdebtorid__app
# 18 - bigdealertypeid__app
# 19 - bigdealerid__app
# 20 - bigaccountid__app
# 21 - bigdebtorid__ln
# 22 - bigaccountid__ln
#
# There are 25 columns containing the strings "date", "dtm", or "dte"
# 1 - dtmstampcreation__base
# 2 - dtmapproved__base
# 3 - creditasofdate__tu
# 4 - observationdate__tu
# 5 - decision_dte__base
# 6 - gnrcrem_frsrpt_dte__base
# 7 - open_dte__base
# 8 - dtmdeclined__base
# 9 - dtmstampcreation__tu
# 10 - dateofbirth__tu
# 11 - observationdate__base
# 12 - dtmdeclined__tu
# 13 - dtmdeclined__app
# 14 - chargeoffdate__app
# 15 - defaultdate__app
# 16 - dtmapproved__tu
# 17 - tu_creditbureaudate__tu
# 18 - inputprovideddateofbirth__ln
# 19 - ssndatelowissued__ln
# 20 - credit_as_of_date__tu
# 21 - dtmfunded__app
# 22 - dtmapproved__app
# 23 - dtmstampcreation__app
# 24 - fundeddate__app
# 25 - approvaldate__app
#
# There are 16 columns containing the string "score"
# 1 - score_cvpropensity__tu
# 2 - score_epd__tu
# 3 - score_newaccount__tu
# 4 - score_bankcard__tu
# 5 - finscore__tu
# 6 - score_cvauto__tu
# 7 - intscore__ln
# 8 - vantagescore4__tu
# 9 - vantagescore3__tu
# 10 - syntheticfraud_score__tu
# 11 - auto_score__ln
# 12 - crossindustry_score__ln
# 13 - crossindustry_score_name__ln
# 14 - short_term_lending_score__ln
# 15 - telecommunications_score__ln
# 16 - bankcard_score__ln
#
# There are 3 columns containing the string "fund"
# 1 - dtmfunded__app
# 2 - fundeddate__app
# 3 - bitfunded__app
#
#
# There are 63 features with names suggesting they should be dropped
# 1 - permid__tu
# 2 - partyid__tu
# 3 - acctid__tu
# 4 - middlename__tu
# 5 - educationevidence__ln
# 6 - inputprovidedfirstname__ln
# 7 - inputprovidedlastname__ln
# 8 - inputprovidedlexid__ln
# 9 - inputprovidedphone__ln
# 10 - inputprovideddateofbirth__ln
# 11 - inputprovidedssn__ln
# 12 - inputprovidedzipcode__ln
# 13 - inputprovidedstate__ln
# 14 - inputprovidedcity__ln
# 15 - inputprovidedstreetaddress__ln
# 16 - uniqueid__app
# 17 - bigdebtorid__app
# 18 - bigdealertypeid__app
# 19 - bigdealerid__app
# 20 - bigaccountid__app
# 21 - bigdebtorid__ln
# 22 - bigaccountid__ln
# 23 - dtmstampcreation__base
# 24 - dtmapproved__base
# 25 - creditasofdate__tu
# 26 - observationdate__tu
# 27 - decision_dte__base
# 28 - gnrcrem_frsrpt_dte__base
# 29 - open_dte__base
# 30 - dtmdeclined__base
# 31 - dtmstampcreation__tu
# 32 - dateofbirth__tu
# 33 - observationdate__base
# 34 - dtmdeclined__tu
# 35 - dtmdeclined__app
# 36 - chargeoffdate__app
# 37 - defaultdate__app
# 38 - dtmapproved__tu
# 39 - tu_creditbureaudate__tu
# 40 - ssndatelowissued__ln
# 41 - credit_as_of_date__tu
# 42 - dtmfunded__app
# 43 - dtmapproved__app
# 44 - dtmstampcreation__app
# 45 - fundeddate__app
# 46 - approvaldate__app
# 47 - score_cvpropensity__tu
# 48 - score_epd__tu
# 49 - score_newaccount__tu
# 50 - score_bankcard__tu
# 51 - finscore__tu
# 52 - score_cvauto__tu
# 53 - intscore__ln
# 54 - vantagescore4__tu
# 55 - vantagescore3__tu
# 56 - syntheticfraud_score__tu
# 57 - auto_score__ln
# 58 - crossindustry_score__ln
# 59 - crossindustry_score_name__ln
# 60 - short_term_lending_score__ln
# 61 - telecommunications_score__ln
# 62 - bankcard_score__ln
# 63 - bitfunded__app
#
# CPU times: user 2.31 ms, sys: 0 ns, total: 2.31 ms
# Wall time: 2.3 ms

# %%
# remove good cols in list_leaky_by_name
list_dont_drop = [
    'educationevidence__ln',
    'inputprovidedstate__ln',
    'inputprovidedfirstname__ln',
    'inputprovidedlastname__ln',
    'inputprovidedcity__ln',
    'inputprovidedzipcode__ln',
    'inputprovidedssn__ln',
    'inputprovideddateofbirth__ln',
    'inputprovidedphone__ln',
    'inputprovidedlexid__ln',
    'inputprovidedstreetaddress__ln',
    'bigdealertypeid__app',
    'auto_score__ln',
    # 2023-11-06
    'intscore__ln',
    'vantagescore4__tu',
]
list_leaky_by_name = [col for col in list_leaky_by_name if col not in list_dont_drop]

# message
print(f'There are {len(list_leaky_by_name)} features identified as leaky based off of their name')
for a, col in enumerate(list_leaky_by_name):
    print(f'{a+1} - {col}')
# Out:
# There are 48 features identified as leaky based off of their name
# 1 - permid__tu
# 2 - partyid__tu
# 3 - acctid__tu
# 4 - middlename__tu
# 5 - uniqueid__app
# 6 - bigdebtorid__app
# 7 - bigdealerid__app
# 8 - bigaccountid__app
# 9 - bigdebtorid__ln
# 10 - bigaccountid__ln
# 11 - dtmstampcreation__base
# 12 - dtmapproved__base
# 13 - creditasofdate__tu
# 14 - observationdate__tu
# 15 - decision_dte__base
# 16 - gnrcrem_frsrpt_dte__base
# 17 - open_dte__base
# 18 - dtmdeclined__base
# 19 - dtmstampcreation__tu
# 20 - dateofbirth__tu
# 21 - observationdate__base
# 22 - dtmdeclined__tu
# 23 - dtmdeclined__app
# 24 - chargeoffdate__app
# 25 - defaultdate__app
# 26 - dtmapproved__tu
# 27 - tu_creditbureaudate__tu
# 28 - ssndatelowissued__ln
# 29 - credit_as_of_date__tu
# 30 - dtmfunded__app
# 31 - dtmapproved__app
# 32 - dtmstampcreation__app
# 33 - fundeddate__app
# 34 - approvaldate__app
# 35 - score_cvpropensity__tu
# 36 - score_epd__tu
# 37 - score_newaccount__tu
# 38 - score_bankcard__tu
# 39 - finscore__tu
# 40 - score_cvauto__tu
# 41 - vantagescore3__tu
# 42 - syntheticfraud_score__tu
# 43 - crossindustry_score__ln
# 44 - crossindustry_score_name__ln
# 45 - short_term_lending_score__ln
# 46 - telecommunications_score__ln
# 47 - bankcard_score__ln
# 48 - bitfunded__app

# %% [markdown]
# ### List of Leaky Features Manually

# %%
# create list leaky manual 
list_leaky_manual = [
    # obviously bad
    'runningnetloss__app', # target for LGD
    'bitdefault__app', # target for PD (was renamed to target in PD so its not in list of leaky for PD model)
    'chargeoffamount__app',
    'defaultamount__app',
    'bitdebtor__base',
    'bitdebtor__tu',
    'bitlhmgroup__app',
    'bitfunded__app',
    'dealerzip__app',
    'dealercity__app',
    'analyticsmatchkey__tu',
    'strzipcode__app',
    'bitapproved__app',
    'strcity__app',
    'fltapprovedapr_contract__app',
    'subjectage__ln',
    'applicationmonth__app',
    'applicationdayofweek__app',
    'applicationquarter__app',
    'fltapproveddebttoincome__app',
    'agg612__tu',
    'agg613__tu',
    'agg614__tu',
    'agg615__tu',
    'agg616__tu',
    'agg617__tu',
    'agg618__tu',
    'agg619__tu',
    'agg620__tu',
    'agg621__tu',
    'agg622__tu',
    'agg623__tu',
    'agg624__tu',
    'agg701__tu',
    'agg702__tu',
    'agg703__tu',
    'agg704__tu',
    'agg705__tu',
    'agg706__tu',
    'agg707__tu',
    'agg708__tu',
    'agg709__tu',
    'agg710__tu',
    'agg711__tu',
    'agg712__tu',
    'agg713__tu',
    'agg714__tu',
    'agg715__tu',
    'agg716__tu',
    'agg717__tu',
    'agg718__tu',
    'agg719__tu',
    'agg720__tu',
    'agg721__tu',
    'agg722__tu',
    'agg723__tu',
    'agg724__tu',
    'agg801__tu',
    'agg802__tu',
    'agg803__tu',
    'agg804__tu',
    'agg805__tu',
    'agg806__tu',
    'agg807__tu',
    'agg808__tu',
    'agg809__tu',
    'agg810__tu',
    'agg811__tu',
    'agg812__tu',
    'agg813__tu',
    'agg814__tu',
    'agg815__tu',
    'agg816__tu',
    'agg817__tu',
    'agg818__tu',
    'agg819__tu',
    'agg820__tu',
    'agg821__tu',
    'agg822__tu',
    'agg823__tu',
    'agg824__tu',
    'aggs101__tu',
    'aggs102__tu',
    'aggs103__tu',
    'aggs104__tu',
    'aggs105__tu',
    'aggs106__tu',
    'aggs107__tu',
    'aggs108__tu',
    'aggs109__tu',
    'aggs110__tu',
    'aggs111__tu',
    'aggs112__tu',
    'aggs113__tu',
    'aggs114__tu',
    'aggs115__tu',
    'aggs116__tu',
    'aggs117__tu',
    'aggs118__tu',
    'aggs119__tu',
    'aggs120__tu',
    'aggs121__tu',
    'aggs122__tu',
    'aggs123__tu',
    'aggs124__tu',
    'rets101__tu',
    'rets102__tu',
    'rets103__tu',
    'rets104__tu',
    'rets105__tu',
    'rets106__tu',
    'rets107__tu',
    'rets108__tu',
    'rets109__tu',
    'rets110__tu',
    'rets111__tu',
    'rets112__tu',
    'rets113__tu',
    'rets114__tu',
    'rets115__tu',
    'rets116__tu',
    'rets117__tu',
    'rets118__tu',
    'rets119__tu',
    'rets120__tu',
    'rets121__tu',
    'rets122__tu',
    'rets123__tu',
    'rets124__tu',
    'revs101__tu',
    'revs102__tu',
    'revs103__tu',
    'revs104__tu',
    'revs105__tu',
    'revs106__tu',
    'revs107__tu',
    'revs108__tu',
    'revs109__tu',
    'revs110__tu',
    'revs111__tu',
    'revs112__tu',
    'revs113__tu',
    'revs114__tu',
    'revs115__tu',
    'revs116__tu',
    'revs117__tu',
    'revs118__tu',
    'revs119__tu',
    'revs120__tu',
    'revs121__tu',
    'revs122__tu',
    'revs123__tu',
    'revs124__tu',
    # 20024-05-07
    'strvehicletype__app', # unavailable at time of application
]

# %%
# check if cols in dataset
list_leaky_manual = [col for col in list_leaky_manual if col in list_cols]
print(f'There are {len(list_leaky_manual)} features to remove manually')
for a, col in enumerate(list_leaky_manual):
    print(f'{a+1} - {col}')
# Out:
# There are 290 features to remove manually
# 1 - runningnetloss__app
# 2 - chargeoffamount__app
# 3 - defaultamount__app
# 4 - bitlhmgroup__app
# 5 - bitfunded__app
# 6 - dealerzip__app
# 7 - dealercity__app
# 8 - analyticsmatchkey__tu
# 9 - strzipcode__app
# 10 - bitapproved__app
# 11 - strcity__app
# 12 - fltapprovedapr_contract__app
# 13 - subjectage__ln
# 14 - applicationmonth__app
# 15 - applicationdayofweek__app
# 16 - applicationquarter__app
# 17 - fltapproveddebttoincome__app
# 18 - bitsystemdecline__app
# 19 - addrinputtaxyr__ln
# 20 - bitrolled__app
# 21 - addrcurrenttaxyr__ln
# 22 - RunningNetLoss
# 23 - bitTarget24Months
# 24 - linkb011__tu
# 25 - fltacquisitionfee__app
# 26 - flttaxgrossreceipts__app
# 27 - agg101__tu
# 28 - agg102__tu
# 29 - agg103__tu
# 30 - agg104__tu
# 31 - agg105__tu
# 32 - agg106__tu
# 33 - agg107__tu
# 34 - agg108__tu
# 35 - agg109__tu
# 36 - agg110__tu
# 37 - agg111__tu
# 38 - agg112__tu
# 39 - agg113__tu
# 40 - agg114__tu
# 41 - agg115__tu
# 42 - agg116__tu
# 43 - agg117__tu
# 44 - agg118__tu
# 45 - agg119__tu
# 46 - agg120__tu
# 47 - agg121__tu
# 48 - agg122__tu
# 49 - agg123__tu
# 50 - agg124__tu
# 51 - agg201__tu
# 52 - agg202__tu
# 53 - agg203__tu
# 54 - agg204__tu
# 55 - agg205__tu
# 56 - agg206__tu
# 57 - agg207__tu
# 58 - agg208__tu
# 59 - agg209__tu
# 60 - agg210__tu
# 61 - agg211__tu
# 62 - agg212__tu
# 63 - agg213__tu
# 64 - agg214__tu
# 65 - agg215__tu
# 66 - agg216__tu
# 67 - agg217__tu
# 68 - agg218__tu
# 69 - agg219__tu
# 70 - agg220__tu
# 71 - agg221__tu
# 72 - agg222__tu
# 73 - agg223__tu
# 74 - agg224__tu
# 75 - agg301__tu
# 76 - agg302__tu
# 77 - agg303__tu
# 78 - agg304__tu
# 79 - agg305__tu
# 80 - agg306__tu
# 81 - agg307__tu
# 82 - agg308__tu
# 83 - agg309__tu
# 84 - agg310__tu
# 85 - agg311__tu
# 86 - agg312__tu
# 87 - agg313__tu
# 88 - agg314__tu
# 89 - agg315__tu
# 90 - agg316__tu
# 91 - agg317__tu
# 92 - agg318__tu
# 93 - agg319__tu
# 94 - agg320__tu
# 95 - agg321__tu
# 96 - agg322__tu
# 97 - agg323__tu
# 98 - agg324__tu
# 99 - agg401__tu
# 100 - agg402__tu
# 101 - agg403__tu
# 102 - agg404__tu
# 103 - agg405__tu
# 104 - agg406__tu
# 105 - agg407__tu
# 106 - agg408__tu
# 107 - agg409__tu
# 108 - agg410__tu
# 109 - agg411__tu
# 110 - agg412__tu
# 232 - aggs114__tu
# 233 - aggs115__tu
# 234 - aggs116__tu
# 235 - aggs117__tu
# 236 - aggs118__tu
# 237 - aggs119__tu
# 238 - aggs120__tu
# 239 - aggs121__tu
# 240 - aggs122__tu
# 241 - aggs123__tu
# 242 - aggs124__tu
# 243 - rets101__tu
# 244 - rets102__tu
# 245 - rets103__tu
# 246 - rets104__tu
# 247 - rets105__tu
# 248 - rets106__tu
# 249 - rets107__tu
# 250 - rets108__tu
# 251 - rets109__tu
# 252 - rets110__tu
# 253 - rets111__tu
# 254 - rets112__tu
# 255 - rets113__tu
# 256 - rets114__tu
# 257 - rets115__tu
# 258 - rets116__tu
# 259 - rets117__tu
# 260 - rets118__tu
# 261 - rets119__tu
# 262 - rets120__tu
# 263 - rets121__tu
# 264 - rets122__tu
# 265 - rets123__tu
# 266 - rets124__tu
# 267 - revs101__tu
# 268 - revs102__tu
# 269 - revs103__tu
# 270 - revs104__tu
# 271 - revs105__tu
# 272 - revs106__tu
# 273 - revs107__tu
# 274 - revs108__tu
# 275 - revs109__tu
# 276 - revs110__tu
# 277 - revs111__tu
# 278 - revs112__tu
# 279 - revs113__tu
# 280 - revs114__tu
# 281 - revs115__tu
# 282 - revs116__tu
# 283 - revs117__tu
# 284 - revs118__tu
# 285 - revs119__tu
# 286 - revs120__tu
# 287 - revs121__tu
# 288 - revs122__tu
# 289 - revs123__tu
# 290 - revs124__tu

# %% [markdown]
# ### Combine All Leaky Features and Remove Duplicates

# %%
# combine lists
list_cols_all = list_leaky_by_name + list_leaky_manual
list_cols_all = list(dict.fromkeys(list_cols_all))

# make df
df = pd.DataFrame({'feature': list_cols_all})

# save
str_filename = 'df_cols_drop.csv'
str_local_path = f'{str_dirname_output}/{str_filename}'
df.to_csv(str_local_path, index=False)

# show
df
# Out:
#             feature
# 0        permid__tu
# 1       partyid__tu
# 2        acctid__tu
# 3    middlename__tu
# 4     uniqueid__app
# ..              ...
# 332     revs120__tu
# 333     revs121__tu
# 334     revs122__tu
# 335     revs123__tu
# 336     revs124__tu
#
# [337 rows x 1 columns]

# %% [markdown]
# ### Save ```df_no_leaks.csv```

# %%
# create list of cols to keep
list_cols_keep = [col for col in list_cols if col not in list_cols_all]
# extend
list_cols_keep.extend(list_cols_id)
# rm dups
list_cols_keep = list(dict.fromkeys(list_cols_keep))

# create df
df = pd.DataFrame({'feature': list_cols_keep})
# save
str_filename = 'df_cols_noleaks.csv'
str_local_path = f'{str_dirname_output}/{str_filename}'
df.to_csv(str_local_path, index=False)

# show
df
# Out:
#                              feature
# 0              fltstatesalestax__app
# 1                         bkc204__tu
# 2                         bkc203__tu
# 3                         bkc202__tu
# 4                         bkc201__tu
# ...                              ...
# 2150   strdealershiptrackertype__app
# 2151  bitdealerapplicantsamezip__app
# 2152                        uniqueid
# 2153            applicationdate__app
# 2154                          target
#
# [2155 rows x 1 columns]
