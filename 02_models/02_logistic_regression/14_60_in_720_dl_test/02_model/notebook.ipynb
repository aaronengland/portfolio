# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm
import pickle
import sklearn.metrics as skm
from scipy.stats import ks_2samp
import math
import shap
from sklearn.linear_model import LogisticRegression
from scipy.stats import spearmanr
import datetime as dt

# silence warnings
import warnings
warnings.filterwarnings('ignore')

# binning
try:
    from optbinning import OptimalBinning
except:
    ! pip install optbinning
    from optbinning import OptimalBinning
# Out:
# (CVXPY) Jan 28 11:40:26 PM: Encountered unexpected exception importing solver GLOP:
# RuntimeError('Unrecognized new version of ortools (9.11.4210). Expected < 9.10.0. Please open a feature request on cvxpy to enable support for this version.')
# (CVXPY) Jan 28 11:40:26 PM: Encountered unexpected exception importing solver PDLP:
# RuntimeError('Unrecognized new version of ortools (9.11.4210). Expected < 9.10.0. Please open a feature request on cvxpy to enable support for this version.')

# %%
print(f'Latest run date: {dt.datetime.today()}')
# Out:
# Latest run date: 2025-01-28 23:40:26.928836

# %% [markdown]
# #### Functions

# %%
def target_by_data_set(df, str_target):
    df_tmp = df.groupby(by='data_set', as_index=False).agg({
        str_target: 'mean',
    })
    df_tmp['sort'] = df_tmp['data_set'].map(dict_sort)
    df_tmp.sort_values(by='sort', ascending=True, inplace=True)
    df_tmp.drop('sort', axis=1, inplace=True)

    # plot
    x = df_tmp['data_set']
    y = df_tmp[str_target]
    fig, ax = plt.subplots(figsize=(9,5))
    ax.set_title(f'Mean {str_target} by Data Set')
    ax.set_xlabel('Data Set')
    ax.set_ylabel(f'Mean {str_target}')
    # bars
    bars = ax.bar(x, y)
    # add labels to the bars
    ax.bar_label(bars, fmt='%.4f')
    # show
    plt.show()

# %%
def target_by_feature(df, str_col, str_target):
    df_tmp = df[df['data_set'] == 'train'].groupby(by=str_col, as_index=False).agg({
        str_target: 'mean',
    })

    # plot
    x = df_tmp[str_col].astype(str)
    y = df_tmp[str_target]
    fig, ax = plt.subplots(figsize=(9,5))
    ax.set_title(f'Mean {str_target} by {str_col}')
    ax.set_xlabel('Data Set')
    ax.set_ylabel(f'Mean {str_target}')
    # bars
    bars = ax.bar(x, y)
    # add labels to the bars
    ax.bar_label(bars, fmt='%.4f')
    # show
    plt.show()

# %%
def target_by_feature_quantile(df, str_col, int_n_quantiles, str_target):
    # get quantile
    df_tmp = df[df['data_set'] == 'train'].copy()
    # replace infs with nan
    df_tmp[str_col] = df_tmp[str_col].replace(np.inf, np.nan)
    # drop missing rows
    df_tmp = df_tmp.dropna(subset=[str_col])
    # get quantile
    df_tmp['quantile'] = pd.qcut(df_tmp[str_col], q=int_n_quantiles, duplicates='drop')
    # min-max
    df_tmp['min'] = df_tmp[str_col]
    df_tmp['max'] = df_tmp[str_col]
    # get target mean by quangtile
    df_tmp = df_tmp.groupby(by='quantile', as_index=False).agg({
        'min': 'min',
        'max': 'max',
        str_target: 'mean',
    })
    # sort
    df_tmp.sort_values(by='min', ascending=True, inplace=True)
    # rank
    df_tmp['quantile'] = range(1, df_tmp.shape[0]+1)
    # plot
    fig, ax = plt.subplots(figsize=(9,5))
    ax.set_title(f'{str_target} by {str_col} Quantile')
    ax.set_xlabel(f'{str_col} Quantile')
    ax.set_ylabel(str_target)
    ax.plot(df_tmp['quantile'].astype(str), df_tmp[str_target])
    plt.show()

# %%
def get_suggested_constraints(df, list_cols_model, str_target, int_n_quantiles):
    list_dict_row = []
    for col in tqdm(list_cols_model):
        # df_tmp
        df_tmp = df.copy()
        # replace infs with nan
        df_tmp[col] = df_tmp[col].replace(np.inf, np.nan)
        # drop missing rows
        df_tmp = df_tmp.dropna(subset=[col])
        # get number of unique values
        int_n_unique = df_tmp[col].nunique()
        # logic
        if int_n_unique <= int_n_quantiles:
            # create a feature named quantile
            df_tmp['quantile'] = df_tmp[str_col]
        else:
            # get quantile
            df_tmp['quantile'] = pd.qcut(df_tmp[col], q=int_n_quantiles, duplicates='drop')
        # min-max
        df_tmp['min'] = df_tmp[col]
        df_tmp['max'] = df_tmp[col]
        # get target mean by quangtile
        df_tmp = df_tmp.groupby(by='quantile', as_index=False).agg({
            'min': 'min',
            'max': 'max',
            str_target: 'mean',
        })
        # sort
        df_tmp.sort_values(by='min', ascending=True, inplace=True)
        # create rank column
        df_tmp['rank'] = range(1, df_tmp.shape[0]+1)
        # fit trend line
        try:
            flt_slope, flt_intercept = np.polyfit(x=df_tmp['rank'], y=df_tmp[str_target], deg=1)
        except:
            flt_slope = 0
            flt_intercept = 0
        # logic for monotone contraints
        if flt_slope > 0:
            int_constraint = 1
            str_imputation = 'max'
        elif flt_slope < 0:
            int_constraint = -1
            str_imputation = 'min'
        else:
            int_constraint = 0
            str_imputation = 'none'
        # make a row
        dict_row = {
            'feature': col,
            'intercept': flt_intercept,
            'slope': flt_slope,
            'constraint': int_constraint,
            'imputation': str_imputation,
        }
        list_dict_row.append(dict_row)
    # make a df
    df = pd.DataFrame(list_dict_row)
    # return
    return df

# %%
class OverSampling:
    def __init__(self, df, str_target, flt_target_value, flt_current_value):
        self.df = df
        self.str_target = str_target
        self.flt_target_value = flt_target_value
        self.flt_current_value = flt_current_value
    # oversample zeros
    def oversample_zeros(self):
        # get n zeros
        df_zeros = self.df[self.df[str_target] == 0].copy()
        int_n_zeros_original = df_zeros.shape[0]
        # get n ones
        df_ones = self.df[self.df[str_target] == 1].copy()
        int_n_ones_original = df_ones.shape[0]
        # get total
        int_n_total_original = int_n_zeros_original + int_n_ones_original
        # solve for the new n total to reach target
        int_n_total_new = math.ceil(int_n_ones_original / flt_target_value)
        # get n additional 0s
        int_n_additional_zeros = int_n_total_new - int_n_ones_original - int_n_zeros_original
        # get sample
        df_zeros_additional = df_zeros.sample(n=int_n_additional_zeros, random_state=42)
        # concat
        df = pd.concat([df_zeros, df_ones, df_zeros_additional])
        # shuffle
        df = df.sample(frac=1.0, random_state=42)
        # return
        return df 
    # undersample ones
    def oversample_ones(self):
        # get n zeros
        df_zeros = self.df[self.df[str_target] == 0].copy()
        int_n_zeros_original = df_zeros.shape[0]
        # get n ones
        df_ones = self.df[self.df[str_target] == 1].copy()
        int_n_ones_original = df_ones.shape[0]
        # get total
        int_n_total_original = int_n_zeros_original + int_n_ones_original
        # solve for number of 1s
        int_n_additional_ones = math.ceil((int_n_ones_original - (flt_target_value * int_n_total_original)) / (flt_target_value - 1))
        # get sample
        df_ones_additional = df_ones.sample(n=int_n_additional_ones, random_state=42)
        # concat
        df = pd.concat([df_zeros, df_ones, df_ones_additional])
        # shuffle
        df = df.sample(frac=1.0, random_state=42)
        # return
        return df
    # sample
    def sample(self):
        # logic
        if self.flt_target_value < self.flt_current_value:
            df = self.oversample_zeros()
        else:
            df = self.oversample_ones()
        # return
        return df

# %%
def get_logistic_regression_feat_importance(df, cls_model_inference, list_cols_model=None):
    try:
        list_cols_model = list(cls_model_inference.feature_names_in_)
    except:
        pass
    df_tmp = pd.DataFrame({
        'feature': list_cols_model,
        'importance': list(cls_model_inference.coef_[0]),
    })
    # make into dictionary
    dict_coef = dict(zip(df_tmp['feature'], df_tmp['importance']))
    # subset df
    df_tmp = df[list_cols_model].copy()
    # iterate
    for key, val in dict_coef.items():
        # multiply the feature by the coefficient
        df_tmp[key] = df_tmp[key] * val
    # get the mean for each
    list_dict_row = []
    for col in list_cols_model:
        flt_mean = df_tmp[col].mean()
        dict_row = {
            'feature': col,
            'importance': flt_mean,
        }
        list_dict_row.append(dict_row)
    # make df
    df_tmp = pd.DataFrame(list_dict_row)
    # make abs value
    df_tmp['importance_abs'] = df_tmp['importance'].apply(abs)
    # sort    
    df_tmp.sort_values(by='importance_abs', ascending=False, inplace=True)
    # return
    return df_tmp

# %%
# ks
def get_ks_score(y_true, y_pred):
    fpr, tpr, _ = skm.roc_curve(
        y_true=y_true,
        y_score=y_pred,
    )
    ks_stat = max(tpr - fpr)
    return ks_stat

# %%
def evaluate(y_train, list_predictions_train, y_test, list_predictions_test, y_holdout, list_predictions_holdout):
    # get auc
    flt_auc_train = skm.roc_auc_score(
        y_true=y_train,
        y_score=list_predictions_train,
    )
    print(f'AUC Train: {flt_auc_train:0.4f}')
    flt_auc_test = skm.roc_auc_score(
        y_true=y_test,
        y_score=list_predictions_test,
    )
    print(f'AUC Test: {flt_auc_test:0.4f}')
    flt_auc_holdout = skm.roc_auc_score(
        y_true=y_holdout,
        y_score=list_predictions_holdout,
    )
    print(f'AUC Holdout: {flt_auc_holdout:0.4f}')
    print()
    # logloss
    flt_logloss_train = skm.log_loss(
        y_true=y_train,
        y_pred=list_predictions_train,
    )
    print(f'Logloss Train: {flt_logloss_train:0.4f}')
    flt_logloss_test = skm.log_loss(
        y_true=y_test,
        y_pred=list_predictions_test,
    )
    print(f'Logloss Test: {flt_logloss_test:0.4f}')
    flt_logloss_holdout = skm.log_loss(
        y_true=y_holdout,
        y_pred=list_predictions_holdout,
    )
    print(f'Logloss Holdout: {flt_logloss_holdout:0.4f}')
    print()
    # ks
    flt_ks_train = get_ks_score(
        y_true=y_train,
        y_pred=list_predictions_train,
    )
    print(f'KS Train: {flt_ks_train:0.4f}')
    flt_ks_test = get_ks_score(
        y_true=y_test,
        y_pred=list_predictions_test,
    )
    print(f'KS Test: {flt_ks_test:0.4f}')
    flt_ks_holdout = get_ks_score(
        y_true=y_holdout,
        y_pred=list_predictions_holdout,
    )
    print(f'KS Holdout: {flt_ks_holdout:0.4f}')
    return flt_auc_train, flt_auc_test

# %%
def get_directions_of_predictions(X, list_predictions, str_target, list_actual, list_cols, int_n_quantiles):
    # assign predictions
    X['yhat'] = list_predictions
    # assign actual
    X[str_target] = list_actual
    # iterate and plot
    for col in tqdm(list_cols):
        # get number of unique values
        int_n_unique = X[col].nunique()
        # logic
        if int_n_unique <= int_n_quantiles:
            # create a feature named quantile
            X['quantile'] = X[col]
        else:
            # get quantile
            X['quantile'] = pd.qcut(X[col], q=int_n_quantiles, duplicates='drop')
        # get target mean by quantile
        X['min'] = X[col]
        # group
        df_tmp = X.groupby(by='quantile', as_index=False).agg({
            'min': 'min',
            'yhat': 'mean',
            str_target: 'mean',
            
        })
        # sort
        df_tmp.sort_values(by='min', ascending=True, inplace=True)
        # rank
        df_tmp['quantile'] = range(1, df_tmp.shape[0]+1)
        # plot
        fig, ax = plt.subplots(figsize=(9,5))
        ax.set_title(f'Mean Predicted and Actual by {col} Quantile')
        ax.set_xlabel(f'{col} Quantile')
        ax.set_ylabel(str_target)
        # predicted
        ax.plot(df_tmp['quantile'].astype(str), df_tmp['yhat'], label='Predicted')
        # actual
        ax.plot(df_tmp['quantile'].astype(str), df_tmp[str_target], label='Actual')
        # legend
        ax.legend()
        # show
        plt.show()

# %%
def get_directions_of_predictions_for_scorecard(X, list_predictions, str_target, list_actual, list_cols, df_bins):
    # assign predictions
    X['yhat'] = list_predictions
    # assign actual
    X[str_target] = list_actual
    # iterate and plot
    for col in tqdm(list_cols):
        # map bin label
        df_bins_tmp = df_bins[df_bins['feature'] == col].copy()
        # create dict
        dict_map_bin = dict(zip(df_bins_tmp['bin'], df_bins_tmp['bin_label']))
        # map
        X['bin_label'] = X[col].map(dict_map_bin)
        # group
        df_tmp = X.groupby(by='bin_label', as_index=False).agg({
            'yhat': 'mean',
            str_target: 'mean',
            
        })
        # sort
        df_tmp.sort_values(by='bin_label', ascending=True, inplace=True)
        # plot
        fig, ax = plt.subplots(figsize=(9,5))
        ax.set_title(f'Mean Predicted and Actual by {col} Bin (Ascending)')
        ax.set_xlabel(f'{col} Bin')
        ax.set_ylabel(str_target)
        # predicted
        ax.plot(df_tmp['bin_label'].astype(str), df_tmp['yhat'], label='Predicted')
        # actual
        ax.plot(df_tmp['bin_label'].astype(str), df_tmp[str_target], label='Actual')
        # legend
        ax.legend()
        # show
        plt.show()

# %%
def get_mean_actual_by_prediction_quantile(X, list_predictions, list_actual, str_target, int_n_quantiles, str_model_type):
    # assign
    X['yhat'] = list_predictions
    X[str_target] = list_actual
    # get quantile
    X['quantile'] = pd.qcut(X['yhat'], q=int_n_quantiles, duplicates='drop')
    # get min
    X['min'] = X['yhat']
    X['predicted'] = X['yhat']
    # group
    df_tmp = X.groupby(by='quantile', as_index=False).agg({
        'min': 'min',
        'predicted': 'mean',
        str_target: 'mean',
    })
    # sort
    df_tmp.sort_values(by='min', ascending=True, inplace=True)
    # create rank
    df_tmp['quantile'] = range(1, df_tmp.shape[0]+1)
    # plot
    fig, ax = plt.subplots(figsize=(9,5))
    ax.set_title(f'Mean {str_target} by {str_model_type} Prediction Quantile')
    ax.set_xlabel('Prediction Quantile')
    ax.set_ylabel(f'Mean {str_target}')
    ax.plot(df_tmp['quantile'].astype(str), df_tmp[str_target], label='Actual')
    ax.plot(df_tmp['quantile'].astype(str), df_tmp['predicted'], label='Predicted')
    # legend
    ax.legend()
    # show
    plt.show()

# %%
def remove_multicollinearity(X, list_cols_model, dict_map_importance, flt_threshold):
    list_dict_row = []
    a = 0
    for col1 in tqdm(list_cols_model):
        # temporary list
        list_tmp = list_cols_model[a+1:].copy()
        for col2 in list_tmp:
            # get correlation
            x = X[col1]
            y = X[col2]
            flt_r, flt_p = spearmanr(x, y)
            # row
            dict_row = {
                'col1': col1,
                'col2': col2,
                'r': flt_r,
            }
            # append
            list_dict_row.append(dict_row)
        # add 1
        a += 1
    # make df
    df_tmp = pd.DataFrame(list_dict_row)
    # make absolute value
    df_tmp['r_abs'] = df_tmp['r'].apply(abs)
    # map importance
    df_tmp['col1_importance'] = df_tmp['col1'].map(dict_map_importance)
    df_tmp['col2_importance'] = df_tmp['col2'].map(dict_map_importance)
    # flag high correlation
    df_tmp['high_correlation'] = df_tmp['r_abs'].apply(
        lambda x: 1 if x >= flt_threshold else 0,
    )
    # subset
    df_tmp = df_tmp[df_tmp['high_correlation'] == 1].copy()
    # select feature to remove
    df_tmp['remove_feature'] = df_tmp.apply(
        lambda x: x['col2'] if x['col1_importance'] > x['col2_importance']  else x['col1'],
        axis=1,
    )
    # get feats to rm
    list_cols_remove = list(df_tmp['remove_feature'])
    # rm dups
    list_cols_remove = list(dict.fromkeys(list_cols_remove))
    # return
    return df_tmp, list_cols_remove

# %%
def bin_features(list_cols, X_train, y_train, X_test, X_holdout, dict_monotone_constraints):
    dict_bins = {}
    list_cols_scorecard = []
    for col in tqdm(list_cols):
        # get the monotonicity
        int_monotonicity = dict_monotone_constraints[col]
        # logic
        if int_monotonicity == -1:
            str_monotonic_trend = 'descending'
        else:
            str_monotonic_trend = 'ascending'
            
        # logic
        if col == 'ENG-loan_to_value':
            prebinning_method = 'uniform'
        else:
            prebinning_method = 'cart'
        
        # init
        cls_binning = OptimalBinning(
            name=col,
            dtype='numerical',
            solver='cp',
            monotonic_trend=str_monotonic_trend,
            prebinning_method=prebinning_method,
            user_splits=None,
            user_splits_fixed=None,
        )
        # fit
        cls_binning.fit(
            X_train[col],
            y_train,
        )
        # assign
        dict_bins[col] = cls_binning
        # transform
        str_col = f'{col}_binned'
        X_train[str_col] = cls_binning.transform(
            X_train[col],
            metric='woe',
        )
        X_test[str_col] = cls_binning.transform(
            X_test[col],
            metric='woe',
        )
        X_holdout[str_col] = cls_binning.transform(
            X_holdout[col],
            metric='woe',
        )
        # append
        list_cols_scorecard.append(str_col)
    # return
    return dict_bins, list_cols_scorecard, X_train, X_test, X_holdout

# %%
def weight_the_coefficients(cls_model_inference, dict_weights):
    # features and coefficients
    list_feature_names_in = list(cls_model_inference.feature_names_in_)
    arr_coef = cls_model_inference.coef_[0]
    # multiply by weights and reassign
    for key, val in dict_weights.items():
        try:
            # get idx of feature
            int_idx = list_feature_names_in.index(key)
            # get the coef
            flt_coef = arr_coef[int_idx]
            # multiply by weight
            flt_coef = flt_coef * val
            # reassign
            arr_coef[int_idx] = flt_coef
        except ValueError:
            pass
    # reassign into model
    cls_model_inference.coef_[0] = arr_coef
    # return
    return cls_model_inference

# %%
def prep_for_partial_score(list_predictions, y_actual, flt_prop_pred=0.6):
    df_pred = pd.DataFrame({
        'pred': list_predictions,
        'actual': y_actual,
    })
    df_pred.sort_values(by='pred', ascending=True, inplace=True)
    # get rows
    int_nrows_subset = int(flt_prop_pred * len(df_pred))
    df_pred = df_pred.iloc[:int_nrows_subset].copy()
    # return
    return df_pred

# %% [markdown]
# #### Constants

# %%
str_project = os.getcwd().split('/')[4].replace('_','-')
print(f'Project: {str_project}')

str_task = os.getcwd().split('/')[5]
print(f'Task: {str_task}')

str_subtask = os.getcwd().split('/')[6]
print(f'Subtask: {str_subtask}')

str_target = 'Early_Pay_Delinquency_60_720_Flag'
print(f'Target: {str_target}')

str_dirname_output = './output'

# for ordering
dict_sort = {
    'train': 1,
    'valid': 2,
    'test': 3,
    'inform': 4,
    'holdout': 5,
}

# correlation threshold
flt_threshold = 0.70

# nan threshold
flt_threshold_nan = 0.80

# max rounds
int_rounds_max = 150

# weights
dict_weights = {
    'ENG-loan_to_value_binned': 1.0,
    'g106s__tu_binned': 1.0,
}

flt_prop_pred = 1.0
# Out:
# Project: 20241112-simple-model-test
# Task: 14_60_in_720_dl_test
# Subtask: 02_model
# Target: Early_Pay_Delinquency_60_720_Flag

# %% [markdown]
# #### Output directory

# %%
try:
    os.mkdir(str_dirname_output)
except:
    pass

# %% [markdown]
# #### Get data dictionary for mapping descriptions

# %%
str_filename = 'data_dictionary.csv'
str_local_path = f'../../data_dictionary/{str_filename}'
df_tmp = pd.read_csv(str_local_path)
dict_map_descriptions = dict(zip(df_tmp['feature_name'], df_tmp['Description']))

# %% [markdown]
# #### Import data

# %%
# import
list_str_filename = [
    'train',
    'test',
    'holdout',
]
list_df = []
for str_filename in tqdm(list_str_filename):
    str_filename_tmp = f'df_{str_filename}.gzip'
    str_uri = f's3://{str_project}/{str_task}/01_data_split/{str_filename_tmp}'
    df = pd.read_parquet(
        str_uri,
    )
    # append
    list_df.append(df)
# concatenate
df = pd.concat(list_df)
# save memory
del list_df
# show
df
# Out:
# 100%|██████████| 3/3 [00:07<00:00,  2.40s/it]
#        accountid             request_datetime response_model_name  \
# 0        5702434  2021-07-26 16:29:29.3903686               Gen10
# 1        5714239  2021-07-26 16:39:34.1121025               Gen10
# 2        5713063  2021-07-26 16:48:39.3211104               Gen10
# 3        5713732  2021-07-27 09:02:35.3300974               Gen10
# 4        5715634  2021-07-27 09:18:12.2190097               Gen10
# ...          ...                          ...                 ...
# 41693    6453589    2022-11-30 23:45:32+00:00      PRESTIGE-GENXI
# 41694    6418453    2022-11-30 23:48:36+00:00      PRESTIGE-GENXI
# 41695    6411914    2022-11-30 23:53:12+00:00      PRESTIGE-GENXI
# 41696    6434554    2022-11-30 23:57:04+00:00      PRESTIGE-GENXI
# 41697    6447867    2022-11-30 23:58:56+00:00      PRESTIGE-GENXI
#
#                                                 file_key  bitdebtor  \
# 0      deprecated/03_pull_payloads_tbldove/df_request...          1
# 1      deprecated/03_pull_payloads_tbldove/df_request...          1
# 2      deprecated/03_pull_payloads_tbldove/df_request...          1
# 3      deprecated/03_pull_payloads_tbldove/df_request...          1
# 4      deprecated/03_pull_payloads_tbldove/df_request...          1
# ...                                                  ...        ...
# 41693       01_pull_payloads/df_requests_2022-11-30.gzip          1
# 41694       01_pull_payloads/df_requests_2022-11-30.gzip          1
# 41695       01_pull_payloads/df_requests_2022-11-30.gzip          1
# 41696       01_pull_payloads/df_requests_2022-11-30.gzip          1
# 41697       01_pull_payloads/df_requests_2022-11-30.gzip          1
#
#        bitdebtor__app dealerstate__app strdealershiptrackertype__app  \
# 0                   1             Iowa                     Franchise
# 1                   1             Utah                     Franchise
# 2                   1         Illinois                     Franchise
# 3                   1         Michigan                   Independent
# 4                   1          Arizona                     Franchise
# ...               ...              ...                           ...
# 41693               1         Michigan                     Franchise
# 41694               1         Michigan                   Independent
# 41695               1       Washington                   Independent
# 41696               1         Michigan                     Franchise
# 41697               1   South Carolina                   Independent
#
#          strname__app bitdealertrack__app  ...  ENG-perfect_payment_hx_open  \
# 0                Iowa                True  ...                            0
# 1                Utah                True  ...                            0
# 2            Illinois                True  ...                            0
# 3            Michigan               False  ...                            0
# 4             Arizona               False  ...                            0
# ...               ...                 ...  ...                          ...
# 41693        Michigan               False  ...                            0
# 41694        Michigan               False  ...                            0
# 41695      Washington                True  ...                            0
# 41696        Michigan               False  ...                            0
# 41697  South Carolina                True  ...                            0
#
#        ENG-perfect_payment_hx_closed  ENG-bk_x_wtd_avg request_month    row  \
# 0                                  0          0.616667    2021-07-01      1
# 1                                  0               NaN    2021-07-01      2
# 2                                  0               NaN    2021-07-01      3
# 3                                  1          0.000000    2021-07-01      4
# 4                                  1          0.000000    2021-07-01      5
# ...                              ...               ...           ...    ...
# 41693                              1          0.000000    2022-11-01  41694
# 41694                              0          0.000000    2022-11-01  41695
# 41695                              0               NaN    2022-11-01  41696
# 41696                              0          0.137374    2022-11-01  41697
# 41697                              1          0.000000    2022-11-01  41698
#
#        prop_row data_set  train  test  holdout
# 0      0.000024    train      1     0        0
# 1      0.000048    train      1     0        0
# 2      0.000072    train      1     0        0
# 3      0.000096    train      1     0        0
# 4      0.000120    train      1     0        0
# ...         ...      ...    ...   ...      ...
# 41693  0.999904  holdout      0     0        1
# 41694  0.999928  holdout      0     0        1
# 41695  0.999952  holdout      0     0        1
# 41696  0.999976  holdout      0     0        1
# 41697  1.000000  holdout      0     0        1
#
# [41698 rows x 2776 columns]

# %% [markdown]
# #### Remove the features that belong in a set

# %%
list_cols_set = [
    'agg101',
    'agg102',
    'agg103',
    'agg104',
    'agg105',
    'agg106',
    'agg107',
    'agg108',
    'agg109',
    'agg110',
    'agg111',
    'agg112',
    'agg113',
    'agg114',
    'agg115',
    'agg116',
    'agg117',
    'agg118',
    'agg119',
    'agg120',
    'agg121',
    'agg122',
    'agg123',
    'agg124',
    'agg201',
    'agg202',
    'agg203',
    'agg204',
    'agg205',
    'agg206',
    'agg207',
    'agg208',
    'agg209',
    'agg210',
    'agg211',
    'agg212',
    'agg213',
    'agg214',
    'agg215',
    'agg216',
    'agg217',
    'agg218',
    'agg219',
    'agg220',
    'agg221',
    'agg222',
    'agg223',
    'agg224',
    'agg301',
    'agg302',
    'agg303',
    'agg304',
    'agg305',
    'agg306',
    'agg307',
    'agg308',
    'agg309',
    'agg310',
    'agg311',
    'agg312',
    'agg313',
    'agg314',
    'agg315',
    'agg316',
    'agg317',
    'agg318',
    'agg319',
    'agg320',
    'agg321',
    'agg322',
    'agg323',
    'agg324',
    'agg401',
    'agg402',
    'agg403',
    'agg404',
    'agg405',
    'agg406',
    'agg407',
    'agg408',
    'agg409',
    'agg410',
    'agg411',
    'agg412',
    'agg413',
    'agg414',
    'agg415',
    'agg416',
    'agg417',
    'agg418',
    'agg419',
    'agg420',
    'agg421',
    'agg422',
    'agg423',
    'agg424',
    'agg501',
    'agg502',
    'agg503',
    'agg504',
    'agg505',
    'agg506',
    'agg507',
    'agg508',
    'agg509',
    'agg510',
    'agg511',
    'agg512',
    'agg513',
    'agg514',
    'agg515',
    'agg516',
    'agg517',
    'agg518',
    'agg519',
    'agg520',
    'agg521',
    'agg522',
    'agg523',
    'agg524',
    'agg601',
    'agg602',
    'agg603',
    'agg604',
    'agg605',
    'agg606',
    'agg607',
    'agg608',
    'agg609',
    'agg610',
    'agg611',
    'agg612',
    'agg613',
    'agg614',
    'agg615',
    'agg616',
    'agg617',
    'agg618',
    'agg619',
    'agg620',
    'agg621',
    'agg622',
    'agg623',
    'agg624',
    'agg701',
    'agg702',
    'agg703',
    'agg704',
    'agg705',
    'agg706',
    'agg707',
    'agg708',
    'agg709',
    'agg710',
    'agg711',
    'agg712',
    'agg713',
    'agg714',
    'agg715',
    'agg716',
    'agg717',
    'agg718',
    'agg719',
    'agg720',
    'agg721',
    'agg722',
    'agg723',
    'agg724',
    'agg801',
    'agg802',
    'agg803',
    'agg804',
    'agg805',
    'agg806',
    'agg807',
    'agg808',
    'agg809',
    'agg810',
    'agg811',
    'agg812',
    'agg813',
    'agg814',
    'agg815',
    'agg816',
    'agg817',
    'agg818',
    'agg819',
    'agg820',
    'agg821',
    'agg822',
    'agg823',
    'agg824',
    'aggs101',
    'aggs102',
    'aggs103',
    'aggs104',
    'aggs105',
    'aggs106',
    'aggs107',
    'aggs108',
    'aggs109',
    'aggs110',
    'aggs111',
    'aggs112',
    'aggs113',
    'aggs114',
    'aggs115',
    'aggs116',
    'aggs117',
    'aggs118',
    'aggs119',
    'aggs120',
    'aggs121',
    'aggs122',
    'aggs123',
    'aggs124',
    'rets101',
    'rets102',
    'rets103',
    'rets104',
    'rets105',
    'rets106',
    'rets107',
    'rets108',
    'rets109',
    'rets110',
    'rets111',
    'rets112',
    'rets113',
    'rets114',
    'rets115',
    'rets116',
    'rets117',
    'rets118',
    'rets119',
    'rets120',
    'rets121',
    'rets122',
    'rets123',
    'rets124',
    'revs101',
    'revs102',
    'revs103',
    'revs104',
    'revs105',
    'revs106',
    'revs107',
    'revs108',
    'revs109',
    'revs110',
    'revs110',
    'revs111',
    'revs112',
    'revs113',
    'revs114',
    'revs115',
    'revs116',
    'revs117',
    'revs118',
    'revs119',
    'revs120',
    'revs121',
    'revs122',
    'revs123',
    'revs124',
]
# add suffix
list_cols_set = [f'{col}__tu' for col in list_cols_set]
print(f'There are {len(list_cols_set)} set features')
# drop
df.drop(list_cols_set, axis=1, inplace=True)
# show
df
# Out:
# There are 265 set features
#        accountid             request_datetime response_model_name  \
# 0        5702434  2021-07-26 16:29:29.3903686               Gen10
# 1        5714239  2021-07-26 16:39:34.1121025               Gen10
# 2        5713063  2021-07-26 16:48:39.3211104               Gen10
# 3        5713732  2021-07-27 09:02:35.3300974               Gen10
# 4        5715634  2021-07-27 09:18:12.2190097               Gen10
# ...          ...                          ...                 ...
# 41693    6453589    2022-11-30 23:45:32+00:00      PRESTIGE-GENXI
# 41694    6418453    2022-11-30 23:48:36+00:00      PRESTIGE-GENXI
# 41695    6411914    2022-11-30 23:53:12+00:00      PRESTIGE-GENXI
# 41696    6434554    2022-11-30 23:57:04+00:00      PRESTIGE-GENXI
# 41697    6447867    2022-11-30 23:58:56+00:00      PRESTIGE-GENXI
#
#                                                 file_key  bitdebtor  \
# 0      deprecated/03_pull_payloads_tbldove/df_request...          1
# 1      deprecated/03_pull_payloads_tbldove/df_request...          1
# 2      deprecated/03_pull_payloads_tbldove/df_request...          1
# 3      deprecated/03_pull_payloads_tbldove/df_request...          1
# 4      deprecated/03_pull_payloads_tbldove/df_request...          1
# ...                                                  ...        ...
# 41693       01_pull_payloads/df_requests_2022-11-30.gzip          1
# 41694       01_pull_payloads/df_requests_2022-11-30.gzip          1
# 41695       01_pull_payloads/df_requests_2022-11-30.gzip          1
# 41696       01_pull_payloads/df_requests_2022-11-30.gzip          1
# 41697       01_pull_payloads/df_requests_2022-11-30.gzip          1
#
#        bitdebtor__app dealerstate__app strdealershiptrackertype__app  \
# 0                   1             Iowa                     Franchise
# 1                   1             Utah                     Franchise
# 2                   1         Illinois                     Franchise
# 3                   1         Michigan                   Independent
# 4                   1          Arizona                     Franchise
# ...               ...              ...                           ...
# 41693               1         Michigan                     Franchise
# 41694               1         Michigan                   Independent
# 41695               1       Washington                   Independent
# 41696               1         Michigan                     Franchise
# 41697               1   South Carolina                   Independent
#
#          strname__app bitdealertrack__app  ...  ENG-perfect_payment_hx_open  \
# 0                Iowa                True  ...                            0
# 1                Utah                True  ...                            0
# 2            Illinois                True  ...                            0
# 3            Michigan               False  ...                            0
# 4             Arizona               False  ...                            0
# ...               ...                 ...  ...                          ...
# 41693        Michigan               False  ...                            0
# 41694        Michigan               False  ...                            0
# 41695      Washington                True  ...                            0
# 41696        Michigan               False  ...                            0
# 41697  South Carolina                True  ...                            0
#
#        ENG-perfect_payment_hx_closed  ENG-bk_x_wtd_avg request_month    row  \
# 0                                  0          0.616667    2021-07-01      1
# 1                                  0               NaN    2021-07-01      2
# 2                                  0               NaN    2021-07-01      3
# 3                                  1          0.000000    2021-07-01      4
# 4                                  1          0.000000    2021-07-01      5
# ...                              ...               ...           ...    ...
# 41693                              1          0.000000    2022-11-01  41694
# 41694                              0          0.000000    2022-11-01  41695
# 41695                              0               NaN    2022-11-01  41696
# 41696                              0          0.137374    2022-11-01  41697
# 41697                              1          0.000000    2022-11-01  41698
#
#        prop_row data_set  train  test  holdout
# 0      0.000024    train      1     0        0
# 1      0.000048    train      1     0        0
# 2      0.000072    train      1     0        0
# 3      0.000096    train      1     0        0
# 4      0.000120    train      1     0        0
# ...         ...      ...    ...   ...      ...
# 41693  0.999904  holdout      0     0        1
# 41694  0.999928  holdout      0     0        1
# 41695  0.999952  holdout      0     0        1
# 41696  0.999976  holdout      0     0        1
# 41697  1.000000  holdout      0     0        1
#
# [41698 rows x 2512 columns]

# %% [markdown]
# #### Identify and drop the ln features (DLv2)

# %%
list_cols_ln = [col for col in df.columns if '__ln' in col.lower()]
print(f'There are {len(list_cols_ln)} ln features')
# drop
df.drop(list_cols_ln, axis=1, inplace=True)
# show
df
# Out:
# There are 197 ln features
#        accountid             request_datetime response_model_name  \
# 0        5702434  2021-07-26 16:29:29.3903686               Gen10
# 1        5714239  2021-07-26 16:39:34.1121025               Gen10
# 2        5713063  2021-07-26 16:48:39.3211104               Gen10
# 3        5713732  2021-07-27 09:02:35.3300974               Gen10
# 4        5715634  2021-07-27 09:18:12.2190097               Gen10
# ...          ...                          ...                 ...
# 41693    6453589    2022-11-30 23:45:32+00:00      PRESTIGE-GENXI
# 41694    6418453    2022-11-30 23:48:36+00:00      PRESTIGE-GENXI
# 41695    6411914    2022-11-30 23:53:12+00:00      PRESTIGE-GENXI
# 41696    6434554    2022-11-30 23:57:04+00:00      PRESTIGE-GENXI
# 41697    6447867    2022-11-30 23:58:56+00:00      PRESTIGE-GENXI
#
#                                                 file_key  bitdebtor  \
# 0      deprecated/03_pull_payloads_tbldove/df_request...          1
# 1      deprecated/03_pull_payloads_tbldove/df_request...          1
# 2      deprecated/03_pull_payloads_tbldove/df_request...          1
# 3      deprecated/03_pull_payloads_tbldove/df_request...          1
# 4      deprecated/03_pull_payloads_tbldove/df_request...          1
# ...                                                  ...        ...
# 41693       01_pull_payloads/df_requests_2022-11-30.gzip          1
# 41694       01_pull_payloads/df_requests_2022-11-30.gzip          1
# 41695       01_pull_payloads/df_requests_2022-11-30.gzip          1
# 41696       01_pull_payloads/df_requests_2022-11-30.gzip          1
# 41697       01_pull_payloads/df_requests_2022-11-30.gzip          1
#
#        bitdebtor__app dealerstate__app strdealershiptrackertype__app  \
# 0                   1             Iowa                     Franchise
# 1                   1             Utah                     Franchise
# 2                   1         Illinois                     Franchise
# 3                   1         Michigan                   Independent
# 4                   1          Arizona                     Franchise
# ...               ...              ...                           ...
# 41693               1         Michigan                     Franchise
# 41694               1         Michigan                   Independent
# 41695               1       Washington                   Independent
# 41696               1         Michigan                     Franchise
# 41697               1   South Carolina                   Independent
#
#          strname__app bitdealertrack__app  ...  ENG-perfect_payment_hx_open  \
# 0                Iowa                True  ...                            0
# 1                Utah                True  ...                            0
# 2            Illinois                True  ...                            0
# 3            Michigan               False  ...                            0
# 4             Arizona               False  ...                            0
# ...               ...                 ...  ...                          ...
# 41693        Michigan               False  ...                            0
# 41694        Michigan               False  ...                            0
# 41695      Washington                True  ...                            0
# 41696        Michigan               False  ...                            0
# 41697  South Carolina                True  ...                            0
#
#        ENG-perfect_payment_hx_closed  ENG-bk_x_wtd_avg request_month    row  \
# 0                                  0          0.616667    2021-07-01      1
# 1                                  0               NaN    2021-07-01      2
# 2                                  0               NaN    2021-07-01      3
# 3                                  1          0.000000    2021-07-01      4
# 4                                  1          0.000000    2021-07-01      5
# ...                              ...               ...           ...    ...
# 41693                              1          0.000000    2022-11-01  41694
# 41694                              0          0.000000    2022-11-01  41695
# 41695                              0               NaN    2022-11-01  41696
# 41696                              0          0.137374    2022-11-01  41697
# 41697                              1          0.000000    2022-11-01  41698
#
#        prop_row  data_set  train  test  holdout
# 0      0.000024     train      1     0        0
# 1      0.000048     train      1     0        0
# 2      0.000072     train      1     0        0
# 3      0.000096     train      1     0        0
# 4      0.000120     train      1     0        0
# ...         ...       ...    ...   ...      ...
# 41693  0.999904   holdout      0     0        1
# 41694  0.999928   holdout      0     0        1
# 41695  0.999952   holdout      0     0        1
# 41696  0.999976   holdout      0     0        1
# 41697  1.000000   holdout      0     0        1
#
# [41698 rows x 2315 columns]

# %% [markdown]
# #### Target mean by data set

# %%
target_by_data_set(
    df=df,
    str_target=str_target,
)

# %% [markdown]
# #### Target mean by BK

# %%
str_col = 'ENG-bk'
target_by_feature(
    df=df, 
    str_col=str_col,
    str_target=str_target,
)

# %% [markdown]
# #### Target mean by dealer type

# %%
str_col = 'ENG-franchise'
target_by_feature(
    df=df, 
    str_col=str_col,
    str_target=str_target,
)

# %% [markdown]
# #### Target mean by has a codebtor

# %%
str_col = 'ENG-has_codebtor'
target_by_feature(
    df=df, 
    str_col=str_col,
    str_target=str_target,
)

# %% [markdown]
# #### Target by LTV Quantile

# %%
# get quantile
str_col = 'ENG-loan_to_value'
int_n_quantiles = 5
target_by_feature_quantile(
    df=df,
    str_col=str_col,
    int_n_quantiles=int_n_quantiles,
    str_target=str_target,
)

# %% [markdown]
# #### Target by income quantile

# %%
# get quantile
str_col = 'fltgrossmonthly__income_sum'
int_n_quantiles = 5
target_by_feature_quantile(
    df=df,
    str_col=str_col,
    int_n_quantiles=int_n_quantiles,
    str_target=str_target,
)

# %% [markdown]
# #### Target by PTI Quantile

# %%
# get quantile
str_col = 'ENG-payment_to_income'
int_n_quantiles = 5
target_by_feature_quantile(
    df=df,
    str_col=str_col,
    int_n_quantiles=int_n_quantiles,
    str_target=str_target,
)

# %% [markdown]
# #### Target by DTI quantile

# %%
# get quantile
str_col = 'ENG-dti'
int_n_quantiles = 5
target_by_feature_quantile(
    df=df,
    str_col=str_col,
    int_n_quantiles=int_n_quantiles,
    str_target=str_target,
)

# %% [markdown]
# #### List of columns in model

# %%
# list cols ignore
list_cols_ignore = [
    'uniqueid__ln',
    'biglnriskviewattributesv5id__ln',
    'bigaccountid__ln',
    'bigdebtorid__ln',
    'biglnriskviewscoreid__ln',
    'bitinvalid__ln',
    'uniqueid__app',
    'bigdebtorid__app',
    'request_datetime',
    'approvaldate__app',
    'fundeddate__app',
    'defaultdate__app',
    'chargeoffdate__app',
    'applicationdate__app',
    'run_date',
    'data_set',
    'bankruptcychapter__ln',
    'bankruptcycount24month__ln',
    'bankruptcycount__ln',
    'bankruptcydismissed24month__ln',
    'bankruptcystatus__ln',
    'bankruptcytimenewest__ln',
    'criminalfelonycount12month__ln',
    'criminalfelonycount__ln',
    'addronfilecollege__ln',
    'phoneinputmobile__ln',
    'educationprogramattended__ln',
    'subjectdeceased__ln',
    'subjectage__ln',
    'dti__app',
    'flt_payment_open__tu_pmthx',
    'ssndatelowissued__ln',
    'educationevidence__ln',
    'businessassociation__ln',
    'sourcevoterregistration__ln',
    'addrcurrentcountyratio__ln',
    'addrinputcountyratio__ln',
    'addrinputtractratio__ln',
    'addrinputblockratio__ln',
    'addrcurrenttractratio__ln',
    'addrcurrentblockratio__ln',
    'ENG-franchise',
    'ENG-has_codebtor',
    'ENG-has_auto',
    'ENG-open_auto',
    'ENG-dti',
    # bks
    'ENG-bk',
    's207a__tu',
    's207s__tu',
    'cvbk__tu',
    'linkf032__tu',
    'g094s__tu',
    'g099s__tu',
    'g100s__tu',
    's207s__tu',
    's207a__tu',
    'g099a__tu',
    'cvbk__tu',
    'linkt008__tu',
    'linkt009__tu',
    'linkt010__tu',
    'linkf032__tu',
    'alert1__ln',
    'alert2__ln',
    'alert3__ln',
    'alert4__ln',
    'alert5__ln',
    'alert6__ln',
    'alert7__ln',
    'alert8__ln',
    'alert9__ln',
    'alert10__ln',
]
# structure
list_cols_structure = [
    'fltgrossmonthly__income_sum', # income
    'miles_odometer__app',
    'ENG-int_n_months',
    'ENG-int_n_months_total',
    'ENG-wtd_avg',
    'ENG-closed_auto',
    'ENG-open_and_closed_auto',
    'ENG-3mo_bad',
    'ENG-6mo_bad',
    'ENG-3mo_bad_end',
    'ENG-6mo_bad_end',
    'ENG-vehicle_age',
    'ENG-payment_to_income',
    'ENG-loan_to_value',
    'ENG-perfect_payment_hx',
    'ENG-perfect_payment_hx_open',
    'ENG-perfect_payment_hx_closed',
]
# tu
list_cols_tu = [col for col in df.columns if '__tu' in col]
# ln
list_cols_ln = [col for col in df.columns if '__ln' in col]
# combine
list_cols_model = list_cols_structure + list_cols_tu + list_cols_ln
# rm
list_cols_model = [col for col in list_cols_model if col not in list_cols_ignore]
print(f'There are {len(list_cols_model)} features available for scorecard')
# Out:
# There are 2178 features available for scorecard

# %% [markdown]
# #### Hard code list of columns in the model

# %%
# list_cols_model = [
#     # ability
#     'dti__app',
#     # exposure
#     'ENG-loan_to_value',
#     'miles_odometer__app',
#     # pmt hx (auto)
#     'flt_wtd_avg_open__tu_pmthx',
#     'flt_wtd_avg_closed__tu_pmthx',
#     'int_30dpd_open__tu_pmthx',
#     'int_30dpd_closed__tu_pmthx',
#     # pmt hx (overall)
#     'au206s__tu',
#     'balmag01__tu',
#     'g251b__tu',
#     'g242f__tu',
#     # length
#     'g106s__tu',
#     're01s__tu',
#     # early delinquency
#     'int_bad_3mo_open__tu_pmthx',
#     'int_bad_3mo_closed__tu_pmthx',
#     'int_bad_6mo_open__tu_pmthx',
#     'int_bad_6mo_closed__tu_pmthx',
# ]
# print(f'There are {len(list_cols_model)} features available for scorecard')

# %%
# rm non-numeric
list_cols_nonnumeric = []
for col in tqdm(list_cols_model):
    str_dtype = df[col].dtype
    if str_dtype not in ['int64','float64']:
        list_cols_nonnumeric.append(col)
    else:
        pass
print(f'There were {len(list_cols_nonnumeric)} non-numeric columns')
# rm
list_cols_model = [col for col in list_cols_model if col not in list_cols_nonnumeric]
print(f'There are {len(list_cols_model)} features available for scorecard')
# Out:
# 100%|██████████| 2178/2178 [00:00<00:00, 24160.53it/s]
# There were 62 non-numeric columns
# There are 2116 features available for scorecard

# %%
# show the duplicates
ser_freq = pd.Series(list_cols_model).value_counts()
ser_freq = ser_freq[ser_freq > 1]
dict_freq = dict(ser_freq)
print('Duplicate Columns:')
a = 1
for key, val in dict_freq.items():
    print(f'{a}: {key}: {val}')
    a += 1
print('')
# rm dups
list_cols_model = list(dict.fromkeys(list_cols_model))
print(f'There are {len(list_cols_model)} features available for scorecard')
# Out:
# Duplicate Columns:
#
# There are 2116 features available for scorecard

# %% [markdown]
# #### Get any feature with a lot of missing in any data set

# %%
list_isnull_all = []
for str_df in tqdm(['train','test','holdout']):
    df_tmp = df[df['data_set'] == str_df].copy()
    # get those with > 0.8
    ser_isnull = df_tmp.isnull().mean()
    list_isnull = list(ser_isnull[ser_isnull >= flt_threshold_nan].index)
    list_isnull_all += list_isnull
# rm dups
list_isnull_all = list(dict.fromkeys(list_isnull_all))
print(f'There were {len(list_isnull_all)} columns {flt_threshold_nan*100:0.2f}% or more missing in any data frame')
list_cols_model = [col for col in list_cols_model if col not in list_isnull_all]
print(f'There are {len(list_cols_model)} features available for scorecard')
# Out:
# 100%|██████████| 3/3 [00:02<00:00,  1.31it/s]
# There were 1173 columns 80.00% or more missing in any data frame
# There are 982 features available for scorecard

# %% [markdown]
# #### Drop

# %%
df.drop(list_isnull_all, axis=1, inplace=True)

# %% [markdown]
# #### Get any feature with a lot missing in most recent month

# %%
str_filename = 'df.gzip'
str_uri = f's3://{str_project}/08_prep_data/{str_filename}'
df_tmp = pd.read_parquet(str_uri)
df_tmp['request_month'] = df_tmp['request_datetime'].apply(
    lambda x: str(x)[:10],
)
df_tmp['request_month'] = pd.to_datetime(df_tmp['request_month'])
df_tmp['request_month'] = df_tmp['request_month'].dt.to_period('M').dt.to_timestamp()
dtm_max = df_tmp['request_month'].max()
df_tmp = df_tmp[df_tmp['request_month'] != dtm_max].copy()
dtm_max = df_tmp['request_month'].max()
# get prop missing by col
ser_isnull = df_tmp[list_cols_model].isnull().mean()
list_isnull_all = list(ser_isnull[ser_isnull >= flt_threshold_nan].index)
# rm dups
list_isnull_all = list(dict.fromkeys(list_isnull_all))
print(f'There were {len(list_isnull_all)} columns {flt_threshold_nan*100:0.2f}% or more missing in the most recent month of payloads')
list_cols_model = [col for col in list_cols_model if col not in list_isnull_all]
print(f'There are {len(list_cols_model)} features available for scorecard')
# save memory
del df_tmp
# Out:
# There were 0 columns 80.00% or more missing in the most recent month of payloads
# There are 982 features available for scorecard

# %%
# show it
list_isnull_all
# Out:
# []

# %% [markdown]
# #### Drop

# %%
df.drop(list_isnull_all, axis=1, inplace=True)

# %% [markdown]
# #### Get relationship with target in training data

# %%
df_tmp = df[df['data_set'] == 'train'].copy()
df_tmp = df_tmp.sample(frac=0.10, random_state=42)
int_n_quantiles = 5
df_tmp = get_suggested_constraints(
    df=df_tmp,
    list_cols_model=list_cols_model,
    str_target=str_target,
    int_n_quantiles=int_n_quantiles,
)
# map data dictionary
df_tmp['description'] = df_tmp['feature'].map(dict_map_descriptions)
# show
df_tmp
# Out:
# 100%|██████████| 982/982 [00:36<00:00, 27.13it/s]
#                               feature  intercept     slope  constraint  \
# 0         fltgrossmonthly__income_sum   0.328744 -0.016313          -1
# 1                 miles_odometer__app   0.187391  0.030637           1
# 2                    ENG-int_n_months   0.346597 -0.026286          -1
# 3              ENG-int_n_months_total   0.359604 -0.035050          -1
# 4                         ENG-wtd_avg   0.328533 -0.023669          -1
# ..                                ...        ...       ...         ...
# 977        int_90dpd_closed__tu_pmthx   0.133162  0.133162           1
# 978      int_bad_3mo_closed__tu_pmthx   0.277911 -0.000020          -1
# 979      int_bad_6mo_closed__tu_pmthx   0.258796  0.000009           1
# 980  int_bad_3mo_closed_end__tu_pmthx   0.247380  0.000026           1
# 981  int_bad_6mo_closed_end__tu_pmthx   0.255678  0.000013           1
#
#     imputation description
# 0          min         NaN
# 1          max         NaN
# 2          min         NaN
# 3          min         NaN
# 4          min         NaN
# ..         ...         ...
# 977        max         NaN
# 978        min         NaN
# 979        max         NaN
# 980        max         NaN
# 981        max         NaN
#
# [982 rows x 6 columns]

# %% [markdown]
# #### Create monotone constraints dictionary for later

# %%
dict_monotone_constraints = dict(zip(df_tmp['feature'], df_tmp['constraint']))

# manually adjust
dict_monotone_constraints['fltgrossmonthly__income_sum'] = -1
dict_monotone_constraints['ENG-int_n_months'] = -1
dict_monotone_constraints['ENG-int_n_months_total'] = -1
dict_monotone_constraints['int_n_months_open__tu_pmthx'] = -1
dict_monotone_constraints['int_n_months_closed__tu_pmthx'] = -1
dict_monotone_constraints['ENG-wtd_avg'] = -1
dict_monotone_constraints['ENG-bk_x_wtd_avg'] = -1
dict_monotone_constraints['ENG-has_auto'] = -1
dict_monotone_constraints['ENG-open_auto'] = -1
dict_monotone_constraints['ENG-closed_auto'] = -1
dict_monotone_constraints['ENG-open_and_closed_auto'] = -1
dict_monotone_constraints['ENG-3mo_bad'] = 1
dict_monotone_constraints['ENG-6mo_bad'] = 1
dict_monotone_constraints['ENG-3mo_bad_end'] = 1
dict_monotone_constraints['ENG-6mo_bad_end'] = 1
dict_monotone_constraints['ENG-dti'] = 1
dict_monotone_constraints['ENG-franchise'] = -1
dict_monotone_constraints['ENG-vehicle_age'] = 1
dict_monotone_constraints['miles_odometer__app'] = 1
dict_monotone_constraints['ENG-payment_to_income'] = 1
dict_monotone_constraints['ENG-loan_to_value'] = 1
dict_monotone_constraints['ENG-bk'] = -1
dict_monotone_constraints['ENG-perfect_payment_hx'] = -1
dict_monotone_constraints['ENG-perfect_payment_hx_open'] = -1
dict_monotone_constraints['ENG-perfect_payment_hx_closed'] = -1
dict_monotone_constraints['flt_wtd_avg_open__tu_pmthx'] = -1
dict_monotone_constraints['flt_wtd_avg_closed__tu_pmthx'] = -1
dict_monotone_constraints['int_bad_3mo_open__tu_pmthx'] = 1
dict_monotone_constraints['int_bad_3mo_closed__tu_pmthx'] = 1 
dict_monotone_constraints['int_bad_6mo_open__tu_pmthx'] = 1
dict_monotone_constraints['int_bad_6mo_closed__tu_pmthx'] = 1
dict_monotone_constraints['int_bad_3mo_open_end__tu_pmthx'] = 1
dict_monotone_constraints['int_bad_3mo_closed_end__tu_pmthx'] = 1 
dict_monotone_constraints['int_bad_6mo_open_end__tu_pmthx'] = 1
dict_monotone_constraints['int_bad_6mo_closed_end__tu_pmthx'] = 1

# %%
# save
str_filename = 'dict_monotone_constraints.pkl'
str_local_path = f'{str_dirname_output}/{str_filename}'
pickle.dump(dict_monotone_constraints, open(str_local_path, 'wb'))

# show
#dict_monotone_constraints

# %% [markdown]
# #### Create dictionary for imputation type

# %%
dict_impute_type = dict(zip(df_tmp['feature'], df_tmp['imputation']))

# manually adjust
dict_impute_type['fltgrossmonthly__income_sum'] = 'min'
dict_impute_type['ENG-int_n_months'] = 'min'
dict_impute_type['ENG-int_n_months_total'] = 'min'
dict_impute_type['int_n_months_open__tu_pmthx'] = 'min'
dict_impute_type['int_n_months_closed__tu_pmthx'] = 'min',
dict_impute_type['ENG-wtd_avg'] = 'min'
dict_impute_type['ENG-bk_x_wtd_avg'] = 'min'
dict_impute_type['ENG-has_auto'] = 'min'
dict_impute_type['ENG-open_auto'] = 'min'
dict_impute_type['ENG-closed_auto'] = 'min'
dict_impute_type['ENG-open_and_closed_auto'] = 'min'
dict_impute_type['ENG-3mo_bad'] = 'max'
dict_impute_type['ENG-6mo_bad'] = 'max'
dict_impute_type['ENG-3mo_bad_end'] = 'max'
dict_impute_type['ENG-6mo_bad_end'] = 'max'
dict_impute_type['ENG-dti'] = 'max'
dict_impute_type['ENG-franchise'] = 'min'
dict_impute_type['ENG-vehicle_age'] = 'max'
dict_impute_type['miles_odometer__app'] = 'max'
dict_impute_type['ENG-payment_to_income'] = 'max'
dict_impute_type['ENG-loan_to_value'] = 'max'
dict_impute_type['ENG-bk'] = 'min'
dict_impute_type['ENG-perfect_payment_hx'] = 'min'
dict_impute_type['ENG-perfect_payment_hx_open'] = 'min'
dict_impute_type['ENG-perfect_payment_hx_closed'] = 'min'
dict_impute_type['flt_wtd_avg_open__tu_pmthx'] = 'min'
dict_impute_type['int_bad_3mo_open__tu_pmthx'] = 'max'
dict_impute_type['int_bad_3mo_closed__tu_pmthx'] = 'max'
dict_impute_type['int_bad_6mo_open__tu_pmthx'] = 'max'
dict_impute_type['int_bad_6mo_closed__tu_pmthx'] = 'max'
dict_impute_type['int_bad_3mo_open_end__tu_pmthx'] = 'max'
dict_impute_type['int_bad_3mo_closed_end__tu_pmthx'] = 'max'
dict_impute_type['int_bad_6mo_open_end__tu_pmthx'] = 'max'
dict_impute_type['int_bad_6mo_closed_end__tu_pmthx'] = 'max'

# %%
# create an imputation dictionary
dict_impute = {}
df_train = df[df['data_set'] == 'train'].copy()
for key, val in tqdm(dict_impute_type.items()):
    # logic
    if val == 'min':
        flt_val = df_train[key].min()
    else:
        flt_val = df_train[key].max()
    # assign
    dict_impute[key] = flt_val

# manually impute
dict_impute['miles_odometer__app'] = df_train['miles_odometer__app'].mean()
dict_impute['ENG-loan_to_value'] = df_train['ENG-loan_to_value'].mean()

# save
str_filename = 'dict_impute.pkl'
str_local_path = f'{str_dirname_output}/{str_filename}'
pickle.dump(dict_impute, open(str_local_path, 'wb'))

# save memory
del df_train
# show
#dict_impute
# Out:
# 100%|██████████| 988/988 [00:00<00:00, 5150.40it/s]

# %%
# impute
for key, val in tqdm(dict_impute.items()):
    # replace any infs with nan
    df[key] = df[key].replace(np.inf, np.nan)
    # fillna
    df[key] = df[key].fillna(val)
# show
df
# Out:
# 100%|██████████| 988/988 [00:01<00:00, 732.94it/s]
#        accountid             request_datetime response_model_name  \
# 0        5702434  2021-07-26 16:29:29.3903686               Gen10
# 1        5714239  2021-07-26 16:39:34.1121025               Gen10
# 2        5713063  2021-07-26 16:48:39.3211104               Gen10
# 3        5713732  2021-07-27 09:02:35.3300974               Gen10
# 4        5715634  2021-07-27 09:18:12.2190097               Gen10
# ...          ...                          ...                 ...
# 41693    6453589    2022-11-30 23:45:32+00:00      PRESTIGE-GENXI
# 41694    6418453    2022-11-30 23:48:36+00:00      PRESTIGE-GENXI
# 41695    6411914    2022-11-30 23:53:12+00:00      PRESTIGE-GENXI
# 41696    6434554    2022-11-30 23:57:04+00:00      PRESTIGE-GENXI
# 41697    6447867    2022-11-30 23:58:56+00:00      PRESTIGE-GENXI
#
#                                                 file_key  bitdebtor  \
# 0      deprecated/03_pull_payloads_tbldove/df_request...          1
# 1      deprecated/03_pull_payloads_tbldove/df_request...          1
# 2      deprecated/03_pull_payloads_tbldove/df_request...          1
# 3      deprecated/03_pull_payloads_tbldove/df_request...          1
# 4      deprecated/03_pull_payloads_tbldove/df_request...          1
# ...                                                  ...        ...
# 41693       01_pull_payloads/df_requests_2022-11-30.gzip          1
# 41694       01_pull_payloads/df_requests_2022-11-30.gzip          1
# 41695       01_pull_payloads/df_requests_2022-11-30.gzip          1
# 41696       01_pull_payloads/df_requests_2022-11-30.gzip          1
# 41697       01_pull_payloads/df_requests_2022-11-30.gzip          1
#
#        bitdebtor__app dealerstate__app strdealershiptrackertype__app  \
# 0                   1             Iowa                     Franchise
# 1                   1             Utah                     Franchise
# 2                   1         Illinois                     Franchise
# 3                   1         Michigan                   Independent
# 4                   1          Arizona                     Franchise
# ...               ...              ...                           ...
# 41693               1         Michigan                     Franchise
# 41694               1         Michigan                   Independent
# 41695               1       Washington                   Independent
# 41696               1         Michigan                     Franchise
# 41697               1   South Carolina                   Independent
#
#          strname__app bitdealertrack__app  ...  ENG-perfect_payment_hx_open  \
# 0                Iowa                True  ...                            0
# 1                Utah                True  ...                            0
# 2            Illinois                True  ...                            0
# 3            Michigan               False  ...                            0
# 4             Arizona               False  ...                            0
# ...               ...                 ...  ...                          ...
# 41693        Michigan               False  ...                            0
# 41694        Michigan               False  ...                            0
# 41695      Washington                True  ...                            0
# 41696        Michigan               False  ...                            0
# 41697  South Carolina                True  ...                            0
#
#       ENG-perfect_payment_hx_closed  ENG-bk_x_wtd_avg  request_month    row  \
# 0                                 0          0.616667     2021-07-01      1
# 1                                 0          0.000000     2021-07-01      2
# 2                                 0          0.000000     2021-07-01      3
# 3                                 1          0.000000     2021-07-01      4
# 4                                 1          0.000000     2021-07-01      5
# ...                             ...               ...            ...    ...
# 41693                             1          0.000000     2022-11-01  41694
# 41694                             0          0.000000     2022-11-01  41695
# 41695                             0          0.000000     2022-11-01  41696
# 41696                             0          0.137374     2022-11-01  41697
# 41697                             1          0.000000     2022-11-01  41698
#
#        prop_row  data_set  train  test  holdout
# 0      0.000024     train      1     0        0
# 1      0.000048     train      1     0        0
# 2      0.000072     train      1     0        0
# 3      0.000096     train      1     0        0
# 4      0.000120     train      1     0        0
# ...         ...       ...    ...   ...      ...
# 41693  0.999904   holdout      0     0        1
# 41694  0.999928   holdout      0     0        1
# 41695  0.999952   holdout      0     0        1
# 41696  0.999976   holdout      0     0        1
# 41697  1.000000   holdout      0     0        1
#
# [41698 rows x 1142 columns]

# %% [markdown]
# #### Show proportion missing

# %%
ser_isnull = df[list_cols_model].isnull().mean()
ser_isnull[ser_isnull > 0]
# Out:
# Series([], dtype: float64)

# %% [markdown]
# #### Bin features before sampling

# %%
df_train = df[df['data_set'] == 'train'].copy()
df_test = df[df['data_set'] == 'test'].copy()
df_holdout = df[df['data_set'] == 'holdout'].copy()
# save memory
del df

# %%
dict_bins, list_cols_scorecard, df_train, df_test, df_holdout = bin_features(
    list_cols=list_cols_model,
    X_train=df_train,
    y_train=df_train[str_target],
    X_test=df_test,
    X_holdout=df_holdout,
    dict_monotone_constraints=dict_monotone_constraints,
)
# pickle dict_bins
str_filename = 'dict_bins.pkl'
str_local_path = f'{str_dirname_output}/{str_filename}'
pickle.dump(dict_bins, open(str_local_path, 'wb'))
# Out:
# 100%|██████████| 982/982 [00:38<00:00, 25.80it/s]

# %% [markdown]
# #### Check for no variance bins

# %%
# make sure every column has at least 2 bins
list_col_no_var = []
for col in tqdm(list_cols_scorecard):
    int_n_unique = df_train[col].nunique()
    # logic
    if int_n_unique < 2:
        list_col_no_var.append(col)
    else:
        pass
print(f'There are {len(list_col_no_var)} features with no variance after binning')
# rm
list_cols_scorecard = [col for col in list_cols_scorecard if col not in list_col_no_var]
print(f'There are {len(list_cols_scorecard)} features available for scorecard inclusion')
# Out:
# 100%|██████████| 982/982 [00:00<00:00, 1659.90it/s]
# There are 238 features with no variance after binning
# There are 744 features available for scorecard inclusion

# %%
# show bins
df_tmp = df_train.copy()
df_tmp['target'] = df_train[str_target]
list_df = []
for col in tqdm(list_cols_scorecard):
    # get original column
    str_col_original = col.split('_binned')[0]
    # get min max and mean
    df_grouped = df_tmp.groupby(by=col, as_index=False).agg({
        str_col_original: ['min', 'max', 'count'],
        'target': 'mean',
    })
    # sort
    df_grouped.sort_values(by=(str_col_original, 'min'), ascending=True, inplace=True)
    df_grouped['feature'] = col
    # rename
    list_cols = ['bin','min','max','count','target','feature']
    df_grouped.columns = list_cols
    df_grouped['prop'] = df_grouped['count'] / df_grouped['count'].sum()
    # bin label
    df_grouped['bin_label'] = range(1, df_grouped.shape[0]+1)
    # reorder
    list_cols = ['feature','bin','min','max','count','prop','target','bin_label']
    df_grouped = df_grouped[list_cols].copy()
    # append
    list_df.append(df_grouped)
    
    #print(f'{a+1} - {str_col_original}')
    #print(df_grouped)
    #print()

# make df
df_bins = pd.concat(list_df)

# save
str_filename = 'df_bins.csv'
str_local_path = f'{str_dirname_output}/{str_filename}'
df_bins.to_csv(str_local_path, index=False)

# show
df_bins
# Out:
# 100%|██████████| 744/744 [00:09<00:00, 78.66it/s]
#                                     feature       bin      min      max  \
# 0        fltgrossmonthly__income_sum_binned -0.112058     0.00  3245.72
# 1        fltgrossmonthly__income_sum_binned -0.088137  3245.83  3776.38
# 2        fltgrossmonthly__income_sum_binned  0.034510  3776.64  4116.67
# 3        fltgrossmonthly__income_sum_binned  0.042981  4116.89  4879.90
# 4        fltgrossmonthly__income_sum_binned  0.053438  4880.18  5280.26
# ..                                      ...       ...      ...      ...
# 0       int_bad_6mo_closed__tu_pmthx_binned -0.083606     1.00     1.00
# 1   int_bad_3mo_closed_end__tu_pmthx_binned  0.235304     0.00     0.00
# 0   int_bad_3mo_closed_end__tu_pmthx_binned -0.057739     1.00     1.00
# 1   int_bad_6mo_closed_end__tu_pmthx_binned  0.191972     0.00     0.00
# 0   int_bad_6mo_closed_end__tu_pmthx_binned -0.047368     1.00     1.00
#
#     count      prop    target  bin_label
# 0    8676  0.346790  0.296219          1
# 1    3660  0.146295  0.291257          2
# 2    2048  0.081861  0.266602          3
# 3    3880  0.155088  0.264948          4
# 4    1529  0.061116  0.262917          5
# ..    ...       ...       ...        ...
# 0   14880  0.594772  0.290323          2
# 1    5209  0.208210  0.229219          1
# 0   19809  0.791790  0.285022          2
# 1    5178  0.206971  0.236964          1
# 0   19840  0.793029  0.282913          2
#
# [2453 rows x 8 columns]

# %%
df_bins[df_bins['feature'] == 'ENG-loan_to_value_binned']
# Out:
#                     feature       bin       min       max  count      prop  \
# 9  ENG-loan_to_value_binned  2.147141  0.185462  0.775976     95  0.003797
# 8  ENG-loan_to_value_binned  1.034299  0.776875  0.894086    178  0.007115
# 7  ENG-loan_to_value_binned  0.624390  0.894686  1.012695    942  0.037653
# 6  ENG-loan_to_value_binned  0.215360  1.012821  1.130922   3089  0.123471
# 5  ENG-loan_to_value_binned  0.041781  1.130961  1.249133   6422  0.256695
# 4  ENG-loan_to_value_binned -0.103403  1.249141  1.367298   7435  0.297186
# 3  ENG-loan_to_value_binned -0.119005  1.367374  1.603364   6823  0.272724
# 2  ENG-loan_to_value_binned -0.417809  1.603826  1.707916     22  0.000879
# 1  ENG-loan_to_value_binned -1.265106  1.744855  2.148742      7  0.000280
# 0  ENG-loan_to_value_binned -1.382889  2.388451  2.549193      5  0.000200
#
#      target  bin_label
# 9  0.042105          1
# 8  0.117978          2
# 7  0.167728          3
# 6  0.232761          4
# 5  0.265182          5
# 4  0.294418          6
# 3  0.297670          7
# 2  0.363636          8
# 1  0.571429          9
# 0  0.600000         10

# %% [markdown]
# #### Get simple logistic regression performance for multicollinearity

# %%
list_dict_row = []
for col in tqdm(list_cols_scorecard):
    # init
    cls_model_inference = LogisticRegression(
        random_state=42,
        fit_intercept=True,
    )
    # fit
    cls_model_inference.fit(
        df_train[[col]],
        df_train[str_target],
    )
    # do not adjust weights in this step!
    # get predictions
    list_predictions_test = list(cls_model_inference.predict_proba(df_test[[col]])[:,1])
    # get score
    flt_score = skm.roc_auc_score(
        y_true=df_test[str_target],
        y_score=list_predictions_test,
    )
    # row
    dict_row = {
        'feature': col,
        'score': flt_score,
    }
    # append
    list_dict_row.append(dict_row)
# df
df_tmp = pd.DataFrame(list_dict_row)
df_tmp.sort_values(by='score', ascending=False, inplace=True)
df_tmp['feature'] = df_tmp['feature'].apply(
    lambda x: x.split('_binned')[0],
)
# map importance
dict_map_importance = dict(zip(df_tmp['feature'], df_tmp['score']))
# show
df_tmp
# Out:
# 100%|██████████| 744/744 [00:29<00:00, 25.14it/s]
#           feature     score
# 379     g415s__tu  0.562784
# 422      cv15__tu  0.562784
# 215     g232s__tu  0.561354
# 219     g238s__tu  0.552977
# 421      cv14__tu  0.549330
# ..            ...       ...
# 645  linkf086__tu  0.488514
# 679  linkf161__tu  0.487298
# 667  linkf143__tu  0.486619
# 685  linkf170__tu  0.484199
# 673  linkf152__tu  0.482108
#
# [744 rows x 2 columns]

# %% [markdown]
# #### Check for multicollinearity before sampling

# %%
# list_cols = [f'{col.split("_binned")[0]}' for col in list_cols_scorecard]
# # find multicollinear columns
# df_tmp = df_train.sample(frac=0.01, random_state=42)
# df_tmp, list_cols_remove = remove_multicollinearity(
#     X=df_tmp, 
#     list_cols_model=list_cols, 
#     dict_map_importance=dict_map_importance, 
#     flt_threshold=flt_threshold,
# )

# save
str_filename = 'df_multicollinearity.csv'
str_local_path = f'{str_dirname_output}/{str_filename}'
#df_tmp.to_csv(str_local_path, index=False)

# import
df_tmp = pd.read_csv(str_local_path)

# save
str_filename = 'list_cols_remove.pkl'
str_local_path = f'{str_dirname_output}/{str_filename}'
#pickle.dump(list_cols_remove, open(str_local_path, 'wb'))

# import
list_cols_remove = pickle.load(open(str_local_path, 'rb'))

# add binned suffix
list_cols_remove = [f'{col}_binned' for col in list_cols_remove]
print('Columns to Remove:')
for a, col in enumerate(list_cols_remove):
    print(f'{a+1} - {col}')
print()

# show
df_tmp
# Out:
# Columns to Remove:
# 1 - ENG-int_n_months_total_binned
# 2 - ENG-3mo_bad_binned
# 3 - au06s__tu_binned
# 4 - au09s__tu_binned
# 5 - ENG-int_n_months_binned
# 6 - au21s__tu_binned
# 7 - ENG-closed_auto_binned
# 8 - au01s__tu_binned
# 9 - int_bad_3mo_closed__tu_pmthx_binned
# 10 - ENG-6mo_bad_binned
# 11 - ENG-perfect_payment_hx_binned
# 12 - au36s__tu_binned
# 13 - au201s__tu_binned
# 14 - au202s__tu_binned
# 15 - au203s__tu_binned
# 16 - flt_mean_months_to_first_bad__tu_pmthx_binned
# 17 - ENG-wtd_avg_binned
# 18 - ENG-open_and_closed_auto_binned
# 19 - ENG-6mo_bad_end_binned
# 20 - ENG-perfect_payment_hx_closed_binned
# 21 - ENG-3mo_bad_end_binned
# 22 - int_bad_6mo_open_end__tu_pmthx_binned
# 23 - int_bad_6mo_closed_end__tu_pmthx_binned
# 24 - au03s__tu_binned
# 25 - au12s__tu_binned
# 26 - au28s__tu_binned
# 27 - au32s__tu_binned
# 28 - ENG-payment_to_income_binned
# 29 - au35s__tu_binned
# 30 - au57s__tu_binned
# 31 - fi28s__tu_binned
# 32 - fi33s__tu_binned
# 33 - aut202__tu_binned
# 34 - aut203__tu_binned
# 35 - aut204__tu_binned
# 36 - aut222__tu_binned
# 37 - aut223__tu_binned
# 38 - aut224__tu_binned
# 39 - ENG-perfect_payment_hx_open_binned
# 40 - linkt006__tu_binned
# 41 - g311s__tu_binned
# 42 - g093s__tu_binned
# 43 - linkt007__tu_binned
# 44 - g041s__tu_binned
# 45 - g042s__tu_binned
# 46 - g043s__tu_binned
# 47 - g061s__tu_binned
# 48 - g066s__tu_binned
# 49 - g224a__tu_binned
# 50 - g250a__tu_binned
# 51 - g250c__tu_binned
# 52 - g251a__tu_binned
# 53 - in01s__tu_binned
# 54 - cv10__tu_binned
# 55 - cv11__tu_binned
# 56 - cv12__tu_binned
# 57 - at01s__tu_binned
# 58 - inst_trd__tu_binned
# 59 - at02s__tu_binned
# 60 - at33b__tu_binned
# 61 - in02s__tu_binned
# 62 - in03s__tu_binned
# 63 - in12s__tu_binned
# 64 - in29s__tu_binned
# 65 - in33s__tu_binned
# 66 - at12s__tu_binned
# 67 - at03s__tu_binned
# 68 - at28b__tu_binned
# 69 - at29s__tu_binned
# 70 - at33a__tu_binned
# 71 - at57s__tu_binned
# 72 - at103s__tu_binned
# 73 - in24s__tu_binned
# 74 - at06s__tu_binned
# 75 - at09s__tu_binned
# 76 - at32s__tu_binned
# 77 - at20s__tu_binned
# 78 - at21s__tu_binned
# 79 - at25s__tu_binned
# 80 - at24s__tu_binned
# 81 - at28a__tu_binned
# 82 - g020s__tu_binned
# 83 - in25s__tu_binned
# 84 - st02s__tu_binned
# 85 - st03s__tu_binned
# 86 - st12s__tu_binned
# 87 - st24s__tu_binned
# 88 - st25s__tu_binned
# 89 - in27s__tu_binned
# 90 - st27s__tu_binned
# 91 - st28s__tu_binned
# 92 - st33s__tu_binned
# 93 - st34s__tu_binned
# 94 - at101s__tu_binned
# 95 - at101b__tu_binned
# 96 - g199s__tu_binned
# 97 - g207s__tu_binned
# 98 - in28s__tu_binned
# 99 - in32s__tu_binned
# 100 - in35s__tu_binned
# 101 - in57s__tu_binned
# 102 - in101s__tu_binned
# 103 - atap01__tu_binned
# 104 - g199b__tu_binned
# 105 - g207b__tu_binned
# 106 - cv19__tu_binned
# 107 - cv20__tu_binned
# 108 - inap01__tu_binned
# 109 - at30s__tu_binned
# 110 - at34a__tu_binned
# 111 - at34b__tu_binned
# 112 - at36s__tu_binned
# 113 - g235s__tu_binned
# 114 - s061s__tu_binned
# 115 - s062s__tu_binned
# 116 - at104s__tu_binned
# 117 - int_n_months_closed__tu_pmthx_binned
# 118 - int_60dpd_closed__tu_pmthx_binned
# 119 - int_90dpd_closed__tu_pmthx_binned
# 120 - au02s__tu_binned
# 121 - au101s__tu_binned
# 122 - fi02s__tu_binned
# 123 - fi03s__tu_binned
# 124 - fi12s__tu_binned
# 125 - au200s__tu_binned
# 126 - au206s__tu_binned
# 127 - fi101s__tu_binned
# 128 - aut254__tu_binned
# 129 - fi20s__tu_binned
# 130 - au24s__tu_binned
# 131 - au33s__tu_binned
# 132 - flt_avg_open__tu_pmthx_binned
# 133 - int_bad_3mo_open__tu_pmthx_binned
# 134 - au25s__tu_binned
# 135 - fi24s__tu_binned
# 136 - au30s__tu_binned
# 137 - fi31s__tu_binned
# 138 - au31s__tu_binned
# 139 - fi32s__tu_binned
# 140 - fi35s__tu_binned
# 141 - fi57s__tu_binned
# 142 - aut205__tu_binned
# 143 - aut225__tu_binned
# 144 - int_60dpd_open__tu_pmthx_binned
# 145 - fi34s__tu_binned
# 146 - in34s__tu_binned
# 147 - au34s__tu_binned
# 148 - flt_wtd_avg_open__tu_pmthx_binned
# 149 - int_90dpd_open__tu_pmthx_binned
# 150 - int_bad_6mo_open__tu_pmthx_binned
# 151 - bc01s__tu_binned
# 152 - bc101s__tu_binned
# 153 - bc106s__tu_binned
# 154 - g218c__tu_binned
# 155 - g219c__tu_binned
# 156 - g220c__tu_binned
# 157 - g221c__tu_binned
# 158 - g300s__tu_binned
# 159 - g301s__tu_binned
# 160 - rvlr66__tu_binned
# 161 - rvlr73__tu_binned
# 162 - rvlr75__tu_binned
# 163 - rvlr77__tu_binned
# 164 - cv22__tu_binned
# 165 - cv27__tu_binned
# 166 - cv28__tu_binned
# 167 - agg907__tu_binned
# 168 - agg908__tu_binned
# 169 - rvlr07__tu_binned
# 170 - rvlr31__tu_binned
# 171 - rvlr32__tu_binned
# 172 - rvlr33__tu_binned
# 173 - bc02s__tu_binned
# 174 - bc09s__tu_binned
# 175 - br30s__tu_binned
# 176 - br35s__tu_binned
# 177 - s043s__tu_binned
# 178 - revs902__tu_binned
# 179 - cv23__tu_binned
# 180 - aggs901__tu_binned
# 181 - aggs902__tu_binned
# 182 - aggs903__tu_binned
# 183 - aggs904__tu_binned
# 184 - aggs905__tu_binned
# 185 - bkc315__tu_binned
# 186 - bkc11__tu_binned
# 187 - bkc12__tu_binned
# 188 - bkc13__tu_binned
# 189 - bkc51__tu_binned
# 190 - bkc52__tu_binned
# 191 - bkc53__tu_binned
# 192 - bkc81__tu_binned
# 193 - bkc82__tu_binned
# 194 - bkc83__tu_binned
# 195 - bkc132__tu_binned
# 196 - aggs907__tu_binned
# 197 - aggs908__tu_binned
# 198 - aggs909__tu_binned
# 199 - aggs910__tu_binned
# 200 - trv19__tu_binned
# 201 - rvlr29__tu_binned
# 202 - bc12s__tu_binned
# 203 - bc24s__tu_binned
# 204 - bc03s__tu_binned
# 205 - bc29s__tu_binned
# 206 - bc32s__tu_binned
# 207 - bc33s__tu_binned
# 208 - bc35s__tu_binned
# 209 - br02s__tu_binned
# 210 - br12s__tu_binned
# 211 - br29s__tu_binned
# 212 - br32s__tu_binned
# 213 - br33s__tu_binned
# 214 - bc06s__tu_binned
# 215 - br09s__tu_binned
# 216 - bkc323__tu_binned
# 217 - rev81__tu_binned
# 218 - bc21s__tu_binned
# 219 - br01s__tu_binned
# 220 - bc20s__tu_binned
# 221 - br21s__tu_binned
# 222 - bc_trd__tu_binned
# 223 - bc25s__tu_binned
# 224 - bc28s__tu_binned
# 225 - re32s__tu_binned
# 226 - revs901__tu_binned
# 227 - bkc54__tu_binned
# 228 - bkc142__tu_binned
# 229 - aggs906__tu_binned
# 230 - bc30s__tu_binned
# 231 - bc31s__tu_binned
# 232 - br31s__tu_binned
# 233 - bkc152__tu_binned
# 234 - bkc14__tu_binned
# 235 - bc57s__tu_binned
# 236 - bc97a__tu_binned
# 237 - bc98a__tu_binned
# 238 - bc102s__tu_binned
# 239 - bc104s__tu_binned
# 240 - br03s__tu_binned
# 241 - br28s__tu_binned
# 242 - bc34s__tu_binned
# 243 - br57s__tu_binned
# 244 - g201a__tu_binned
# 245 - g202a__tu_binned
# 246 - bkc316__tu_binned
# 247 - bkc317__tu_binned
# 248 - bkc320__tu_binned
# 249 - bc36s__tu_binned
# 250 - re29s__tu_binned
# 251 - re33s__tu_binned
# 252 - bc103s__tu_binned
# 253 - bc107s__tu_binned
# 254 - bc108s__tu_binned
# 255 - g219d__tu_binned
# 256 - g220d__tu_binned
# 257 - g221d__tu_binned
# 258 - bc109s__tu_binned
# 259 - bc110s__tu_binned
# 260 - trv02__tu_binned
# 261 - bi06s__tu_binned
# 262 - bi01s__tu_binned
# 263 - bi09s__tu_binned
# 264 - bi21s__tu_binned
# 265 - bi36s__tu_binned
# 266 - br101s__tu_binned
# 267 - revs903__tu_binned
# 268 - revs904__tu_binned
# 269 - revs905__tu_binned
# 270 - rev203__tu_binned
# 271 - rev223__tu_binned
# 272 - rev12__tu_binned
# 273 - rev51__tu_binned
# 274 - rev52__tu_binned
# 275 - rev82__tu_binned
# 276 - trv18__tu_binned
# 277 - re35s__tu_binned
# 278 - rev233__tu_binned
# 279 - rev253__tu_binned
# 280 - agg905__tu_binned
# 281 - br06s__tu_binned
# 282 - br20s__tu_binned
# 283 - br24s__tu_binned
# 284 - rvlr09__tu_binned
# 285 - rev11__tu_binned
# 286 - rvlr76__tu_binned
# 287 - rev83__tu_binned
# 288 - rev13__tu_binned
# 289 - rev53__tu_binned
# 290 - re02s__tu_binned
# 291 - re03s__tu_binned
# 292 - re12s__tu_binned
# 293 - re28s__tu_binned
# 294 - br34s__tu_binned
# 295 - re57s__tu_binned
# 296 - bkc318__tu_binned
# 297 - bkc319__tu_binned
# 298 - bkc325__tu_binned
# 299 - bkc326__tu_binned
# 300 - bkc328__tu_binned
# 301 - bkc122__tu_binned
# 302 - bkc162__tu_binned
# 303 - aggs911__tu_binned
# 304 - agg906__tu_binned
# 305 - agg910__tu_binned
# 306 - agg911__tu_binned
# 307 - rev84__tu_binned
# 308 - re21s__tu_binned
# 309 - co02s__tu_binned
# 310 - co03s__tu_binned
# 311 - co04s__tu_binned
# 312 - co05s__tu_binned
# 313 - g209s__tu_binned
# 314 - g210s__tu_binned
# 315 - g211s__tu_binned
# 316 - g212s__tu_binned
# 317 - cv01__tu_binned
# 318 - fi01s__tu_binned
# 319 - fi09s__tu_binned
# 320 - fi30s__tu_binned
# 321 - g001s__tu_binned
# 322 - g001b__tu_binned
# 323 - g217s__tu_binned
# 324 - g003s__tu_binned
# 325 - g058s__tu_binned
# 326 - g063s__tu_binned
# 327 - g064s__tu_binned
# 328 - g068s__tu_binned
# 329 - g069s__tu_binned
# 330 - g071s__tu_binned
# 331 - g218b__tu_binned
# 332 - g224b__tu_binned
# 333 - g224c__tu_binned
# 334 - g250b__tu_binned
# 335 - g251b__tu_binned
# 336 - g251c__tu_binned
# 337 - g059s__tu_binned
# 338 - g051s__tu_binned
# 339 - g057s__tu_binned
# 340 - g418s__tu_binned
# 341 - g205s__tu_binned
# 342 - g205b__tu_binned
# 343 - cv21__tu_binned
# 344 - g200s__tu_binned
# 345 - g208s__tu_binned
# 346 - g208b__tu_binned
# 347 - jt02s__tu_binned
# 348 - g206s__tu_binned
# 349 - s064a__tu_binned
# 350 - g216s__tu_binned
# 351 - g218d__tu_binned
# 352 - g219b__tu_binned
# 353 - g221b__tu_binned
# 354 - g220b__tu_binned
# 355 - g222s__tu_binned
# 356 - g223s__tu_binned
# 357 - cv18__tu_binned
# 358 - g237s__tu_binned
# 359 - g238s__tu_binned
# 360 - g960s__tu_binned
# 361 - cv14__tu_binned
# 362 - g242s__tu_binned
# 363 - g990s__tu_binned
# 364 - re36s__tu_binned
# 365 - g303s__tu_binned
# 366 - g302s__tu_binned
# 367 - g304s__tu_binned
# 368 - g305s__tu_binned
# 369 - g307s__tu_binned
# 370 - g980s__tu_binned
# 371 - g411s__tu_binned
# 372 - in09s__tu_binned
# 373 - in20s__tu_binned
# 374 - st32s__tu_binned
# 375 - st35s__tu_binned
# 376 - st29s__tu_binned
# 377 - paymnt06__tu_binned
# 378 - of01s__tu_binned
# 379 - of36s__tu_binned
# 380 - of21s__tu_binned
# 381 - re01s__tu_binned
# 382 - walsrvs2__tu_binned
# 383 - rev315__tu_binned
# 384 - rev254__tu_binned
# 385 - rev224__tu_binned
# 386 - rev132__tu_binned
# 387 - rev234__tu_binned
# 388 - re09s__tu_binned
# 389 - rev14__tu_binned
# 390 - rev142__tu_binned
# 391 - rev202__tu_binned
# 392 - rev204__tu_binned
# 393 - rev222__tu_binned
# 394 - rev_trd__tu_binned
# 395 - rev92__tu_binned
# 396 - re25s__tu_binned
# 397 - re24s__tu_binned
# 398 - re102s__tu_binned
# 399 - rvdexq2__tu_binned
# 400 - rvdexq4__tu_binned
# 401 - rev320__tu_binned
# 402 - rev112__tu_binned
# 403 - rvdex02__tu_binned
# 404 - rev235__tu_binned
# 405 - reap01__tu_binned
# 406 - rev54__tu_binned
# 407 - re30s__tu_binned
# 408 - re31s__tu_binned
# 409 - rev152__tu_binned
# 410 - re34s__tu_binned
# 411 - rev319__tu_binned
# 412 - bkc327__tu_binned
# 413 - rev102__tu_binned
# 414 - re101s__tu_binned
# 415 - rt06s__tu_binned
# 416 - rt20s__tu_binned
# 417 - rt21s__tu_binned
# 418 - rt36s__tu_binned
# 419 - rt01s__tu_binned
# 420 - rvlr04__tu_binned
# 421 - rvlr11__tu_binned
# 422 - rvlr12__tu_binned
# 423 - rvlr13__tu_binned
# 424 - rt02s__tu_binned
# 425 - ret320__tu_binned
# 426 - ret82__tu_binned
# 427 - rt09s__tu_binned
# 428 - rt201s__tu_binned
# 429 - rt101s__tu_binned
# 430 - ret83__tu_binned
# 431 - s209s__tu_binned
# 432 - cv04__tu_binned
# 433 - s071b__tu_binned
# 434 - st01s__tu_binned
# 435 - st102s__tu_binned
# 436 - st09s__tu_binned
# 437 - st21s__tu_binned
# 438 - st36s__tu_binned
# 439 - st45s__tu_binned
# 440 - st101s__tu_binned
# 441 - st103s__tu_binned
# 442 - st50s__tu_binned
# 443 - s209a__tu_binned
# 444 - g242f__tu_binned
# 445 - g243f__tu_binned
# 446 - g243b__tu_binned
# 447 - g242b__tu_binned
# 448 - g417s__tu_binned
# 449 - g409s__tu_binned
# 450 - us06s__tu_binned
# 451 - us09s__tu_binned
# 452 - us01s__tu_binned
# 453 - us21s__tu_binned
# 454 - us36s__tu_binned
# 455 - us20s__tu_binned
# 456 - per254__tu_binned
# 457 - se06s__tu_binned
# 458 - se01s__tu_binned
# 459 - se20s__tu_binned
# 460 - se09s__tu_binned
# 461 - se21s__tu_binned
# 462 - jt01s__tu_binned
# 463 - jt33s__tu_binned
# 464 - jt44s__tu_binned
# 465 - jt51s__tu_binned
# 466 - jt21s__tu_binned
# 467 - jt41s__tu_binned
# 468 - jt75s__tu_binned
# 469 - jt42s__tu_binned
# 470 - au204s__tu_binned
# 471 - au205s__tu_binned
# 472 - au207s__tu_binned
# 473 - g412s__tu_binned
# 474 - g413s__tu_binned
# 475 - g414s__tu_binned
# 476 - g415s__tu_binned
# 477 - rvlr61__tu_binned
# 478 - rvlr62__tu_binned
# 479 - rvlr63__tu_binned
# 480 - rvlr70__tu_binned
# 481 - rvlr72__tu_binned
# 482 - rvlr74__tu_binned
# 483 - rvlr65__tu_binned
# 484 - rvlr01__tu_binned
# 485 - rvlr03__tu_binned
# 486 - rvlr05__tu_binned
# 487 - rvlr08__tu_binned
# 488 - rvlr30__tu_binned
# 489 - walshrs2__tu_binned
# 490 - indexq2__tu_binned
# 491 - indexq4__tu_binned
# 492 - rev232__tu_binned
# 493 - rev252__tu_binned
# 494 - rev205__tu_binned
# 495 - rev225__tu_binned
# 496 - trv04__tu_binned
# 497 - trv12__tu_binned
# 498 - rvdex01__tu_binned
# 499 - rvdexq3__tu_binned
# 500 - index01__tu_binned
# 501 - indexq1__tu_binned
# 502 - rvdexq1__tu_binned
# 503 - indexq3__tu_binned
# 504 - walshrs1__tu_binned
# 505 - rev316__tu_binned
# 506 - rev318__tu_binned
# 507 - rev317__tu_binned
# 508 - rev327__tu_binned
# 509 - rev328__tu_binned
# 510 - rev162__tu_binned
# 511 - rev255__tu_binned
# 512 - bkc112__tu_binned
# 513 - rev321__tu_binned
# 514 - bkc321__tu_binned
# 515 - rev122__tu_binned
# 516 - rev323__tu_binned
# 517 - rev325__tu_binned
# 518 - rev322__tu_binned
# 519 - bkc322__tu_binned
# 520 - rev324__tu_binned
# 521 - bkc102__tu_binned
# 522 - bkc92__tu_binned
# 523 - bkc324__tu_binned
# 524 - ret315__tu_binned
# 525 - ret81__tu_binned
# 526 - ret324__tu_binned
# 527 - ret319__tu_binned
# 528 - all232__tu_binned
# 529 - all252__tu_binned
# 530 - all233__tu_binned
# 531 - all234__tu_binned
# 532 - all253__tu_binned
# 533 - all254__tu_binned
# 534 - all255__tu_binned
# 535 - rev231__tu_binned
# 536 - ret235__tu_binned
# 537 - aut232__tu_binned
# 538 - aut234__tu_binned
# 539 - aut233__tu_binned
# 540 - aut253__tu_binned
# 541 - aut255__tu_binned
# 542 - per234__tu_binned
# 543 - per255__tu_binned
# 544 - ret84__tu_binned
# 545 - trd__tu_binned
# 546 - agg902__tu_binned
# 547 - trv14__tu_binned
# 548 - trv05__tu_binned
# 549 - trv07__tu_binned
# 550 - paymnt07__tu_binned
# 551 - trv08__tu_binned
# 552 - paymnt10__tu_binned
# 553 - paymnt11__tu_binned
# 554 - paymnt02__tu_binned
# 555 - trv11__tu_binned
# 556 - rvlr10__tu_binned
# 557 - paymnt04__tu_binned
# 558 - paymnt05__tu_binned
# 559 - linkf031__tu_binned
# 560 - linkf064__tu_binned
# 561 - linkf075__tu_binned
# 562 - linkf106__tu_binned
# 563 - linkf196__tu_binned
# 564 - linkf197__tu_binned
# 565 - linkf035__tu_binned
# 566 - linkf044__tu_binned
# 567 - linkf079__tu_binned
# 568 - linkf133__tu_binned
# 569 - linkf134__tu_binned
# 570 - linkf071__tu_binned
# 571 - linkf040__tu_binned
# 572 - linkf199__tu_binned
# 573 - linkf068__tu_binned
# 574 - linkf086__tu_binned
# 575 - linkf087__tu_binned
# 576 - linkf053__tu_binned
# 577 - linkf107__tu_binned
# 578 - linkf111__tu_binned
# 579 - linkf112__tu_binned
# 580 - linkf132__tu_binned
# 581 - linkf143__tu_binned
# 582 - linkf144__tu_binned
# 583 - linkf145__tu_binned
# 584 - linkf146__tu_binned
# 585 - linkf147__tu_binned
# 586 - linkf152__tu_binned
# 587 - linkf153__tu_binned
# 588 - linkf154__tu_binned
# 589 - linkf161__tu_binned
# 590 - linkf162__tu_binned
# 591 - linkf163__tu_binned
# 592 - linkf164__tu_binned
# 593 - linkf165__tu_binned
# 594 - linkf167__tu_binned
# 595 - linkf170__tu_binned
# 596 - linkf171__tu_binned
# 597 - linkf172__tu_binned
# 598 - linkf179__tu_binned
# 599 - linkf180__tu_binned
# 600 - linkf181__tu_binned
# 601 - linkf185__tu_binned
# 602 - linkf089__tu_binned
# 603 - linkf088__tu_binned
# 604 - linkf105__tu_binned
# 605 - linkf114__tu_binned
# 606 - linkf137__tu_binned
# 607 - linkf138__tu_binned
# 608 - linkf140__tu_binned
# 609 - linkf149__tu_binned
# 610 - linkf155__tu_binned
# 611 - linkf156__tu_binned
# 612 - linkf174__tu_binned
# 613 - linkf113__tu_binned
# 614 - linkf090__tu_binned
# 615 - linkf173__tu_binned
# 616 - linkf193__tu_binned
# 617 - linkf091__tu_binned
# 618 - linkf116__tu_binned
# 619 - linkf115__tu_binned
# 620 - linkf176__tu_binned
# 621 - linka024__tu_binned
# 622 - linka050__tu_binned
# 623 - linka051__tu_binned
# 624 - linka052__tu_binned
# 625 - linka029__tu_binned
# 626 - linka053__tu_binned
# 627 - linka022__tu_binned
# 628 - linka021__tu_binned
# 629 - linka020__tu_binned
# 630 - linka025__tu_binned
# 631 - linka046__tu_binned
# 632 - linka047__tu_binned
# 633 - linka012__tu_binned
# 634 - linka017__tu_binned
# 635 - linka018__tu_binned
# 636 - linka019__tu_binned
# 637 - linka013__tu_binned
# 638 - int_bad_3mo_open_end__tu_pmthx_binned
# 639 - flt_avg_closed__tu_pmthx_binned
# 640 - int_30dpd_closed__tu_pmthx_binned
# 641 - int_bad_6mo_closed__tu_pmthx_binned
# 642 - int_bad_3mo_closed_end__tu_pmthx_binned
#                                   col1                              col2  \
# 0                     ENG-int_n_months            ENG-int_n_months_total
# 1                     ENG-int_n_months                       ENG-3mo_bad
# 2                     ENG-int_n_months                         au06s__tu
# 3                     ENG-int_n_months                         au09s__tu
# 4                     ENG-int_n_months                         au20s__tu
# ...                                ...                               ...
# 9705        int_60dpd_closed__tu_pmthx      int_bad_6mo_closed__tu_pmthx
# 9706        int_90dpd_closed__tu_pmthx      int_bad_3mo_closed__tu_pmthx
# 9707        int_90dpd_closed__tu_pmthx      int_bad_6mo_closed__tu_pmthx
# 9708      int_bad_3mo_closed__tu_pmthx      int_bad_6mo_closed__tu_pmthx
# 9709  int_bad_3mo_closed_end__tu_pmthx  int_bad_6mo_closed_end__tu_pmthx
#
#              r     r_abs  col1_importance  col2_importance  high_correlation  \
# 0     0.928763  0.928763         0.536567         0.535469                 1
# 1    -0.812483  0.812483         0.536567         0.507772                 1
# 2    -0.771509  0.771509         0.536567         0.508226                 1
# 3    -0.797946  0.797946         0.536567         0.523945                 1
# 4     0.712262  0.712262         0.536567         0.543295                 1
# ...        ...       ...              ...              ...               ...
# 9705  0.736107  0.736107         0.511962         0.518697                 1
# 9706  0.875578  0.875578         0.508039         0.508473                 1
# 9707  0.744399  0.744399         0.508039         0.518697                 1
# 9708  0.826401  0.826401         0.508473         0.518697                 1
# 9709  0.951723  0.951723         0.518402         0.515941                 1
#
#                         remove_feature
# 0               ENG-int_n_months_total
# 1                          ENG-3mo_bad
# 2                            au06s__tu
# 3                            au09s__tu
# 4                     ENG-int_n_months
# ...                                ...
# 9705        int_60dpd_closed__tu_pmthx
# 9706        int_90dpd_closed__tu_pmthx
# 9707        int_90dpd_closed__tu_pmthx
# 9708      int_bad_3mo_closed__tu_pmthx
# 9709  int_bad_6mo_closed_end__tu_pmthx
#
# [9710 rows x 8 columns]

# %%
'ENG-loan_to_value' in list_cols_remove
# Out:
# False

# %%
'g106s__tu' in list_cols_remove
# Out:
# False

# %% [markdown]
# #### Get info from inform set

# %%
# # get target value
# flt_target_value = df_holdout[str_target].mean()
# print(f'Target Value: {flt_target_value:0.4f}')

# %% [markdown]
# #### Get train to match the inform set

# %%
# %%time

# # get current target mean
# flt_current_value = df_train[str_target].mean()
# print(f'Target Value Before Sampling: {flt_current_value:0.4f}')
# # init
# cls_sample = OverSampling(
#     df=df_train,
#     str_target=str_target,
#     flt_target_value=flt_target_value,
#     flt_current_value=flt_current_value,
# )
# # sample
# df_train = cls_sample.sample()
# # get current target mean
# flt_current_value = df_train[str_target].mean()
# print(f'Target Value After Sampling: {flt_current_value:0.4f}')
# print()
# # show
# df_train

# %% [markdown]
# #### Get test to match the inform set

# %%
# %%time

# # get current target mean
# flt_current_value = df_test[str_target].mean()
# print(f'Target Value Before Sampling: {flt_current_value:0.4f}')
# # init
# cls_sample = OverSampling(
#     df=df_test,
#     str_target=str_target,
#     flt_target_value=flt_target_value,
#     flt_current_value=flt_current_value,
# )
# # sample
# df_test = cls_sample.sample()
# # get current target mean
# flt_current_value = df_test[str_target].mean()
# print(f'Target Value After Sampling: {flt_current_value:0.4f}')
# print()
# # show
# df_test

# %% [markdown]
# #### List of columns to start

# %%
print(f'Starting with {len(list_cols_scorecard)} features:')
# Out:
# Starting with 744 features:

# %% [markdown]
# #### Get the scorecard cols and the original col

# %%
list_cols_original = []
for col in tqdm(list_cols_scorecard):
    str_col_original = col.split('_binned')[0]
    # append
    list_cols_original.append(str_col_original)
# combine
list_cols_x = list_cols_original + list_cols_scorecard
# Out:
# 100%|██████████| 744/744 [00:00<00:00, 1063223.91it/s]

# %% [markdown]
# #### Split into X and y

# %%
# train
X_train = df_train[list_cols_x].copy()
y_train = df_train[str_target]
# save memory
del df_train

# %%
X_train.shape
# Out:
# (25018, 1488)

# %%
# test
X_test = df_test[list_cols_x].copy()
y_test = df_test[str_target]
# save memory
del df_test

# %%
X_test.shape
# Out:
# (8340, 1488)

# %%
# holdout
X_holdout = df_holdout[list_cols_x].copy()
y_holdout = df_holdout[str_target]
# save memory
del df_holdout

# %%
X_holdout.shape
# Out:
# (8340, 1488)

# %% [markdown]
# #### Baseline model

# %%
# rm collinear
list_cols_scorecard = [col for col in list_cols_scorecard if col not in list_cols_remove]
print(f'There are {len(list_cols_scorecard)} features available for scorecard inclusion')

# init
cls_model_inference = LogisticRegression(
    random_state=42,
    fit_intercept=True,
)
# fit
cls_model_inference.fit(
    X_train[list_cols_scorecard],
    y_train,
)
# adjust weights
cls_model_inference = weight_the_coefficients(
    cls_model_inference=cls_model_inference,
    dict_weights=dict_weights,
)

# get predictions
list_predictions_train = list(cls_model_inference.predict_proba(X_train[list_cols_scorecard])[:,1])
list_predictions_test = list(cls_model_inference.predict_proba(X_test[list_cols_scorecard])[:,1])
list_predictions_holdout = list(cls_model_inference.predict_proba(X_holdout[list_cols_scorecard])[:,1])

# plot distributions
fig, ax = plt.subplots(figsize=(9,5))
ax.set_title('Distributions of Train, Test, and Holdout Predictions')
sns.kdeplot(list_predictions_train, label=f'Train: {np.mean(list_predictions_train):0.4f}')
sns.kdeplot(list_predictions_test, label=f'Test: {np.mean(list_predictions_test):0.4f}')
sns.kdeplot(list_predictions_holdout, label=f'Holdout: {np.mean(list_predictions_holdout):0.4f}')
# legend
ax.legend()
# show
plt.show()
# Out:
# There are 102 features available for scorecard inclusion

# %%
# eval
flt_auc_train, flt_auc_test = evaluate(
    y_train=y_train,
    list_predictions_train=list_predictions_train,
    y_test=y_test,
    list_predictions_test=list_predictions_test,
    y_holdout=y_holdout,
    list_predictions_holdout=list_predictions_holdout,
)
# Out:
# AUC Train: 0.6601
# AUC Test: 0.6440
# AUC Holdout: 0.6406
#
# Logloss Train: 0.5536
# Logloss Test: 0.5630
# Logloss Holdout: 0.5243
#
# KS Train: 0.2279
# KS Test: 0.2121
# KS Holdout: 0.2166

# %% [markdown]
# #### Forward stepwise

# %%
# map description
dict_map_descriptions_bin = {f'{key}_binned': val for key, val in dict_map_descriptions.items()}

# make copy
list_cols_start = list_cols_scorecard.copy()

flt_target_train = 0.5
flt_target_test = 0.5
list_cols_in_model = [
    'ENG-loan_to_value_binned',
    'fltgrossmonthly__income_sum_binned',
    'miles_odometer__app_binned',
    'flt_wtd_avg_open__tu_pmthx_binned',
    'flt_wtd_avg_closed__tu_pmthx_binned',
]
list_dict_row_a = []
counter = 0
while True:
    list_dict_row_b = []
    # make sure the features have been removed
    list_cols_start = [col for col in list_cols_start if col not in list_cols_in_model]
    # iterate through cols
    for col_a in tqdm(list_cols_start):
        # add to 
        list_cols_scorecard_tmp = list_cols_in_model + [col_a]
        
        # fit model
        cls_model_inference = LogisticRegression(
            random_state=42,
            fit_intercept=True,
        )
        cls_model_inference.fit(
            X_train[list_cols_scorecard_tmp].copy(),
            y_train,
        )
        # adjust weights
        cls_model_inference = weight_the_coefficients(
            cls_model_inference=cls_model_inference,
            dict_weights=dict_weights,
        )
        # get score - train
        list_predictions_tmp = list(cls_model_inference.predict_proba(X_train[list_cols_scorecard_tmp])[:,1])     
        # get score
        flt_score_train = skm.roc_auc_score(
            y_true=y_train,
            y_score=list_predictions_tmp,
        )
        # get score - test
        list_predictions_tmp = list(cls_model_inference.predict_proba(X_test[list_cols_scorecard_tmp])[:,1])       
        # get score
        flt_score_test = skm.roc_auc_score(
            y_true=y_test,
            y_score=list_predictions_tmp,
        )
        # make row
        dict_row_b = {
            'feature': col_a,
            'score_train': flt_score_train,
            'score_test': flt_score_test,
        }
        # append
        list_dict_row_b.append(dict_row_b)
    
    # make df
    df_tmp = pd.DataFrame(list_dict_row_b)
    
    # get diffs
    df_tmp['diff_train'] = df_tmp['score_train'] - flt_target_train
    df_tmp['diff_test'] = df_tmp['score_test'] - flt_target_test
    
    # subset to where both are positive
    df_tmp = df_tmp[(df_tmp['diff_train'] > 0) & (df_tmp['diff_test'] >= 0)].copy()
    
    # get number of rows
    int_nrows = df_tmp.shape[0]
    
    # logic to break loop
    if int_nrows == 0:
        break
    else:
        pass
    
    # get the wtd avg
    df_tmp['diff_overall'] = df_tmp.apply(
        lambda x: np.average(
            [x['diff_train'], x['diff_test']],
            weights=[1,1],
        ),
        axis=1,
    )
    
    # sort
    df_tmp.sort_values(by='diff_overall', ascending=False, inplace=True)
    
    # get best scores
    flt_score_train = df_tmp['score_train'].iloc[0]
    flt_score_test = df_tmp['score_test'].iloc[0]
    
    # get targets
    flt_target_train = flt_score_train
    flt_target_test = flt_score_test
    
    # get the feature that improves performance most upon addition
    str_feat_add = df_tmp['feature'].iloc[0]
    # append
    list_cols_in_model.append(str_feat_add)
    
    # get the description
    try:
        str_description = dict_map_descriptions_bin[str_feat_add]
    except KeyError:
        str_description = ''
    
    # make row
    dict_row_a = {
        'list_cols_in_model': list_cols_in_model.copy(),
        'n_feats': len(list_cols_in_model.copy()),
        'feature': str_feat_add,
        'target_train': flt_target_train,
        'target_test': flt_target_test,
        'score_train': flt_score_train,
        'score_test': flt_score_test,
        'description': str_description,
    }
    # append
    list_dict_row_a.append(dict_row_a)

    # make df
    df_stepwise = pd.DataFrame(list_dict_row_a)
    # save
    str_filename = 'df_stepwise.csv'
    str_local_path = f'{str_dirname_output}/{str_filename}'
    df_stepwise.to_csv(str_local_path, index=False)
    
    # add to counter
    counter += 1
    
    if counter == int_rounds_max:
        break
    else:
        pass

# get features
list_cols_scorecard_stepwise = df_stepwise['list_cols_in_model'].iloc[-1]
print(f'There are {len(list_cols_scorecard_stepwise)} features that do not drift inappropriately')

# show
df_stepwise
# Out:
# 100%|██████████| 98/98 [00:07<00:00, 12.95it/s]
# 100%|██████████| 97/97 [00:07<00:00, 12.77it/s]
# 100%|██████████| 96/96 [00:07<00:00, 13.58it/s]
# 100%|██████████| 95/95 [00:08<00:00, 11.77it/s]
# 100%|██████████| 94/94 [00:10<00:00,  9.27it/s]
# 100%|██████████| 93/93 [00:07<00:00, 11.83it/s]
# 100%|██████████| 92/92 [00:06<00:00, 14.97it/s]
# 100%|██████████| 91/91 [00:08<00:00, 10.25it/s]
# 100%|██████████| 90/90 [00:07<00:00, 12.54it/s]
# 100%|██████████| 89/89 [00:06<00:00, 13.82it/s]
# 100%|██████████| 88/88 [00:06<00:00, 13.66it/s]
# 100%|██████████| 87/87 [00:06<00:00, 12.90it/s]
# 100%|██████████| 86/86 [00:06<00:00, 12.62it/s]
# 100%|██████████| 85/85 [00:07<00:00, 11.94it/s]
# 100%|██████████| 84/84 [00:06<00:00, 13.38it/s]
# 100%|██████████| 83/83 [00:08<00:00, 10.25it/s]
# 100%|██████████| 82/82 [00:07<00:00, 10.94it/s]
# 100%|██████████| 81/81 [00:08<00:00,  9.73it/s]
# 100%|██████████| 80/80 [00:06<00:00, 11.91it/s]
# 100%|██████████| 79/79 [00:09<00:00,  8.76it/s]
# 100%|██████████| 78/78 [00:07<00:00, 10.04it/s]
# 100%|██████████| 77/77 [00:07<00:00, 10.21it/s]
# 100%|██████████| 76/76 [00:07<00:00, 10.23it/s]
# 100%|██████████| 75/75 [00:08<00:00,  8.51it/s]
# 100%|██████████| 74/74 [00:07<00:00,  9.81it/s]
# 100%|██████████| 73/73 [00:09<00:00,  7.77it/s]
# 100%|██████████| 72/72 [00:07<00:00,  9.89it/s]
# 100%|██████████| 71/71 [00:07<00:00,  9.15it/s]
# 100%|██████████| 70/70 [00:07<00:00,  8.97it/s]
# 100%|██████████| 69/69 [00:08<00:00,  8.53it/s]
# 100%|██████████| 68/68 [00:06<00:00,  9.72it/s]
# 100%|██████████| 67/67 [00:06<00:00,  9.83it/s]
# 100%|██████████| 66/66 [00:06<00:00, 10.11it/s]
# 100%|██████████| 65/65 [00:06<00:00,  9.39it/s]
# 100%|██████████| 64/64 [00:06<00:00, 10.54it/s]
# 100%|██████████| 63/63 [00:05<00:00, 11.17it/s]
# 100%|██████████| 62/62 [00:05<00:00, 10.53it/s]
# 100%|██████████| 61/61 [00:06<00:00,  8.75it/s]
# 100%|██████████| 60/60 [00:07<00:00,  7.91it/s]
# 100%|██████████| 59/59 [00:07<00:00,  7.92it/s]
# 100%|██████████| 58/58 [00:07<00:00,  7.81it/s]
# 100%|██████████| 57/57 [00:07<00:00,  7.55it/s]
# 100%|██████████| 56/56 [00:07<00:00,  7.23it/s]
# 100%|██████████| 55/55 [00:07<00:00,  7.69it/s]
# 100%|██████████| 54/54 [00:06<00:00,  7.98it/s]
# 100%|██████████| 53/53 [00:06<00:00,  7.83it/s]
# 100%|██████████| 52/52 [00:06<00:00,  8.22it/s]
# 100%|██████████| 51/51 [00:06<00:00,  8.35it/s]
# There are 52 features that do not drift inappropriately
#                                    list_cols_in_model  n_feats  \
# 0   [ENG-loan_to_value_binned, fltgrossmonthly__in...        6
# 1   [ENG-loan_to_value_binned, fltgrossmonthly__in...        7
# 2   [ENG-loan_to_value_binned, fltgrossmonthly__in...        8
# 3   [ENG-loan_to_value_binned, fltgrossmonthly__in...        9
# 4   [ENG-loan_to_value_binned, fltgrossmonthly__in...       10
# 5   [ENG-loan_to_value_binned, fltgrossmonthly__in...       11
# 6   [ENG-loan_to_value_binned, fltgrossmonthly__in...       12
# 7   [ENG-loan_to_value_binned, fltgrossmonthly__in...       13
# 8   [ENG-loan_to_value_binned, fltgrossmonthly__in...       14
# 9   [ENG-loan_to_value_binned, fltgrossmonthly__in...       15
# 10  [ENG-loan_to_value_binned, fltgrossmonthly__in...       16
# 11  [ENG-loan_to_value_binned, fltgrossmonthly__in...       17
# 12  [ENG-loan_to_value_binned, fltgrossmonthly__in...       18
# 13  [ENG-loan_to_value_binned, fltgrossmonthly__in...       19
# 14  [ENG-loan_to_value_binned, fltgrossmonthly__in...       20
# 15  [ENG-loan_to_value_binned, fltgrossmonthly__in...       21
# 16  [ENG-loan_to_value_binned, fltgrossmonthly__in...       22
# 17  [ENG-loan_to_value_binned, fltgrossmonthly__in...       23
# 18  [ENG-loan_to_value_binned, fltgrossmonthly__in...       24
# 19  [ENG-loan_to_value_binned, fltgrossmonthly__in...       25
# 20  [ENG-loan_to_value_binned, fltgrossmonthly__in...       26
# 21  [ENG-loan_to_value_binned, fltgrossmonthly__in...       27
# 22  [ENG-loan_to_value_binned, fltgrossmonthly__in...       28
# 23  [ENG-loan_to_value_binned, fltgrossmonthly__in...       29
# 24  [ENG-loan_to_value_binned, fltgrossmonthly__in...       30
# 25  [ENG-loan_to_value_binned, fltgrossmonthly__in...       31
# 26  [ENG-loan_to_value_binned, fltgrossmonthly__in...       32
# 27  [ENG-loan_to_value_binned, fltgrossmonthly__in...       33
# 28  [ENG-loan_to_value_binned, fltgrossmonthly__in...       34
# 29  [ENG-loan_to_value_binned, fltgrossmonthly__in...       35
# 30  [ENG-loan_to_value_binned, fltgrossmonthly__in...       36
# 31  [ENG-loan_to_value_binned, fltgrossmonthly__in...       37
# 32  [ENG-loan_to_value_binned, fltgrossmonthly__in...       38
# 33  [ENG-loan_to_value_binned, fltgrossmonthly__in...       39
# 34  [ENG-loan_to_value_binned, fltgrossmonthly__in...       40
# 35  [ENG-loan_to_value_binned, fltgrossmonthly__in...       41
# 36  [ENG-loan_to_value_binned, fltgrossmonthly__in...       42
# 37  [ENG-loan_to_value_binned, fltgrossmonthly__in...       43
# 38  [ENG-loan_to_value_binned, fltgrossmonthly__in...       44
# 39  [ENG-loan_to_value_binned, fltgrossmonthly__in...       45
# 40  [ENG-loan_to_value_binned, fltgrossmonthly__in...       46
# 41  [ENG-loan_to_value_binned, fltgrossmonthly__in...       47
# 42  [ENG-loan_to_value_binned, fltgrossmonthly__in...       48
# 43  [ENG-loan_to_value_binned, fltgrossmonthly__in...       49
# 44  [ENG-loan_to_value_binned, fltgrossmonthly__in...       50
# 45  [ENG-loan_to_value_binned, fltgrossmonthly__in...       51
# 46  [ENG-loan_to_value_binned, fltgrossmonthly__in...       52
#
#                                feature  target_train  target_test  \
# 0                      cv15__tu_binned      0.599066     0.592706
# 1                  linkt001__tu_binned      0.607092     0.600951
# 2                    br109s__tu_binned      0.614691     0.609756
# 3                     in21s__tu_binned      0.619715     0.615414
# 4                  balmag01__tu_binned      0.625531     0.621207
# 5                    rev326__tu_binned      0.628975     0.625770
# 6                     g310s__tu_binned      0.634681     0.629339
# 7                     g232s__tu_binned      0.637311     0.634309
# 8                     rp01s__tu_binned      0.639610     0.635719
# 9                     jt20s__tu_binned      0.641540     0.638040
# 10  int_n_months_open__tu_pmthx_binned      0.642540     0.639478
# 11                 linka006__tu_binned      0.643301     0.640898
# 12                 linkf098__tu_binned      0.643972     0.642332
# 13                    trv10__tu_binned      0.644679     0.643420
# 14                    g002s__tu_binned      0.644988     0.644707
# 15                  rtl_trd__tu_binned      0.645774     0.645520
# 16                    g306s__tu_binned      0.646001     0.646523
# 17                    g407s__tu_binned      0.646945     0.646680
# 18                    au20s__tu_binned      0.647937     0.646883
# 19                 linkt003__tu_binned      0.648233     0.647673
# 20                    co01s__tu_binned      0.648700     0.648411
# 21                 linkt002__tu_binned      0.649474     0.648572
# 22                    in30s__tu_binned      0.649723     0.649179
# 23                   rvlr64__tu_binned      0.649865     0.649765
# 24     int_30dpd_open__tu_pmthx_binned      0.649978     0.650303
# 25                    fi36s__tu_binned      0.650431     0.650582
# 26                   per235__tu_binned      0.650486     0.650811
# 27                   agg904__tu_binned      0.650672     0.650934
# 28                    fi25s__tu_binned      0.650811     0.651038
# 29                    fi21s__tu_binned      0.651084     0.651102
# 30                    st20s__tu_binned      0.651140     0.651337
# 31                     cv13__tu_binned      0.651282     0.651476
# 32                 linka003__tu_binned      0.651326     0.651673
# 33                    trv13__tu_binned      0.651463     0.651717
# 34                   aut252__tu_binned      0.651478     0.651908
# 35                    g244f__tu_binned      0.651485     0.652061
# 36                    in36s__tu_binned      0.651495     0.652240
# 37                    g219a__tu_binned      0.651687     0.652343
# 38                    trv09__tu_binned      0.651793     0.652614
# 39                    of02s__tu_binned      0.651830     0.652927
# 40                    s068b__tu_binned      0.651862     0.653227
# 41                    re06s__tu_binned      0.651865     0.653308
# 42                    trv03__tu_binned      0.651970     0.653400
# 43                 linka027__tu_binned      0.651971     0.653414
# 44                   us101s__tu_binned      0.651989     0.653439
# 45                     cv17__tu_binned      0.652000     0.653450
# 46                    g102s__tu_binned      0.652002     0.653451
#
#     score_train  score_test                                        description
# 0      0.599066    0.592706                   Number of deduped auto inquiries
# 1      0.607092    0.600951   Number of non-military addresses in last 7 years
# 2      0.614691    0.609756  Number of bank revolving trades with past due ...
# 3      0.619715    0.615414  Months since most recent installment trade opened
# 4      0.625531    0.621207  Non-mortgage balance magnitude algorithm over ...
# 5      0.628975    0.625770  Average Total Open-to-Buy for Revolving accoun...
# 6      0.634681    0.629339       Worst rating on all trades in past 12 months
# 7      0.637311    0.634309          Number of inquiries (includes duplicates)
# 8      0.639610    0.635719                      Number of repossession trades
# 9      0.641540    0.638040             Months since oldest joint trade opened
# 10     0.642540    0.639478
# 11     0.643301    0.640898  Number of total inquiries in the last 3 years....
# 12     0.643972    0.642332                      Number of satisfactory trades
# 13     0.644679    0.643420  Number of months non-mortgage balance decrease...
# 14     0.644988    0.644707  Number of 60 days past due ratings in past 12 ...
# 15     0.645774    0.645520                            Number of retail trades
# 16     0.646001    0.646523      Worst rating on auto trades in past 12 months
# 17     0.646945    0.646680                Number of deduped finance inquiries
# 18     0.647937    0.646883              Months since oldest auto trade opened
# 19     0.648233    0.647673  Number of non-military non-corroborated addres...
# 20     0.648700    0.648411                       Number of charged-off trades
# 21     0.649474    0.648572                Number of months at current address
# 22     0.649723    0.649179  Percentage of open installment trades > 50% of...
# 23     0.649865    0.649765  Flag indicating that the consumer revolved at ...
# 24     0.649978    0.650303
# 25     0.650431    0.650582  Months since most recent finance installment d...
# 26     0.650486    0.650811  Aggregate Excess Payment for Personal Loan acc...
# 27     0.650672    0.650934  Number of aggregate non-mortgage credit line d...
# 28     0.650811    0.651038  Number of currently open and satisfactory fina...
# 29     0.651084    0.651102  Months since most recent finance installment t...
# 30     0.651140    0.651337      Months since oldest student loan trade opened
# 31     0.651282    0.651476               Percentage of trades ever delinquent
# 32     0.651326    0.651673  Number of other inquiries in the last 2 years....
# 33     0.651463    0.651717      Number of revolving high credit increases YOY
# 34     0.651478    0.651908  Average Aggregate Excess Payment for Auto acco...
# 35     0.651485    0.652061  Number of finance inquiries (includes duplicat...
# 36     0.651495    0.652240   Months since most recent installment delinquency
# 37     0.651687    0.652343  Number of trades verified in the past 12 month...
# 38     0.651793    0.652614       Number of non-mortgage balance decreases YOY
# 39     0.651830    0.652927                 Number of open credit union trades
# 40     0.651862    0.653227      Number of non-medical third party collections
# 41     0.651865    0.653308  Number of revolving trades opened in past 6 mo...
# 42     0.651970    0.653400  Number of non-mortgage trades with a balance i...
# 43     0.651971    0.653414    Number of days since most recent payday inquiry
# 44     0.651989    0.653439  Total balance of all unsecured installment tra...
# 45     0.652000    0.653450  Number of trades prior 30 days past due, now c...
# 46     0.652002    0.653451                   Months since most recent inquiry

# %%
# plot
x = df_stepwise['feature']
y = df_stepwise['score_test']
z = df_stepwise['score_train']
fig, ax = plt.subplots(figsize=(15,5))
ax.set_title('Score and Contribution by Feature Added')
ax.set_xlabel('Feature Added')
ax.set_ylabel('Score')
ax.plot(x, y, label='Test')
ax.plot(x, z, label='Train')
ax.set_xticklabels(x, rotation=90)
ax.legend()

# save
str_filename = 'plt_forward_stepwise.png'
str_local_path = f'{str_dirname_output}/{str_filename}'
plt.savefig(str_local_path, bbox_inches='tight')

# show
plt.show()

# %%
# init
cls_model_inference = LogisticRegression(
    random_state=42,
    fit_intercept=True,
)
# fit
cls_model_inference.fit(
    X_train[list_cols_scorecard_stepwise].copy(),
    y_train,
)
# adjust weights
cls_model_inference = weight_the_coefficients(
    cls_model_inference=cls_model_inference,
    dict_weights=dict_weights,
)

# get predictions
list_predictions_train = list(cls_model_inference.predict_proba(X_train[list_cols_scorecard_stepwise])[:,1])
list_predictions_test = list(cls_model_inference.predict_proba(X_test[list_cols_scorecard_stepwise])[:,1])
list_predictions_holdout = list(cls_model_inference.predict_proba(X_holdout[list_cols_scorecard_stepwise])[:,1])

# plot distributions
fig, ax = plt.subplots(figsize=(9,5))
ax.set_title('Distributions of Train, Test, and Holdout Predictions')
sns.kdeplot(list_predictions_train, label=f'Train: {np.mean(list_predictions_train):0.4f}')
sns.kdeplot(list_predictions_test, label=f'Test: {np.mean(list_predictions_test):0.4f}')
sns.kdeplot(list_predictions_holdout, label=f'Holdout: {np.mean(list_predictions_holdout):0.4f}')
# legend
ax.legend()
# show
plt.show()

# %%
# eval
flt_auc_train, flt_auc_test = evaluate(
    y_train=y_train,
    list_predictions_train=list_predictions_train,
    y_test=y_test,
    list_predictions_test=list_predictions_test,
    y_holdout=y_holdout,
    list_predictions_holdout=list_predictions_holdout,
)
# Out:
# AUC Train: 0.6520
# AUC Test: 0.6535
# AUC Holdout: 0.6356
#
# Logloss Train: 0.5568
# Logloss Test: 0.5598
# Logloss Holdout: 0.5256
#
# KS Train: 0.2166
# KS Test: 0.2278
# KS Holdout: 0.2075

# %% [markdown]
# #### Force features

# %%
list_feats_force = [
    #'ENG-loan_to_value',
]
list_feats_force = [f'{col}_binned' for col in list_feats_force]
# combine
list_cols_scorecard = list_cols_scorecard_stepwise + list_feats_force
# rm dups
list_cols_scorecard = list(dict.fromkeys(list_cols_scorecard))
# print
print(f'There are {len(list_cols_scorecard)} features in the scorecard')
# Out:
# There are 52 features in the scorecard

# %%
# init
cls_model_inference = LogisticRegression(
    random_state=42,
    fit_intercept=True,
)
# fit
cls_model_inference.fit(
    X_train[list_cols_scorecard].copy(),
    y_train,
)
# adjust weights
cls_model_inference = weight_the_coefficients(
    cls_model_inference=cls_model_inference,
    dict_weights=dict_weights,
)

# get predictions
list_predictions_train = list(cls_model_inference.predict_proba(X_train[list_cols_scorecard])[:,1])
list_predictions_test = list(cls_model_inference.predict_proba(X_test[list_cols_scorecard])[:,1])
list_predictions_holdout = list(cls_model_inference.predict_proba(X_holdout[list_cols_scorecard])[:,1])

# plot distributions
fig, ax = plt.subplots(figsize=(9,5))
ax.set_title('Distributions of Train, Test, and Holdout Predictions')
sns.kdeplot(list_predictions_train, label=f'Train: {np.mean(list_predictions_train):0.4f}')
sns.kdeplot(list_predictions_test, label=f'Test: {np.mean(list_predictions_test):0.4f}')
sns.kdeplot(list_predictions_holdout, label=f'Holdout: {np.mean(list_predictions_holdout):0.4f}')
# legend
ax.legend()
# show
plt.show()

# %%
# eval
flt_auc_train, flt_auc_test = evaluate(
    y_train=y_train,
    list_predictions_train=list_predictions_train,
    y_test=y_test,
    list_predictions_test=list_predictions_test,
    y_holdout=y_holdout,
    list_predictions_holdout=list_predictions_holdout,
)
# Out:
# AUC Train: 0.6520
# AUC Test: 0.6535
# AUC Holdout: 0.6356
#
# Logloss Train: 0.5568
# Logloss Test: 0.5598
# Logloss Holdout: 0.5256
#
# KS Train: 0.2166
# KS Test: 0.2278
# KS Holdout: 0.2075

# %% [markdown]
# #### Get intercept

# %%
# get intercept
flt_intercept = cls_model_inference.intercept_[0]
print(f'Intercept: {flt_intercept}')
# Out:
# Intercept: -0.9792527372901825

# %%
# get feature importance
dict_map_descriptions_bin = {f'{key}_binned': val for key, val in dict_map_descriptions.items()}
df_tmp = get_logistic_regression_feat_importance(
    cls_model_inference=cls_model_inference,
    list_cols_model=list_cols_scorecard,
    df=X_test,
)
# map desceription
df_tmp['description'] = df_tmp['feature'].map(dict_map_descriptions_bin)

# save
str_filename = 'df_feat_imp.csv'
str_local_path = f'{str_dirname_output}/{str_filename}'
df_tmp.to_csv(str_local_path, index=False)

# show
df_tmp
# Out:
#                                 feature  importance  importance_abs  \
# 10                    rev326__tu_binned   -0.015389        0.015389
# 23                     au20s__tu_binned   -0.013869        0.013869
# 6                   linkt001__tu_binned   -0.012772        0.012772
# 11                     g310s__tu_binned   -0.011848        0.011848
# 2            miles_odometer__app_binned    0.011318        0.011318
# 9                   balmag01__tu_binned   -0.011225        0.011225
# 1    fltgrossmonthly__income_sum_binned   -0.010642        0.010642
# 7                     br109s__tu_binned   -0.010270        0.010270
# 15   int_n_months_open__tu_pmthx_binned   -0.008547        0.008547
# 20                   rtl_trd__tu_binned   -0.008445        0.008445
# 26                  linkt002__tu_binned   -0.008375        0.008375
# 0              ENG-loan_to_value_binned    0.007516        0.007516
# 18                     trv10__tu_binned   -0.005847        0.005847
# 38                     trv13__tu_binned   -0.005543        0.005543
# 5                       cv15__tu_binned   -0.005133        0.005133
# 13                     rp01s__tu_binned   -0.004958        0.004958
# 14                     jt20s__tu_binned   -0.004532        0.004532
# 21                     g306s__tu_binned    0.003776        0.003776
# 24                  linkt003__tu_binned   -0.003702        0.003702
# 19                     g002s__tu_binned    0.003381        0.003381
# 28                    rvlr64__tu_binned   -0.003161        0.003161
# 22                     g407s__tu_binned    0.003120        0.003120
# 32                    agg904__tu_binned    0.002880        0.002880
# 12                     g232s__tu_binned    0.002421        0.002421
# 4   flt_wtd_avg_closed__tu_pmthx_binned   -0.002304        0.002304
# 36                      cv13__tu_binned   -0.002194        0.002194
# 34                     fi21s__tu_binned    0.002190        0.002190
# 17                  linkf098__tu_binned   -0.001986        0.001986
# 37                  linka003__tu_binned    0.001874        0.001874
# 27                     in30s__tu_binned   -0.001799        0.001799
# 16                  linka006__tu_binned   -0.001596        0.001596
# 31                    per235__tu_binned   -0.001526        0.001526
# 29      int_30dpd_open__tu_pmthx_binned    0.001518        0.001518
# 25                     co01s__tu_binned    0.001286        0.001286
# 35                     st20s__tu_binned   -0.001233        0.001233
# 30                     fi36s__tu_binned   -0.001114        0.001114
# 41                     in36s__tu_binned    0.000955        0.000955
# 44                     of02s__tu_binned    0.000954        0.000954
# 46                     re06s__tu_binned    0.000824        0.000824
# 33                     fi25s__tu_binned   -0.000816        0.000816
# 8                      in21s__tu_binned   -0.000786        0.000786
# 47                     trv03__tu_binned    0.000625        0.000625
# 49                    us101s__tu_binned   -0.000550        0.000550
# 39                    aut252__tu_binned   -0.000493        0.000493
# 3     flt_wtd_avg_open__tu_pmthx_binned   -0.000467        0.000467
# 45                     s068b__tu_binned    0.000456        0.000456
# 40                     g244f__tu_binned    0.000443        0.000443
# 43                     trv09__tu_binned   -0.000421        0.000421
# 50                      cv17__tu_binned    0.000300        0.000300
# 42                     g219a__tu_binned    0.000196        0.000196
# 48                  linka027__tu_binned   -0.000050        0.000050
# 51                     g102s__tu_binned   -0.000006        0.000006
#
#                                           description
# 10  Average Total Open-to-Buy for Revolving accoun...
# 23              Months since oldest auto trade opened
# 6    Number of non-military addresses in last 7 years
# 11       Worst rating on all trades in past 12 months
# 2                                                 NaN
# 9   Non-mortgage balance magnitude algorithm over ...
# 1                                                 NaN
# 7   Number of bank revolving trades with past due ...
# 15                                                NaN
# 20                            Number of retail trades
# 26                Number of months at current address
# 0                                                 NaN
# 18  Number of months non-mortgage balance decrease...
# 38      Number of revolving high credit increases YOY
# 5                    Number of deduped auto inquiries
# 13                      Number of repossession trades
# 14             Months since oldest joint trade opened
# 21      Worst rating on auto trades in past 12 months
# 24  Number of non-military non-corroborated addres...
# 19  Number of 60 days past due ratings in past 12 ...
# 28  Flag indicating that the consumer revolved at ...
# 22                Number of deduped finance inquiries
# 32  Number of aggregate non-mortgage credit line d...
# 12          Number of inquiries (includes duplicates)
# 4                                                 NaN
# 36               Percentage of trades ever delinquent
# 34  Months since most recent finance installment t...
# 17                      Number of satisfactory trades
# 37  Number of other inquiries in the last 2 years....
# 27  Percentage of open installment trades > 50% of...
# 16  Number of total inquiries in the last 3 years....
# 31  Aggregate Excess Payment for Personal Loan acc...
# 29                                                NaN
# 25                       Number of charged-off trades
# 35      Months since oldest student loan trade opened
# 30  Months since most recent finance installment d...
# 41   Months since most recent installment delinquency
# 44                 Number of open credit union trades
# 46  Number of revolving trades opened in past 6 mo...
# 33  Number of currently open and satisfactory fina...
# 8   Months since most recent installment trade opened
# 47  Number of non-mortgage trades with a balance i...
# 49  Total balance of all unsecured installment tra...
# 39  Average Aggregate Excess Payment for Auto acco...
# 3                                                 NaN
# 45      Number of non-medical third party collections
# 40  Number of finance inquiries (includes duplicat...
# 43       Number of non-mortgage balance decreases YOY
# 50  Number of trades prior 30 days past due, now c...
# 42  Number of trades verified in the past 12 month...
# 48    Number of days since most recent payday inquiry
# 51                   Months since most recent inquiry

# %%
# plot
df_tmp.sort_values(by='importance_abs', ascending=True, inplace=True)
df_tmp['feature_tmp'] = df_tmp['feature'].apply(
    lambda x: x.split('_binned')[0],
)
x = df_tmp['feature_tmp']
y = df_tmp['importance_abs']
fig, ax = plt.subplots(figsize=(9,20))
ax.set_title('Importance by Feature')
ax.barh(x, y)
# show
plt.show()

# %%
# mean actual by prediction quantile in holdout
int_n_quantiles = 10
get_mean_actual_by_prediction_quantile(
    X=X_holdout.copy(),
    list_predictions=list_predictions_holdout,
    list_actual=list(y_holdout),
    str_target=str_target,
    int_n_quantiles=int_n_quantiles,
    str_model_type='LogisticRegressionScorecard',
)

# %%
# # directions of predictions in test
# int_n_quantiles = 10
# get_directions_of_predictions_for_scorecard(
#     X=X_test.copy(),
#     list_predictions=list_predictions_test,
#     str_target=str_target,
#     list_actual=list(y_test),
#     list_cols=list_cols_scorecard,
#     df_bins=df_bins,
# )
