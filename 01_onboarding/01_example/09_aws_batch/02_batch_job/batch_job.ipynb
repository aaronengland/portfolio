# %%
import boto3
import math
from sagemaker import get_execution_role
from pprint import pprint
import time
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %% [markdown]
# ### Functions

# %%
def get_specs(str_instance):
    if str_instance == 'm5.large':
        int_vcpu = 2
        int_memory_gb = 8
    elif str_instance == 'm5.xlarge':
        int_vcpu = 4
        int_memory_gb = 16
    elif str_instance == 'm5.2xlarge':
        int_vcpu = 8
        int_memory_gb = 32
    elif str_instance == 'm5.4xlarge':
        int_vcpu = 16
        int_memory_gb = 64
    elif str_instance == 'm5.8xlarge':
        int_vcpu = 32
        int_memory_gb = 128
    elif str_instance == 'm5.12xlarge':
        int_vcpu = 48
        int_memory_gb = 192
    int_memory_mebibytes = math.ceil(int_memory_gb * 953.674)
    dict_output = {
        'int_vcpu': int_vcpu,
        'int_memory_gb': int_memory_gb,
        'int_memory_mebibytes': int_memory_mebibytes,
    }
    return dict_output

# %% [markdown]
# ### Constants

# %%
str_image_name = 'christian-tuning'
int_iteration = 1
str_instance = 'm5.4xlarge'
dict_specs = get_specs(str_instance=str_instance)
int_vcpu = dict_specs['int_vcpu']
int_memory_gb = dict_specs['int_memory_gb']
int_memory_mebibytes = dict_specs['int_memory_mebibytes']
for key, val in dict_specs.items():
    print(f'{key}: {val}')
# Out:
# int_vcpu: 16
# int_memory_gb: 64
# int_memory_mebibytes: 61036

# %% [markdown]
# ### Create compute environment

# %%
# initialize class
cls_client = boto3.client('batch')

# %%
# get role
try:
    str_role = get_execution_role()
except:
    ! pip install --upgrade boto3
    str_role = get_execution_role()
print(f'Role: {str_role}')
# Out:
# Role: arn:aws:iam::836690756591:role/risk-ops-role

# %%
# create compute environment
while True:
    try:
        str_compute_env_name = f'env-{str_image_name}-{int_iteration}'
        dict_response = cls_client.create_compute_environment(
            computeEnvironmentName=str_compute_env_name,
            type= 'Managed', 
            state= 'ENABLED',
            serviceRole = str_role,
            computeResources={
                #'type': 'SPOT',
                'type': 'EC2',
                'minvCpus': 0,
                'maxvCpus': 256, 
                'desiredvCpus': int_vcpu,
                'instanceTypes': [
                    str_instance,
                ], 
                'subnets': ['subnet-044e573651bb251a7'], 
                'securityGroupIds': ['sg-03904237048cdc335'], 
                'instanceRole': 'ecsInstanceRole',
                #'spotIamFleetRole': 'AmazonEC2SpotFleetTaggingRole',
            },
        )
        pprint(dict_response)
        break
    except:
        int_iteration += 1
# Out:
# {'ResponseMetadata': {'HTTPHeaders': {'access-control-allow-origin': '*',
#                                       'access-control-expose-headers': 'X-amzn-errortype,X-amzn-requestid,X-amzn-errormessage,X-amzn-trace-id,X-amz-apigw-id,date',
#                                       'connection': 'keep-alive',
#                                       'content-length': '157',
#                                       'content-type': 'application/json',
#                                       'date': 'Tue, 11 Jun 2024 22:53:29 GMT',
#                                       'x-amz-apigw-id': 'ZOZIjH4_PHcEhyQ=',
#                                       'x-amzn-requestid': 'e5b1f069-1d7b-470e-be49-831b2f20b37e',
#                                       'x-amzn-trace-id': 'Root=1-6668d569-18c95b993689f7795d55b6c3'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'e5b1f069-1d7b-470e-be49-831b2f20b37e',
#                       'RetryAttempts': 0},
#  'computeEnvironmentArn': 'arn:aws:batch:us-west-2:836690756591:compute-environment/env-christian-tuning-5',
#  'computeEnvironmentName': 'env-christian-tuning-5'}

# %% [markdown]
# ### Create Job Queue

# %%
# create job queue (this is where AWS will store your jobs until an EC2 Instance is available to run them)
while True:
    try:
        str_job_queue_name = f'queue-{str_image_name}-{int_iteration}'
        dict_response = cls_client.create_job_queue(
            jobQueueName=str_job_queue_name,
            state='ENABLED',
            priority=1,
            computeEnvironmentOrder=[
                {
                    'order': 1,
                    'computeEnvironment': str_compute_env_name,
                },
            ]
        )
        # get arn
        str_job_queue_arn = dict_response['jobQueueArn']
        pprint(dict_response)
        break
    except:
        time.sleep(1)
# Out:
# {'ResponseMetadata': {'HTTPHeaders': {'access-control-allow-origin': '*',
#                                       'access-control-expose-headers': 'X-amzn-errortype,X-amzn-requestid,X-amzn-errormessage,X-amzn-trace-id,X-amz-apigw-id,date',
#                                       'connection': 'keep-alive',
#                                       'content-length': '131',
#                                       'content-type': 'application/json',
#                                       'date': 'Tue, 11 Jun 2024 22:53:52 GMT',
#                                       'x-amz-apigw-id': 'ZOZMEFGaPHcEusg=',
#                                       'x-amzn-requestid': '89d2c39e-0256-4fb1-b795-f69ecbd78efc',
#                                       'x-amzn-trace-id': 'Root=1-6668d580-0f20b95436d0b9f412492e43'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '89d2c39e-0256-4fb1-b795-f69ecbd78efc',
#                       'RetryAttempts': 0},
#  'jobQueueArn': 'arn:aws:batch:us-west-2:836690756591:job-queue/queue-christian-tuning-5',
#  'jobQueueName': 'queue-christian-tuning-5'}

# %% [markdown]
# ### Register job definition

# %%
# job definition
while True:
    try:
        str_job_definition = f'job-def-{str_image_name}-{int_iteration}'
        dict_response = cls_client.register_job_definition(
            type='container',
            containerProperties={
                'image': f'836690756591.dkr.ecr.us-west-2.amazonaws.com/{str_image_name}:latest',
                'memory': int_memory_mebibytes,
                'vcpus': int_vcpu,
            },
            jobDefinitionName=str_job_definition,
        )
        # get arn
        str_job_def_arn = dict_response['jobDefinitionArn']
        pprint(dict_response)
        break
    except:
        time.sleep(1)
# Out:
# {'ResponseMetadata': {'HTTPHeaders': {'access-control-allow-origin': '*',
#                                       'access-control-expose-headers': 'X-amzn-errortype,X-amzn-requestid,X-amzn-errormessage,X-amzn-trace-id,X-amz-apigw-id,date',
#                                       'connection': 'keep-alive',
#                                       'content-length': '165',
#                                       'content-type': 'application/json',
#                                       'date': 'Tue, 11 Jun 2024 22:53:52 GMT',
#                                       'x-amz-apigw-id': 'ZOZMFH2YPHcEhGw=',
#                                       'x-amzn-requestid': 'fcef831f-7625-4dee-9480-f5fd13f82ec2',
#                                       'x-amzn-trace-id': 'Root=1-6668d580-5dbc79a43ac1a97135916eb6'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'fcef831f-7625-4dee-9480-f5fd13f82ec2',
#                       'RetryAttempts': 0},
#  'jobDefinitionArn': 'arn:aws:batch:us-west-2:836690756591:job-definition/job-def-christian-tuning-5:1',
#  'jobDefinitionName': 'job-def-christian-tuning-5',
#  'revision': 1}

# %% [markdown]
# ### Submit job

# %%
# submit a job (only for testing)
while True:
    try:
        str_job_name = f'job-name-{str_image_name}-{int_iteration}'
        response = cls_client.submit_job(
            jobDefinition=str_job_definition,
            jobQueue=str_job_queue_name,
            jobName=str_job_name,
            arrayProperties={
                'size': 10,
            },
        )
        pprint(response)
        break
    except:
        time.sleep(1)
# Out:
# {'ResponseMetadata': {'HTTPHeaders': {'access-control-allow-origin': '*',
#                                       'access-control-expose-headers': 'X-amzn-errortype,X-amzn-requestid,X-amzn-errormessage,X-amzn-trace-id,X-amz-apigw-id,date',
#                                       'connection': 'keep-alive',
#                                       'content-length': '177',
#                                       'content-type': 'application/json',
#                                       'date': 'Tue, 11 Jun 2024 22:53:53 GMT',
#                                       'x-amz-apigw-id': 'ZOZMSGHuPHcEQ8g=',
#                                       'x-amzn-requestid': 'c163d9c7-0638-4f6f-9a53-c92472f100cc',
#                                       'x-amzn-trace-id': 'Root=1-6668d581-7498ce9c2e0e1d7602e51da7'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': 'c163d9c7-0638-4f6f-9a53-c92472f100cc',
#                       'RetryAttempts': 0},
#  'jobArn': 'arn:aws:batch:us-west-2:836690756591:job/447f505f-c6b1-43b5-92bc-74cc2359d714',
#  'jobId': '447f505f-c6b1-43b5-92bc-74cc2359d714',
#  'jobName': 'job-name-christian-tuning-5'}

# %% [markdown]
# ### Show arns

# %%
print(f'Job Queue ARN: {str_job_queue_arn}')
print(f'Job Definition ARN: {str_job_def_arn}')
# Out:
# Job Queue ARN: arn:aws:batch:us-west-2:836690756591:job-queue/queue-christian-tuning-4
# Job Definition ARN: arn:aws:batch:us-west-2:836690756591:job-definition/job-def-christian-tuning-4:1
