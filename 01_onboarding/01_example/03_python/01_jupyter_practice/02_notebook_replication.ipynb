# %% [markdown]
# ### Imports

# %%
import os
import pandas as pd
import pickle

try:
    from tqdm import tqdm
except ModuleNotFoundError:
    ! pip install tqdm
    from tqdm import tqdm
    
try:
    import matplotlib.pyplot as plt
except ModuleNotFoundError:
    ! pip install matplotlin.pyplot
    import matplotlib.pyplot as plt

# %% [markdown]
# ### Functions

# %% [markdown]
# ### Constants

# %%
os.getcwd()
# Out:
# '/home/ec2-user/SageMaker/20240509_christian_internship/03_python/01_jupyter_practice'

# %%
str_project = os.getcwd().split('/')[4].replace('_', "-")
print(f'Project: {str_project}')
str_task = os.getcwd().split('/')[5]
print(f'Task: {str_task}')
str_subtask = os.getcwd().split('/')[6]
print(f'Subtask: {str_subtask}')
str_dirname_output = './output'
# Out:
# Project: 20240509-christian-internship
# Task: 03_python
# Subtask: 01_jupyter_practice

# %% [markdown]
# ### Output Directory

# %%
try:
    os.mkdir(str_dirname_output)
except FileExistsError:
    pass

# %% [markdown]
# ### Read CSV

# %%
str_filename = 'all_funded_loans.csv'

# %% [markdown]
# ### Read GZip
