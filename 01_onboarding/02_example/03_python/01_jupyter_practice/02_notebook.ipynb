# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import pyodbc
import numpy as np

# %%
conn = pyodbc.connect(
    'Driver={SQL Server};'
    'Server=electra;'
    'Database=pfsdb;'
    'Trusted_connection=yes;'
)

str_query =open('./sql/UTTempPoolquery.sql', 'r').read()

df = pd.read_sql_query(
    sql=str_query,
    con=conn,
)

conn.close()
# Out:
# C:\Users\bhyde\AppData\Local\Temp\ipykernel_4964\3259373209.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(

# %%
conn = pyodbc.connect(
    'Driver={SQL Server};'
    'Server=electra;'
    'Database=pfsdb;'
    'Trusted_connection=yes;'
)

str_query =open('./sql/TXTempPoolquery.sql', 'r').read()

df2 = pd.read_sql_query(
    sql=str_query,
    con=conn,
)

conn.close()
# Out:
# C:\Users\bhyde\AppData\Local\Temp\ipykernel_4964\4062675336.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df2 = pd.read_sql_query(

# %%
df.head(5)
# Out:
#    bigAccountId FundingMonth LoanStatus CreditorProgramInitial strTier  \
# 0       7191884   2023-10-01          A                      P       A
# 1       7222913   2023-10-01          A                      P       D
# 2       7494826   2024-01-01          A                      P       B
# 3       7514680   2024-02-01          A                      P       B
# 4       7149371   2023-10-01          A                      P       A
#
#    intOpenBKType Portfolio DebtorState        ContractDate BookingDate  ...  \
# 0            7.0         Z          UT 2023-10-11 00:00:00  2023-10-18  ...
# 1            NaN         Z          UT 2023-10-16 00:00:00  2023-10-28  ...
# 2            NaN         E          UT 2024-01-15 20:42:48  2024-01-29  ...
# 3            NaN         E          UT 2024-01-26 00:00:00  2024-02-02  ...
# 4            NaN         Z          UT 2023-10-04 00:00:00  2023-10-12  ...
#
#    mnyManheim  ManheimToNADA  RiskByFinanced  PTIbyAmtFinanced  \
# ...

# %%
df2.head(5)
# Out:
#    bigAccountId FundingMonth LoanStatus CreditorProgramInitial strTier  \
# 0       7223328   2023-11-01          A                      P      A1
# 1       7362260   2023-12-01          A                      P      A1
# 2       7547956   2024-02-01          A                      P      A1
# 3       7844875   2024-05-01          A                      P       C
# 4       6958998   2023-08-01          A                      P       D
#
#    intOpenBKType Portfolio DebtorState        ContractDate BookingDate  ...  \
# 0            7.0         E          TX 2023-10-21 00:00:00  2023-11-22  ...
# 1            7.0         E          TX 2023-11-30 00:00:00  2023-12-11  ...
# 2            7.0         E          TX 2024-02-16 00:00:00  2024-02-22  ...
# 3            NaN         N          TX 2024-05-20 16:44:33  2024-05-22  ...
# 4            NaN         Z          TX 2023-07-21 00:00:00  2023-08-24  ...
#
#    mnyManheim  ManheimToNADA  RiskByFinanced  PTIbyAmtFinanced  \
# ...

# %%
df.plot(x="DebtorState", y="FundingMonth", kind="bar")
# Out:
# <Axes: xlabel='DebtorState'>

# %%
df.plot(x='LoanStatus', y='PTIbyAmtFinanced', kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.pie(df["PTIbyAmtFinanced"], labels=df["LoanStatus"])
plt.show()

# %%
df['utavg'] = (df[['PTIbyAmtFinanced']].mean(axis=0))
df2['txavg'] = (df2[['PTIbyAmtFinanced']].mean(axis=0))
#df.head()
#df2.head()

#df3['utavg'] == df['utavg']
#df3['txavg'] = df2['txavg']
#df3.head()

# %%
plt.pie(df['utavg'], df2['txavg'], labels=df['DebtorState'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 plt.pie(df['utavg'], df2['txavg'], labels=df['DebtorState'])
#       2 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3676, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3653 @_copy_docstring_and_deprecators(Axes.pie)
#    3654 def pie(
#    3655     x: ArrayLike,
#    (...)
#    3674     data=None,
#    3675 ) -> tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]:
# -> 3676     return gca().pie(
#    3677         x,
#    3678         explode=explode,
#    3679         labels=labels,
#    3680         colors=colors,
#    3681         autopct=autopct,
# ...

# %%
df.plot(x=df[['utavg','txavg']],

# %%
df.to_csv('./output/plot_data.csv', index=False)

# %%
# set up connection
conn = pyodbc.connect(
    'Driver={SQL Server};'
    'Server=electra;'
    'Database=pfsdb;'
    'Trusted_connection=yes;'
)

# get our query
str_query =open('./sql/SQLQuery1.sql', 'r').read()

# read query, get dataframe
df4 = pd.read_sql_query(
    sql=str_query,
    con=conn,
)

# close the connection
conn.close()
# Out:
# C:\Users\bhyde\AppData\Local\Temp\ipykernel_4964\1425579841.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df4 = pd.read_sql_query(

# %%
df4.shape
# Out:
# (86386, 206)

# %%
df4.to_csv('./output/data.csv', index=False)

# %%
# save data to parquet (gzip) example
df4.to_parquet('./output/data.gzip',
               index=False,
               compression='gzip')

# %%
# read in parquet 
df5 = pd.read_parquet('./output/data.gzip')
df5.head()
# Out:
#    bigAccountId FundingMonth LoanStatus CreditorProgramInitial strTier  \
# 0       7254423   2023-11-01          A                      P       B
# 1       7254855   2023-10-01          A                      P       B
# 2       7268655   2023-11-01          A                      P       B
# 3       7270149   2023-11-01          A                      P       C
# 4       7270444   2023-10-01          A                      P       D
#
#    intOpenBKType Portfolio DebtorState        ContractDate BookingDate  ...  \
# 0            NaN         E          VA 2023-10-21 16:18:06  2023-11-01  ...
# 1            NaN         E          SC 2023-10-20 00:00:00  2023-10-31  ...
# 2           13.0         E          AL 2023-10-25 11:38:06  2023-11-27  ...
# 3            NaN         E          MI 2023-10-24 00:00:00  2023-11-20  ...
# 4            NaN         Z          SC 2023-10-23 00:00:00  2023-10-27  ...
#
#    mnyManheim  ManheimToNADA  RiskByFinanced  PTIbyAmtFinanced  \
# ...

# %%
#drop all null values
df5.dropna
#drop all non useful columns
df5.drop(columns=['bigAccountId','FundingMonth','LoanStatus','CreditorProgramInitial', 'intOpenBKType','ContractDate','BookingDate','mnyManheim','ManheimToNADA','RiskByFinanced','bitSystemApproval','SegmentedScorebyFinanced','bitEncore'], axis=1)
df5.drop(columns=['MilesDiffManVSDef','bitEmployeeLoan','bitLoanModification','bitPaymentChange'],axis=1)
# Out:
#        bigAccountId FundingMonth LoanStatus CreditorProgramInitial strTier  \
# 0           7254423   2023-11-01          A                      P       B
# 1           7254855   2023-10-01          A                      P       B
# 2           7268655   2023-11-01          A                      P       B
# 3           7270149   2023-11-01          A                      P       C
# 4           7270444   2023-10-01          A                      P       D
# ...             ...          ...        ...                    ...     ...
# 86381       6342686   2022-09-01          C                      P       A
# 86382       6343393   2022-10-01          A                      P       C
# 86383       6343582   2022-10-01          A                      P       B
# 86384       6346098   2022-09-01          A                      P      A1
# 86385       6347781   2022-10-01          A                      P       C
#
# ...

# %%
# establish graph points
xpoints= np.array(df5['ContractDate'])
ypoints= np.array(df5['PTIbyAmtFinanced'])

# plot the graph points
plt.plot(xpoints, ypoints)
plt.show()

# %%
conn = pyodbc.connect(
    'Driver={SQL Server};'
    'Server=electra;'
    'Database=pfsdb;'
    'Trusted_connection=yes;'
)

str_query =open('./sql/UTTempPoolquery.sql', 'r').read()

df6 = pd.read_sql_query(
    sql=str_query,
    con=conn,
)

conn.close()
# Out:
# C:\Users\bhyde\AppData\Local\Temp\ipykernel_4964\2209438818.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df6 = pd.read_sql_query(

# %%
df6.head()
# Out:
#    bigAccountId FundingMonth LoanStatus CreditorProgramInitial strTier  \
# 0       7191884   2023-10-01          A                      P       A
# 1       7222913   2023-10-01          A                      P       D
# 2       7494826   2024-01-01          A                      P       B
# 3       7514680   2024-02-01          A                      P       B
# 4       7149371   2023-10-01          A                      P       A
#
#    intOpenBKType Portfolio DebtorState        ContractDate BookingDate  ...  \
# 0            7.0         Z          UT 2023-10-11 00:00:00  2023-10-18  ...
# 1            NaN         Z          UT 2023-10-16 00:00:00  2023-10-28  ...
# 2            NaN         E          UT 2024-01-15 20:42:48  2024-01-29  ...
# 3            NaN         E          UT 2024-01-26 00:00:00  2024-02-02  ...
# 4            NaN         Z          UT 2023-10-04 00:00:00  2023-10-12  ...
#
#    mnyManheim  ManheimToNADA  RiskByFinanced  PTIbyAmtFinanced  \
# ...

# %%
#set points for information
x = np.array(df6['DealerType'])
y = np.array(df6['DTIbyAmtFinanced'])
# plot the information
plt.scatter(x,y)
plt.show()

# %%
x = np.array(['DealerType'])
y = np.array(['DTIbyAmtFinanced'])

plt.hist(x, y)
plt.show()
