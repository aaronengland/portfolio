# %%
import os
import pandas as pd

# %% [markdown]
# #### Constants

# %%
# get project
str_project = os.getcwd().split('/')[4].replace('_','-')
print(str_project)

# get task
str_task = os.getcwd().split('/')[5]
print(str_task)

# get subtask
str_subtask = os.getcwd().split('/')[6]
print(str_subtask)
# Out:
# 20240521-bridger-internship
# 03_python
# 01_jupyter_practice

# %% [markdown]
# #### Functions

# %%
# read gzip file function
def read_my_gzip(str_local_path):
    print(f'reading from {str_local_path}')
    df = pd.read_parquet(str_local_path)
    return df

# %% [markdown]
# #### Read in the gzip currently stored in s3 bridger project bucket

# %%
str_filename = 'df_model_scores.gzip'
str_uri = f's3://{str_project}/{str_task}/{str_subtask}/df_model_scores.gzip'
df = read_my_gzip(
    str_uri,
)
# Out:
# reading from s3://20240521-bridger-internship/03_python/01_jupyter_practice/df_model_scores.gzip

# %%
df.head()
# Out:
#    bigAccountId  bigDealerId        dtmStampCreation  dtmFunded  intTerm  \
# 0       7493671         3608 2024-01-15 13:21:59.243 2024-01-22       72
# 1       7499635         3838 2024-01-17 17:53:56.933 2024-01-23       60
# 2       7596567         2136 2024-02-22 18:09:58.153 2024-03-01       72
# 3       7516366         4462 2024-01-24 15:21:47.550 2024-02-07       60
# 4       7721684         2136 2024-04-01 12:18:13.677 2024-04-08       72
#
#    intOpenBKType strTier  AmtFinanced  OriginalInterestRate  MaxFico  \
# 0            NaN       B     22864.17                 25.24    525.0
# 1            NaN       D     14452.80                 24.00    577.0
# 2            NaN       C     20290.00                 26.74    527.0
# 3            NaN       A     17827.00                 21.24    631.0
# 4            NaN       D     24690.00                 28.24    450.0
#
#      Gen 11    Gen 12
# 0  0.092872  0.092872
# 1  0.207355  0.207355
# 2  0.208573  0.208573
# ...
